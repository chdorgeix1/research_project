# %%
from os import listdir
from os.path import isfile, join
import numpy as np
import re
import pandas as pd
import numpy as np
import dataProcessing as DP

# %%
my_path = '/Users/15404/Documents/GitHub/research_project/rarefaction_curve_data/'
df = DP.data_processing(my_path, 'phylum', False)
df.head()
# Out:
#   samples paired_end Archaea|Candidatus Bathyarchaeota Archaea|Crenarchaeota  \
# 0     A01         R1                                 0               0.00025
# 1     A02         R2                                 0                     0
# 2     A03         R1                                 0                     0
# 3     E05         R2                                 0               0.00042
# 4     F10         R1                                 0                     0
#
#   Archaea|Euryarchaeota Archaea|Thaumarchaeota Bacteria|Acidobacteria  \
# 0               0.00288                0.00016                0.39156
# 1               0.03238                0.00483                0.19886
# 2               0.04178                0.01153                0.21995
# 3                0.0004                0.01333                0.33679
# 4               0.03391                0.00425                0.25793
#
#   Bacteria|Actinobacteria Bacteria|Aquificae Bacteria|Armatimonadetes  \
# 0                 7.16024                  0                  0.00445
# 1                 5.81539                  0                  0.00447
# 2                  3.6387                  0                  0.00107
# 3                 8.88698                  0                  0.00011
# 4                 6.07029                  0                  0.00272
#
#            ...           Bacteria|candidate division CPR2  \
# 0          ...                                          0
# 1          ...                                          0
# 2          ...                                          0
# 3          ...                                          0
# 4          ...                                          0
#
#   Bacteria|candidate division NC10 Bacteria|candidate division WPS-2  \
# 0                          0.00089                                 0
# 1                          0.00986                                 0
# 2                          0.00821                           0.00022
# 3                          0.01272                                 0
# 4                          0.00361                                 0
#
#   Bacteria|candidate division WWE3 Bacteria|candidate division Zixibacteria  \
# 0                           0.0001                                        0
# 1                          0.00078                                        0
# 2                          0.00026                                        0
# 3                          0.00179                                        0
# 4                                0                                        0
#
#   Eukaryota|Apicomplexa Eukaryota|Ascomycota Eukaryota|Basidiomycota  \
# 0               0.00014              0.00496                 0.00089
# 1                     0              0.00213                 0.00057
# 2                     0               0.0015                  0.0008
# 3                     0              0.00072                  0.0003
# 4                     0              0.00359                 0.00093
#
#   Eukaryota|Chlorophyta Eukaryota|Mucoromycota
# 0               0.00034                0.00025
# 1               0.00084                      0
# 2               0.00052                      0
# 3                     0                      0
# 4               0.00082                      0
#
# [5 rows x 85 columns]

# %%
df.to_csv('rarefaction_data.csv')
