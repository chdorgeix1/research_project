# %%
import pandas as pd
import numpy as np
import sqlite3
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
import statsmodels
import statsmodels.api as sm
from statsmodels.multivariate.manova import MANOVA
from scipy import stats

from useful_functions import *

# %%
tables_to_join = ["tPlantNutrients", "tSample", "tPlantDNA"]
common_column = "sample_id"
full_df = import_all_data(tables_to_join, common_column)
full_df.shape
# Out:
# (158, 26)

# %%
full_df.head(10)
# Out:
#    sample_id  N_percent_dm  P_percent_dm  K_percent_dm  Ca_percent_dm  \
# 0       RRL1           NaN          0.21          4.01           0.83
# 1       RRL2          2.24          0.16          5.34           1.05
# 2       RRL3           NaN          0.20          4.75           0.63
# 3       RRL4           NaN          0.18          4.74           1.25
# 4       RRL5          3.00          0.26          3.51           1.20
# 5       RRL6          3.26          0.19          2.55           0.73
# 6       RRL7           NaN          0.21          3.67           0.88
# 7       RRL9          3.39          0.18          3.23           0.65
# 8      RRL10           NaN          0.18          3.29           1.37
# 9      RRL11          3.28          0.22          2.56           0.64
#
#    Mg_percent_dm  Na_percent_dm  S_percent_dm  Zn_ppm_dm  Mn_ppm_dm  ...  \
# 0           0.29           0.01          0.37       29.0      281.0  ...
# 1           0.32           0.01          0.29       20.0      423.0  ...
# 2           0.27           0.04          0.22       21.0      469.0  ...
# 3           0.32           0.01          0.28       18.0      680.0  ...
# 4           0.44           0.01          0.29       29.0      507.0  ...
# 5           0.50           0.01          0.28       21.0      324.0  ...
# 6           0.22           0.01          0.32       17.0      509.0  ...
# 7           0.30           0.01          0.35       17.0      476.0  ...
# 8           0.38           0.01          0.28       28.0      538.0  ...
# 9           0.30           0.01          0.30       26.0      432.0  ...
#
#    collect_date  sample_id        V1        V2   species       PC1       PC2  \
# 0     6/25/2021       RRL1  0.753244  0.246756  exaltata  0.194769  0.048276
# 1     6/25/2021       RRL2  0.708412  0.291588  exaltata  0.154924  0.071277
# 2     6/25/2021       RRL3  0.778046  0.221954  exaltata  0.187750  0.035009
# 3     6/25/2021       RRL4  0.720367  0.279633  exaltata  0.167167  0.046053
# 4     6/25/2021       RRL5  0.572487  0.427513  exaltata  0.099801  0.089800
# 5     6/25/2021       RRL6  0.653961  0.346039  exaltata  0.128610  0.076955
# 6     6/25/2021       RRL7  0.775482  0.224518  exaltata  0.184532  0.031368
# 7     6/25/2021       RRL9  0.581366  0.418634  exaltata  0.097719  0.094733
# 8     6/25/2021      RRL10  0.592773  0.407227  exaltata  0.113937  0.086560
# 9     6/25/2021      RRL11  0.584173  0.415827  exaltata  0.106894  0.088742
#
#         PC3       PC4       PC5
# 0 -0.023880 -0.017138 -0.039842
# 1  0.000923 -0.025830  0.005592
# 2 -0.016006 -0.012529 -0.011169
# 3 -0.032754 -0.016192 -0.028988
# 4  0.000613 -0.004979  0.017524
# 5  0.020429 -0.053479  0.015590
# 6 -0.018565  0.016763 -0.017642
# 7 -0.006560  0.012822 -0.022248
# 8 -0.018321  0.007765 -0.027255
# 9  0.007519 -0.007988  0.002289
#
# [10 rows x 26 columns]

# %%
#drop duplicate columns
df = full_df
df = df.T.drop_duplicates().T
df.shape
# Out:
# (158, 24)

# %%
nutrients = df.columns
nutrients = nutrients.drop(['sample_id', 'site_id', 'collect_date', 'V1','V2','PC1','PC2','PC3','PC4','PC5', 'species'])

# %%
nutrients
# Out:
# Index(['N_percent_dm', 'P_percent_dm', 'K_percent_dm', 'Ca_percent_dm',
#        'Mg_percent_dm', 'Na_percent_dm', 'S_percent_dm', 'Zn_ppm_dm',
#        'Mn_ppm_dm', 'Fe_ppm_dm', 'Cu_ppm_dm', 'B_ppm_dm', 'Al_ppm_dm'],
#       dtype='object')

# %% [markdown]
# ## Boxplots of Plant Nutrients by Site

# %%
for i in nutrients:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='site_id', y=i, data=df)
    plt.title(i + ' by Site')
    plt.xlabel('Site')
    plt.ylabel(i)
    plt.show()

# %% [markdown]
# ## Boxplot of Plant Nutrients by Plant Species

# %%
subdf = df[df["species"].isin(['syriaca', 'exaltata'])]
subdf.shape
# Out:
# (154, 24)

# %%
for i in nutrients:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='species', y=i, data=subdf)
    plt.title(i + ' by Species')
    plt.xlabel('Species')
    plt.ylabel(i)
    plt.show()

# %% [markdown]
# ## Scatter Plots of V2 vs. Nutrients

# %% [markdown]
# ### Scatterplot for Nitrogen for dropping Rows

# %%
nitrogen_spdf = subdf.dropna()

# %%
x_data = nitrogen_spdf['V2'].astype(float)
y_data = nitrogen_spdf['N_percent_dm'].astype(float)
corel_coef, p_value = stats.pearsonr(x_data, y_data)
    
# Perform linear regression to calculate the best-fit line
slope, intercept = np.polyfit(x_data, y_data, 1)

# Create a scatter plot
plt.scatter(x_data, y_data, label='Data Points')

# Create the best-fit line using the slope and intercept
best_fit_line = [slope * x + intercept for x in x_data]

# Plot the best-fit line
plt.plot(x_data, best_fit_line, color='red', label='Best Fit Line')

# Add labels and a legend
plt.xlabel('Proportion Syriaca')
plt.ylabel('N_percent_dm')
#plt.legend()

# Show the plot
plt.title(f'Scatter plot of Genetic Proportion Syriaca and Leaf N_percent_dm')

if p_value < 0.05:
    plt.text(x_data.max()-.4, y_data.max(), f"Pearson's r ={round(corel_coef,2)}")
    plt.text(x_data.max()-.4, y_data.max()*.95, f"P-Value ={round(p_value, 5)}")

plt.show()

print(i)
print(f'Correlation coefficient value: {corel_coef}')
print(f'Correlation P-Value: {p_value}')
# Out:
# Al_ppm_dm
# Correlation coefficient value: -0.3777019859918462
# Correlation P-Value: 6.297973040330677e-06

# %% [markdown]
# ### Scatterplots for the rest of the nutrients

# %%
spdf = subdf

# %%
no_nitrogen = nutrients.drop('N_percent_dm')

# %%
x_data = spdf['V2'].astype(float)

for i in no_nitrogen:
    y_data = spdf[i].astype(float)
    
    corel_coef, p_value = stats.pearsonr(x_data, y_data)
    
    # Perform linear regression to calculate the best-fit line
    slope, intercept = np.polyfit(x_data, y_data, 1)

    # Create a scatter plot
    plt.scatter(x_data, y_data, label='Data Points')

    # Create the best-fit line using the slope and intercept
    best_fit_line = [slope * x + intercept for x in x_data]

    # Plot the best-fit line
    plt.plot(x_data, best_fit_line, color='red', label='Best Fit Line')

    # Add labels and a legend
    plt.xlabel('Proportion Syriaca')
    plt.ylabel(i)
    #plt.legend()

    # Show the plot
    plt.title(f'Scatter plot of Genetic Proportion Syriaca and Leaf {i}')
    
    if p_value < 0.05:
        plt.text(x_data.max()-.4, y_data.max(), f"Pearson's r ={round(corel_coef,2)}")
        plt.text(x_data.max()-.4, y_data.max()*.95, f"P-Value ={round(p_value, 5)}")
    
    plt.show()
    
    print(i)
    print(f'Correlation coefficient value: {corel_coef}')
    print(f'Correlation P-Value: {p_value}')
# Out:
# P_percent_dm
# Correlation coefficient value: 0.33095331403801237
# Correlation P-Value: 2.7611405882954678e-05
# K_percent_dm
# Correlation coefficient value: -0.33172421295001175
# Correlation P-Value: 2.637750414785177e-05
# Ca_percent_dm
# Correlation coefficient value: 0.3628140816805781
# Correlation P-Value: 3.759012221813593e-06
# Mg_percent_dm
# Correlation coefficient value: 0.35096869100838357
# Correlation P-Value: 8.09256538536148e-06
# Na_percent_dm
# Correlation coefficient value: -0.07327350035878721
# Correlation P-Value: 0.3664693393801553
# S_percent_dm
# Correlation coefficient value: -0.07706390703646887
# Correlation P-Value: 0.3421326193574561
# Zn_ppm_dm
# Correlation coefficient value: -0.013979393262277463
# Correlation P-Value: 0.8633787927006644
# Mn_ppm_dm
# Correlation coefficient value: -0.4132405778669548
# Correlation P-Value: 1.0016721213939321e-07
# Fe_ppm_dm
# Correlation coefficient value: -0.28922864113160196
# Correlation P-Value: 0.00027469816645450445
# Cu_ppm_dm
# Correlation coefficient value: 0.3090316138128935
# Correlation P-Value: 9.63406074953417e-05
# B_ppm_dm
# Correlation coefficient value: -0.5773580646933087
# Correlation P-Value: 4.57095964886463e-15
# Al_ppm_dm
# Correlation coefficient value: -0.30696080913827284
# Correlation P-Value: 0.00010787766724491887

# %% [markdown]
# ## T-Test between Syriaca and Exaltata Plant Nutrients

# %% [markdown]
# ### With NaN included

# %%
def Average(lst):
    return sum(lst) / len(lst)

# %%
for nutrient in nutrients:
    df1 = df[["species",nutrient]]

    s = list(df1.loc[df1["species"].eq("syriaca")][nutrient].to_numpy())
    e = list(df1.loc[df1["species"].eq("exaltata")][nutrient].to_numpy())
    
    #if stats.ttest_ind(s,e)[1] < 0.05:
    print(nutrient)
    print(f'Syriaca Mean {Average(s)}')
    print(f'Exaltata Mean {Average(e)}')
    print(stats.ttest_ind(s,e))
    print('')
# Out:
# N_percent_dm
# Syriaca Mean nan
# Exaltata Mean nan
# TtestResult(statistic=nan, pvalue=nan, df=nan)
#
# P_percent_dm
# Syriaca Mean 0.2867307692307693
# Exaltata Mean 0.22520000000000004
# TtestResult(statistic=4.796172888363872, pvalue=3.8243033406987164e-06, df=152.0)
#
# K_percent_dm
# Syriaca Mean 2.4263461538461533
# Exaltata Mean 3.1409999999999996
# TtestResult(statistic=-4.403936788898745, pvalue=1.9949786527992162e-05, df=152.0)
#
# Ca_percent_dm
# Syriaca Mean 1.35375
# Exaltata Mean 0.9289999999999998
# TtestResult(statistic=5.393687284707425, pvalue=2.5911551607587784e-07, df=152.0)
#
# Mg_percent_dm
# Syriaca Mean 0.45894230769230787
# Exaltata Mean 0.31720000000000004
# TtestResult(statistic=4.646357681125192, pvalue=7.26852912479309e-06, df=152.0)
#
# Na_percent_dm
# Syriaca Mean 0.010192307692307698
# Exaltata Mean 0.010600000000000005
# TtestResult(statistic=-0.8169661398691596, pvalue=0.4152264072238798, df=152.0)
#
# S_percent_dm
# Syriaca Mean 0.26067307692307695
# Exaltata Mean 0.27279999999999993
# TtestResult(statistic=-1.028846113464971, pvalue=0.3051863943324144, df=152.0)
#
# Zn_ppm_dm
# Syriaca Mean 23.221153846153847
# Exaltata Mean 23.88
# TtestResult(statistic=-0.5141077012349855, pvalue=0.6079233127187725, df=152.0)
#
# Mn_ppm_dm
# Syriaca Mean 125.45192307692308
# Exaltata Mean 262.8
# TtestResult(statistic=-7.039003992152551, pvalue=6.224938760482542e-11, df=152.0)
#
# Fe_ppm_dm
# Syriaca Mean 54.50961538461539
# Exaltata Mean 69.18
# TtestResult(statistic=-3.626280710039793, pvalue=0.00039182512263944927, df=152.0)
#
# Cu_ppm_dm
# Syriaca Mean 7.086538461538462
# Exaltata Mean 5.82
# TtestResult(statistic=3.582192497409442, pvalue=0.0004580978666721831, df=152.0)
#
# B_ppm_dm
# Syriaca Mean 20.259615384615383
# Exaltata Mean 31.1
# TtestResult(statistic=-8.286087415626408, pvalue=5.688665001621679e-14, df=152.0)
#
# Al_ppm_dm
# Syriaca Mean 19.384615384615383
# Exaltata Mean 31.84
# TtestResult(statistic=-4.543708179612693, pvalue=1.1196367087663768e-05, df=152.0)

# %% [markdown]
# ### After dropping NaN

# %%
df = df.dropna()

# %%
for nutrient in nutrients:
    df1 = df[["species",nutrient]]

    s = list(df1.loc[df1["species"].eq("syriaca")][nutrient].to_numpy())
    e = list(df1.loc[df1["species"].eq("exaltata")][nutrient].to_numpy())
    
    #if stats.ttest_ind(s,e)[1] < 0.05:
    print(nutrient)
    print(f'Syriaca Mean {Average(s)}')
    print(f'Exaltata Mean {Average(e)}')
    print(stats.ttest_ind(s,e))
    print('')
# Out:
# N_percent_dm
# Syriaca Mean 2.728252427184466
# Exaltata Mean 3.1921875
# TtestResult(statistic=-4.146365136118009, pvalue=5.981679139135237e-05, df=133.0)
#
# P_percent_dm
# Syriaca Mean 0.2876699029126214
# Exaltata Mean 0.2340625
# TtestResult(statistic=3.3812372462574474, pvalue=0.0009477432778971179, df=133.0)
#
# K_percent_dm
# Syriaca Mean 2.4402912621359216
# Exaltata Mean 2.970625
# TtestResult(statistic=-2.7643034708096463, pvalue=0.006514515868904237, df=133.0)
#
# Ca_percent_dm
# Syriaca Mean 1.3544660194174756
# Exaltata Mean 0.9131249999999999
# TtestResult(statistic=4.662372355577227, pvalue=7.5078894455094e-06, df=133.0)
#
# Mg_percent_dm
# Syriaca Mean 0.459611650485437
# Exaltata Mean 0.30062500000000003
# TtestResult(statistic=4.244462256078231, pvalue=4.082428402372664e-05, df=133.0)
#
# Na_percent_dm
# Syriaca Mean 0.01019417475728156
# Exaltata Mean 0.010000000000000004
# TtestResult(statistic=0.5559475741076053, pvalue=0.5791807578469128, df=133.0)
#
# S_percent_dm
# Syriaca Mean 0.26135922330097094
# Exaltata Mean 0.283125
# TtestResult(statistic=-1.529606605237813, pvalue=0.12848909370738965, df=133.0)
#
# Zn_ppm_dm
# Syriaca Mean 23.281553398058254
# Exaltata Mean 24.0
# TtestResult(statistic=-0.4717647287966655, pvalue=0.6378677657748086, df=133.0)
#
# Mn_ppm_dm
# Syriaca Mean 125.32038834951456
# Exaltata Mean 254.09375
# TtestResult(statistic=-6.16778151418913, pvalue=7.760541874242566e-09, df=133.0)
#
# Fe_ppm_dm
# Syriaca Mean 54.66019417475728
# Exaltata Mean 61.4375
# TtestResult(statistic=-1.7293263306289315, pvalue=0.0860708804523309, df=133.0)
#
# Cu_ppm_dm
# Syriaca Mean 7.097087378640777
# Exaltata Mean 5.21875
# TtestResult(statistic=5.146762750849059, pvalue=9.303607960987236e-07, df=133.0)
#
# B_ppm_dm
# Syriaca Mean 20.33009708737864
# Exaltata Mean 28.59375
# TtestResult(statistic=-5.799621967819237, pvalue=4.606200913970748e-08, df=133.0)
#
# Al_ppm_dm
# Syriaca Mean 19.271844660194176
# Exaltata Mean 29.59375
# TtestResult(statistic=-3.634908854114073, pvalue=0.0003962384684369796, df=133.0)
# C:\Users\15404\anaconda3.1\envs\research_env\Lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning:
#
# Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.

# %% [markdown]
# ## Data Setup For PCA

# %%
newdf = full_df
newdf = newdf.T.drop_duplicates().T
#newdf = newdf.dropna()
newdf[nutrients] = StandardScaler().fit_transform(newdf[nutrients])

# %%
newdf.head()
# Out:
#   sample_id  N_percent_dm  P_percent_dm  K_percent_dm  Ca_percent_dm  \
# 0      RRL1           NaN     -0.738864      1.354181      -0.773433
# 1      RRL2     -1.025087     -1.365154      2.697114      -0.334574
# 2      RRL3           NaN     -0.864122      2.101377      -1.172396
# 3      RRL4           NaN     -1.114638      2.091279       0.064390
# 4      RRL5      0.281845     -0.112574      0.849319      -0.035351
#
#    Mg_percent_dm  Na_percent_dm  S_percent_dm  Zn_ppm_dm  Mn_ppm_dm  ...  \
# 0      -0.655431      -0.111002      1.499691   0.762893   0.880423  ...
# 1      -0.494460      -0.111002      0.352922  -0.464294   1.977760  ...
# 2      -0.762745      10.411944     -0.650501  -0.327940   2.333235  ...
# 3      -0.494460      -0.111002      0.209576  -0.737003   3.963785  ...
# 4       0.149425      -0.111002      0.352922   0.762893   2.626888  ...
#
#    site_id  collect_date        V1        V2   species       PC1       PC2  \
# 0      RRL     6/25/2021  0.753244  0.246756  exaltata  0.194769  0.048276
# 1      RRL     6/25/2021  0.708412  0.291588  exaltata  0.154924  0.071277
# 2      RRL     6/25/2021  0.778046  0.221954  exaltata   0.18775  0.035009
# 3      RRL     6/25/2021  0.720367  0.279633  exaltata  0.167167  0.046053
# 4      RRL     6/25/2021  0.572487  0.427513  exaltata  0.099801    0.0898
#
#         PC3       PC4       PC5
# 0  -0.02388 -0.017138 -0.039842
# 1  0.000923  -0.02583  0.005592
# 2 -0.016006 -0.012529 -0.011169
# 3 -0.032754 -0.016192 -0.028988
# 4  0.000613 -0.004979  0.017524
#
# [5 rows x 24 columns]

# %% [markdown]
# ## PCA of Plant Nutrient by Site

# %% [markdown]
# ### PCAs without Nitrogen (Due to NaN)

# %%
no_nitrogen = nutrients.drop('N_percent_dm')

# %%
X = newdf[no_nitrogen]

pca = PCA(n_components=2)
components = pca.fit_transform(X)

fig = px.scatter(components, x=0, y=1, color
marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"CMB","orientation":"v","showlegend":true,"x":[-5.630850791931152,9.24189567565918,12.415122985839844,12.390704154968262,13.482924461364746,7.751380920410156,11.603900909423828,12.968276977539062,14.812870025634766,6.993753910064697,3.7231009006500244,4.915492057800293,8.72504711151123,8.341864585876465,10.664292335510254,9.38166332244873,10.32178783416748,5.561150074005127,5.562178611755371,6.915506362915039,7.630954742431641],"xaxis":"x","y":[-7.801843643188477,13.504714965820312,16.244211196899414,14.873114585876465,14.35273265838623,10.454928398132324,-3.394017457962036,-2.9246888160705566,-3.2589495182037354,7.297180652618408,7.870306968688965,5.178834915161133,5.579760551452637,3.466014862060547,4.692605018615723,8.07349681854248,2.8784708976745605,9.365151405334473,6.954078197479248,5.054340362548828,13.026082038879395],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=SLG<br>0=%{x}<br>1=%{y}<extra></extra>","legendgroup":"SLG","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"SLG","orientation":"v","showlegend":true,"x":[3.1047043800354004,-4.83796 ...

# %% [markdown]
# ## PCA of Plant Nutrients by Species

# %%
subdf = newdf[newdf["species"].isin(['syriaca', 'exaltata'])]
subdf.shape
# Out:
# (154, 24)

# %%
subdf.head()
# Out:
#   sample_id  N_percent_dm  P_percent_dm  K_percent_dm  Ca_percent_dm  \
# 0      RRL1           NaN     -0.738864      1.354181      -0.773433
# 1      RRL2     -1.025087     -1.365154      2.697114      -0.334574
# 2      RRL3           NaN     -0.864122      2.101377      -1.172396
# 3      RRL4           NaN     -1.114638      2.091279       0.064390
# 4      RRL5      0.281845     -0.112574      0.849319      -0.035351
#
#    Mg_percent_dm  Na_percent_dm  S_percent_dm  Zn_ppm_dm  Mn_ppm_dm  ...  \
# 0      -0.655431      -0.111002      1.499691   0.762893   0.880423  ...
# 1      -0.494460      -0.111002      0.352922  -0.464294   1.977760  ...
# 2      -0.762745      10.411944     -0.650501  -0.327940   2.333235  ...
# 3      -0.494460      -0.111002      0.209576  -0.737003   3.963785  ...
# 4       0.149425      -0.111002      0.352922   0.762893   2.626888  ...
#
#    site_id  collect_date        V1        V2   species       PC1       PC2  \
# 0      RRL     6/25/2021  0.753244  0.246756  exaltata  0.194769  0.048276
# 1      RRL     6/25/2021  0.708412  0.291588  exaltata  0.154924  0.071277
# 2      RRL     6/25/2021  0.778046  0.221954  exaltata   0.18775  0.035009
# 3      RRL     6/25/2021  0.720367  0.279633  exaltata  0.167167  0.046053
# 4      RRL     6/25/2021  0.572487  0.427513  exaltata  0.099801    0.0898
#
#         PC3       PC4       PC5
# 0  -0.02388 -0.017138 -0.039842
# 1  0.000923  -0.02583  0.005592
# 2 -0.016006 -0.012529 -0.011169
# 3 -0.032754 -0.016192 -0.028988
# 4  0.000613 -0.004979  0.017524
#
# [5 rows x 24 columns]

# %%
nutrients
# Out:
# Index(['N_percent_dm', 'P_percent_dm', 'K_percent_dm', 'Ca_percent_dm',
#        'Mg_percent_dm', 'Na_percent_dm', 'S_percent_dm', 'Zn_ppm_dm',
#        'Mn_ppm_dm', 'Fe_ppm_dm', 'Cu_ppm_dm', 'B_ppm_dm', 'Al_ppm_dm'],
#       dtype='object')

# %% [markdown]
# ### Plant Nutrients Excluding Nitrogen via Dropping Column

# %%
X = subdf[nutrients].drop(['N_percent_dm'], axis = 1)

pca = PCA(n_components=2)
components = pca.fit_transform(X)

fig = px.scatter(components, x=0, y=1, color=subdf['species'])
fig.update_layout(
    title = "Plant Nutrients by Species PCA Excluding Nitrogen",
    xaxis_title="PC1 " + str(round(100*pca.explained_variance_ratio_[0], 1)) + '%',
    yaxis_title="PC2 " + str(round(100*pca.explained_variance_ratio_[1], 1)) + '%')
fig.show()
# Out:
# <div>                            <div id="f5558ec4-6e6b-4ec2-9529-23ebaf3a0d4a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f
marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"syriaca","orientation":"v","showlegend":true,"x":[4.849168300628662,-5.561485290527344,-6.649074077606201,5.672362804412842,-5.301391124725342,-2.8833024501800537,-4.923600673675537,-4.748455047607422,-5.185644626617432,-5.429289817810059,-6.063827037811279,-8.493647575378418,-9.419910430908203,-0.4960379898548126,-1.638578176498413,-8.286444664001465,-5.085431098937988,-7.28342866897583,-9.51049518585205,-10.756964683532715,-9.133983612060547,2.9602715969085693,7.710843086242676,2.064054012298584,-6.693396091461182,-7.2325849533081055,-11.15008544921875,-3.6604745388031006,1.4464240074157715,3.1952078342437744,4.2589616775512695,4.6190290451049805,5.137172222137451,3.2994980812072754,8.637470245361328,7.928635597229004,7.8944783210754395,3.373318910598755,1.948840618133545,3.40938138961792,4.553857326507568,5.550666809082031,5.760496616363525,4.638345718383789,4.997724533081055,2.4838380813598633,3.1409518718719482,4.2414631843566895,2.510096788406372,-7.299628734588623,-3.8201868534088135,-3.0500802993774414,-3.1207706928253174,-3.387593984603882,1.6198097467422485,-8.413483619689941,-4.591163158416748,-4.325137615203857,0.863307535648346,6.79263162612915,-1.4123189449310303,-2.2361531257629395,-2.915590286254883,-0.25878432393074036,-0.3998944163322449,-7.408136367797852,0.5957423448562622,-10.326169967651367,-1.0364725589752197,-0.47952592372894287,-1.1724345684051514,-1.4511102437973022,-2.584969997406006,-0.6453767418861389,-1.285727620124817,-4.07472038269043,-1.992349624633789,-0.21026106178760529,-9.129264831542969,-9.909181594848633,-8.661612510681152,-1.4504022598266602,-1.4937686920166016,-3.9327549934387207,-5.441022872924805,-3.9572129249572754,-5.401190757751465,-6.0706562995910645,-9.47507381439209,-9.455042839050293,-9.097810745239258,12.784954071044922,-4.506539344787598,-5.685893535 ...

# %% [markdown]
# ## Perform PERMANOVA comparing Syriaca and Exaltata

# %%
X = (subdf[nutrients]).astype(float)

# %%
Y = pd.get_dummies(subdf['species'])
Y
# Out:
#      exaltata  syriaca
# 1        True    False
# 4        True    False
# 5        True    False
# 7        True    False
# 9        True    False
# ..        ...      ...
# 152     False     True
# 153     False     True
# 154      True    False
# 155     False     True
# 157     False     True
#
# [135 rows x 2 columns]

# %%
# Fit the MANOVA model
manova = MANOVA(X, Y)
manova_results = manova.mv_test()

print(manova_results)
# Out:
#                   Multivariate linear model
# ==============================================================
#
# --------------------------------------------------------------
#            x0           Value   Num DF  Den DF  F Value Pr > F
# --------------------------------------------------------------
#           Wilks' lambda 0.3288 13.0000 121.0000 19.0012 0.0000
#          Pillai's trace 0.6712 13.0000 121.0000 19.0012 0.0000
#  Hotelling-Lawley trace 2.0415 13.0000 121.0000 19.0012 0.0000
#     Roy's greatest root 2.0415 13.0000 121.0000 19.0012 0.0000
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#            x1           Value   Num DF  Den DF  F Value Pr > F
# --------------------------------------------------------------
#           Wilks' lambda 0.6162 13.0000 121.0000  5.7962 0.0000
#          Pillai's trace 0.3838 13.0000 121.0000  5.7962 0.0000
#  Hotelling-Lawley trace 0.6227 13.0000 121.0000  5.7962 0.0000
#     Roy's greatest root 0.6227 13.0000 121.0000  5.7962 0.0000
# ==============================================================
