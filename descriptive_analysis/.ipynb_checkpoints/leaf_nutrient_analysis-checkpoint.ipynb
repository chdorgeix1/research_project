# %%
import pandas as pd
import numpy as np
import sqlite3
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
import statsmodels
import statsmodels.api as sm
from statsmodels.multivariate.manova import MANOVA

from useful_functions import *

# %%
tables_to_join = ["tPlantNutrients", "tSample", "tPlantDNA"]
common_column = "sample_id"
full_df = import_all_data(tables_to_join, common_column)
full_df.shape
# Out:
# (158, 26)

# %%
#drop duplicate columns
df = full_df
df = df.T.drop_duplicates().T
df.shape
# Out:
# (158, 24)

# %%
nutrients = df.columns
nutrients = nutrients.drop(['sample_id', 'site_id', 'collect_date', 'V1','V2','PC1','PC2','PC3','PC4','PC5', 'species'])

# %%
nutrients
# Out:
# Index(['N_percent_dm', 'P_percent_dm', 'K_percent_dm', 'Ca_percent_dm',
#        'Mg_percent_dm', 'Na_percent_dm', 'S_percent_dm', 'Zn_ppm_dm',
#        'Mn_ppm_dm', 'Fe_ppm_dm', 'Cu_ppm_dm', 'B_ppm_dm', 'Al_ppm_dm'],
#       dtype='object')

# %% [markdown]
# ## Boxplots of Plant Nutrients by Site

# %%
for i in nutrients:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='site_id', y=i, data=df)
    plt.title(i + ' by Site')
    plt.xlabel('Site')
    plt.ylabel(i)
    plt.show()

# %% [markdown]
# ## Boxplot of Plant Nutrients by Plant Species

# %%
subdf = df[df["species"].isin(['syriaca', 'exaltata'])]
subdf.shape
# Out:
# (154, 24)

# %%
for i in nutrients:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='species', y=i, data=subdf)
    plt.title(i + ' by Species')
    plt.xlabel('Species')
    plt.ylabel(i)
    plt.show()

# %% [markdown]
# ## T-Test between Syriaca and Exaltata Plant Nutrients

# %% [markdown]
# ### With NaN included

# %%
def Average(lst):
    return sum(lst) / len(lst)

# %%
for nutrient in nutrients:
    df1 = df[["species",nutrient]]

    s = list(df1.loc[df1["species"].eq("syriaca")][nutrient].to_numpy())
    e = list(df1.loc[df1["species"].eq("exaltata")][nutrient].to_numpy())
    
    if stats.ttest_ind(s,e)[1] < 0.05:
        print(nutrient)
        print(f'Syriaca Mean {Average(s)}')
        print(f'Exaltata Mean {Average(e)}')
        print(stats.ttest_ind(s,e))
        print('')
# Out:
# P_percent_dm
# Syriaca Mean 0.2867307692307693
# Exaltata Mean 0.22520000000000004
# TtestResult(statistic=4.796172888363872, pvalue=3.8243033406987164e-06, df=152.0)
#
# K_percent_dm
# Syriaca Mean 2.4263461538461533
# Exaltata Mean 3.1409999999999996
# TtestResult(statistic=-4.403936788898745, pvalue=1.9949786527992162e-05, df=152.0)
#
# Ca_percent_dm
# Syriaca Mean 1.35375
# Exaltata Mean 0.9289999999999998
# TtestResult(statistic=5.393687284707425, pvalue=2.5911551607587784e-07, df=152.0)
#
# Mg_percent_dm
# Syriaca Mean 0.45894230769230787
# Exaltata Mean 0.31720000000000004
# TtestResult(statistic=4.646357681125192, pvalue=7.26852912479309e-06, df=152.0)
#
# Mn_ppm_dm
# Syriaca Mean 125.45192307692308
# Exaltata Mean 262.8
# TtestResult(statistic=-7.039003992152551, pvalue=6.224938760482542e-11, df=152.0)
#
# Fe_ppm_dm
# Syriaca Mean 54.50961538461539
# Exaltata Mean 69.18
# TtestResult(statistic=-3.626280710039793, pvalue=0.00039182512263944927, df=152.0)
#
# Cu_ppm_dm
# Syriaca Mean 7.086538461538462
# Exaltata Mean 5.82
# TtestResult(statistic=3.582192497409442, pvalue=0.0004580978666721831, df=152.0)
#
# B_ppm_dm
# Syriaca Mean 20.259615384615383
# Exaltata Mean 31.1
# TtestResult(statistic=-8.286087415626408, pvalue=5.688665001621679e-14, df=152.0)
#
# Al_ppm_dm
# Syriaca Mean 19.384615384615383
# Exaltata Mean 31.84
# TtestResult(statistic=-4.543708179612693, pvalue=1.1196367087663768e-05, df=152.0)

# %% [markdown]
# ### After dropping NaN

# %%
df = df.dropna()

# %%
for nutrient in nutrients:
    df1 = df[["species",nutrient]]

    s = list(df1.loc[df1["species"].eq("syriaca")][nutrient].to_numpy())
    e = list(df1.loc[df1["species"].eq("exaltata")][nutrient].to_numpy())
    
    if stats.ttest_ind(s,e)[1] < 0.05:
        print(nutrient)
        print(f'Syriaca Mean {Average(s)}')
        print(f'Exaltata Mean {Average(e)}')
        print(stats.ttest_ind(s,e))
        print('')
# Out:
# N_percent_dm
# Syriaca Mean 2.728252427184466
# Exaltata Mean 3.1921875
# TtestResult(statistic=-4.146365136118009, pvalue=5.981679139135237e-05, df=133.0)
#
# P_percent_dm
# Syriaca Mean 0.2876699029126214
# Exaltata Mean 0.2340625
# TtestResult(statistic=3.3812372462574474, pvalue=0.0009477432778971179, df=133.0)
#
# K_percent_dm
# Syriaca Mean 2.4402912621359216
# Exaltata Mean 2.970625
# TtestResult(statistic=-2.7643034708096463, pvalue=0.006514515868904237, df=133.0)
#
# Ca_percent_dm
# Syriaca Mean 1.3544660194174756
# Exaltata Mean 0.9131249999999999
# TtestResult(statistic=4.662372355577227, pvalue=7.5078894455094e-06, df=133.0)
#
# Mg_percent_dm
# Syriaca Mean 0.459611650485437
# Exaltata Mean 0.30062500000000003
# TtestResult(statistic=4.244462256078231, pvalue=4.082428402372664e-05, df=133.0)
#
# Mn_ppm_dm
# Syriaca Mean 125.32038834951456
# Exaltata Mean 254.09375
# TtestResult(statistic=-6.16778151418913, pvalue=7.760541874242566e-09, df=133.0)
#
# Cu_ppm_dm
# Syriaca Mean 7.097087378640777
# Exaltata Mean 5.21875
# TtestResult(statistic=5.146762750849059, pvalue=9.303607960987236e-07, df=133.0)
#
# B_ppm_dm
# Syriaca Mean 20.33009708737864
# Exaltata Mean 28.59375
# TtestResult(statistic=-5.799621967819237, pvalue=4.606200913970748e-08, df=133.0)
#
# Al_ppm_dm
# Syriaca Mean 19.271844660194176
# Exaltata Mean 29.59375
# TtestResult(statistic=-3.634908854114073, pvalue=0.0003962384684369796, df=133.0)
# C:\Users\15404\anaconda3.1\envs\research_env\Lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %% [markdown]
# ## Data Setup For PCA

# %%
newdf = full_df
newdf = newdf.T.drop_duplicates().T
newdf = newdf.dropna()
newdf[nutrients] = StandardScaler().fit_transform(newdf[nutrients])

# %%
newdf.head()
# Out:
#   sample_id  N_percent_dm  P_percent_dm  K_percent_dm  Ca_percent_dm  \
# 1      RRL2     -1.025087     -1.423013      2.835118      -0.408278
# 4      RRL5      0.281845     -0.195032      0.956613      -0.110073
# 5      RRL6      0.728954     -1.054619     -0.028833      -1.044448
# 7      RRL9      0.952508     -1.177417      0.669191      -1.203490
# 9     RRL11      0.763347     -0.686225     -0.018568      -1.223371
#
#    Mg_percent_dm  Na_percent_dm  S_percent_dm  Zn_ppm_dm  Mn_ppm_dm  ...  \
# 1      -0.521357      -0.086066      0.325776  -0.459718   2.307150  ...
# 4       0.093867      -0.086066      0.325776   0.747782   3.030048  ...
# 5       0.401478      -0.086066      0.183771  -0.325551   1.455162  ...
# 7      -0.623894      -0.086066      1.177805  -0.862218   2.763264  ...
# 9      -0.623894      -0.086066      0.467781   0.345282   2.384603  ...
#
#    site_id  collect_date        V1        V2   species       PC1       PC2  \
# 1      RRL     6/25/2021  0.708412  0.291588  exaltata  0.154924  0.071277
# 4      RRL     6/25/2021  0.572487  0.427513  exaltata  0.099801    0.0898
# 5      RRL     6/25/2021  0.653961  0.346039  exaltata   0.12861  0.076955
# 7      RRL     6/25/2021  0.581366  0.418634  exaltata  0.097719  0.094733
# 9      RRL     6/25/2021  0.584173  0.415827  exaltata  0.106894  0.088742
#
#         PC3       PC4       PC5
# 1  0.000923  -0.02583  0.005592
# 4  0.000613 -0.004979  0.017524
# 5  0.020429 -0.053479   0.01559
# 7  -0.00656  0.012822 -0.022248
# 9  0.007519 -0.007988  0.002289
#
# [5 rows x 24 columns]

# %% [markdown]
# ## PCA of Plant Nutrient by Site

# %%
X = newdf[nutrients]

pca = PCA(n_components=2)
components = pca.fit_transform(X)

fig = px.scatter(components, x=0, y=1, color=newdf['site_id'])
fig.update_layout(
    title = "Plant Nutrients by Site PCA",
    xaxis_title="PC1 " + str(round(100*pca.explained_variance_ratio_[0], 1)) + '%',
    yaxis_title="PC2 " + str(round(100*pca.explained_variance_ratio_[1], 1)) + '%')
fig.show()
# Out:
# <div>                            <div id="df92871d-c849-4814-a33a-9c91511523b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df92871d-c849-4814-a33a-9c91511523b4")) {                    Plotly.newPlot(                        "df92871d-c849-4814-a33a-9c91511523b4",                        [{"hovertemplate":"color=RRL<br>0=%{x}<br>1=%{y}<extra></extra>","legendgroup":"RRL","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"RRL","orientation":"v","showlegend":true,"x":[1.2952241213749616,1.4147949631763506,0.4640310136683779,2.0520988782346814,1.5332502135231656,0.26687895439894954,0.20588911290602863,-0.027398204104925,-0.20970573879777213,0.06095452097362146],"xaxis":"x","y":[2.0293450168296725,1.0915582076467327,1.8632185530281815,2.0535914507039497,1.6461804595111034,0.6520229725244244,0.1844888960071719,0.3410185101299435,1.4472710149653174,-0.25925879356312637],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=FRW<br>0=%{x}<br>1=%{y}<extra></extra>","legendgroup":"FRW","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"FRW","orientation":"v","showlegend":true,"x":[0.7278272924805549,0.5266590598420923,-0.0008572055795383554,0.04790594592900558,0.6278318883976352,1.2089329116612455,1.2729938834686738,1.4482987489981387,0.9725236071258362,-1.1078121145647015,0.33336344122156736],"xaxis":"x","y":[0.022847007201525795,-1.5209113444777733,-2.8641619314173683,-0.2520838307997343,-2.169579676281611,-2.4118881286212037,-2.4871853270805984,-3.333997679255011,-3.069919015354183,-1.2124292684178724,-2.0996522627209906],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=MMP<br>0=%{x}<br>1=%{y}<extra></extra>","legendgroup":"MMP","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"MMP","orientation":"v","showlegend":true,"x":[-2.8797431404038414,-1.714345813054632,-2.4292456040523898,-2.574445296138225,-1.8109290957852535,-2.3101513533174436,-3.348632953670006,-1.6703930544115346,-1.5840761488739978,-2.3795162604635043,-0.5010761720077426,-0.3799218813888012,-0.5000081922408938,-1.6616084476249282,-0.8695157740257092,-1.1888564324945452,-0.5088936333134694],"xaxis":"x","y":[0.39329369338759185,-0.8222790520554112,0.4366953909161779,0.19208878107397673,0.2628948942899518,0.5257515098331269,-0.08081543716682801,-0.6091171771662104,-1.2614710883375633,-0.022265501810471166,-0.37865329862374597,0.27624300799918833,-0.3668066954728626,0.7759389717562863,0.7437440044689789,-0.6438852264415201,-1.0605300809575269],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=CMB<br>0=%{x}<br>1=%{y}<extra></extra>","legendgroup":"CMB","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"CMB","orientation":"v","showlegend":true,"x":[-1.6667268231484478,1.7229429650591912,3.0242819293237333,3.042406139200516,3.571652660373787,1.1757433676902205,1.5118483163403216,2.43006411111429,3.30559832035857,0.8863744040929912,0.3537375261219476,0.31114399379379387,0.7288729723931171,0.40913169730990107,0.5402714005632057,0.819943449831924,-0.04606357491291609,0.8228171669930544,0.27046775214451796,0.35812188595325534,1.7303113113066237],"xaxis":"x","y":[1.2391523814299392,-1.2898595704528928,-0.7986749625791658,-0.5593317478999407,0.15926049295765196,-0.35397496601117506,0.7371793085078613,1.4354983310330431,2.371755430159497,-0.11107497652515669,-0.2292040582503676,-0.012922147161109761,0.07403465325170691,0.2280961446572174,0.10126907011958056,-0.08755134165965113,0.408648251611503,-0.2776825997818265,-0.28483206358691604,0.4944810135538733,-1.2209887020571002],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=SLG<br>0=%{x}<br>1=%{y}<extra></extra>","legendgroup":"SLG","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","nam ...

# %% [markdown]
# ## TSNE of Plant Nutrients by Site

# %%
perplexity_value = 10 # Change this to your desired perplexity

tsne = TSNE(n_components=2, perplexity=perplexity_value, random_state=42)
tsne_transformed = tsne.fit_transform(newdf[nutrients])

fig = px.scatter(tsne_transformed, x=0, y=1, color=newdf['site_id'])
fig.update_layout(title = 'Plant Nutrients by Site TSNE Perplexity-Value =' + str(perplexity_value))
fig.show()
# Out:
# <div>                            <div id="959ed8b8-73be-4244-8aff-5001960950f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("959ed8b8-73be-4244-8aff-5001960950f6")) {                    Plotly.newPlot(                        "959ed8b8-73be-4244-8aff-5001960950f6",                        [{"hovertemplate":"color=RRL<br>0=%{x}<br>1=%{y}<extra></extra>","legendgroup":"RRL","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"RRL","orientation":"v","showlegend":true,"x":[5.89070463180542,0.3074279725551605,2.3546223640441895,1.1639249324798584,0.9339508414268494,6.547911167144775,6.819538593292236,5.384072780609131,3.5830698013305664,7.482290744781494],"xaxis":"x","y":[24.59249496459961,23.02634048461914,23.910898208618164,25.888080596923828,24.68953514099121,22.336788177490234,20.706867218017578,21.712055206298828,22.00937271118164,19.758296966552734],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=FRW<br>0=%{x}<br>1=%{y}<extra></extra>","legendgroup":"FRW","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"FRW","orientation":"v","showlegend":true,"x":[6.521958827972412,13.340394973754883,16.12984848022461,5.8923492431640625,15.25732707977295,18.543712615966797,19.352407455444336,20.464262008666992,18.06268882751465,10.315668106079102,14.62580680847168],"xaxis":"x","y":[1.274316668510437,-12.464324951171875,-13.924700736999512,0.01292248535901308,-12.205101013183594,-7.221714019775391,-12.584859848022461,-12.102896690368652,-12.600123405456543,-11.610676765441895,-13.239359855651855],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=MMP<br>0=%{x}<br>1=%{y}<extra></extra>","legendgroup":"MMP","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"MMP","orientation":"v","showlegend":true,"x":[-6.98280668258667,-10.178275108337402,-3.482553243637085,-4.088098049163818,-10.229023933410645,-8.61526870727539,-11.663782119750977,-9.219010353088379,-11.996663093566895,-7.8432512283325195,-1.1427720785140991,-6.745609283447266,-2.6513421535491943,-14.455689430236816,-10.129964828491211,-13.316478729248047,8.989018440246582],"xaxis":"x","y":[-21.197052001953125,-22.8892822265625,-10.407220840454102,-11.412825584411621,-21.02938461303711,-14.65727424621582,-16.795623779296875,-23.932437896728516,-23.35365104675293,-22.088565826416016,2.5147316455841064,16.443584442138672,1.074417233467102,-17.94853973388672,-19.406639099121094,-22.488910675048828,-8.741341590881348],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=CMB<br>0=%{x}<br>1=%{y}<extra></extra>","legendgroup":"CMB","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"CMB","orientation":"v","showlegend":true,"x":[-9.46104907989502,-2.467198133468628,-5.491027355194092,-4.332887172698975,-4.0747971534729,-0.016675647348165512,0.057331524789333344,-0.8263773918151855,-2.6930744647979736,1.8683862686157227,2.0519299507141113,4.443389415740967,4.667786121368408,4.615269184112549,6.513125896453857,1.743472695350647,6.906300067901611,0.7120311856269836,2.5783777236938477,2.970158100128174,-2.16009259223938],"xaxis":"x","y":[-5.44225549697876,8.13008975982666,10.018132209777832,10.306526184082031,11.328511238098145,7.070611000061035,16.118408203125,15.400537490844727,15.44002914428711,6.2910261154174805,3.3094868659973145,5.011658191680908,7.014153003692627,8.69321060180664,8.373729705810547,9.093905448913574,6.814822673797607,4.774630069732666,5.276141166687012,7.065614223480225,6.839215278625488],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=SLG<br>0=%{x}<br>1=%{y}<extra></extra>","legendgroup":"SLG","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"SLG","orientation":"v","showlegend":true,"x":[-6.653753757476807,-9.23421573638916,- ...

# %% [markdown]
# ## PCA of Plant Nutrients by Species

# %%
subdf = newdf[newdf["species"].isin(['syriaca', 'exaltata'])]
subdf.shape
# Out:
# (135, 24)

# %%
X = subdf[nutrients]

pca = PCA(n_components=2)
components = pca.fit_transform(X)

fig = px.scatter(components, x=0, y=1, color=subdf['species'])
fig.update_layout(
    title = "Plant Nutrients by Species PCA",
    xaxis_title="PC1 " + str(round(100*pca.explained_variance_ratio_[0], 1)) + '%',
    yaxis_title="PC2 " + str(round(100*pca.explained_variance_ratio_[1], 1)) + '%')
fig.show()
# Out:
# <div>                            <div id="ea4f3892-a727-46d0-9c08-171917ec5d8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea4f3892-a727-46d0-9c08-171917ec5d8f")) {                    Plotly.newPlot(                        "ea4f3892-a727-46d0-9c08-171917ec5d8f",                        [{"hovertemplate":"color=exaltata<br>0=%{x}<br>1=%{y}<extra></extra>","legendgroup":"exaltata","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"exaltata","orientation":"v","showlegend":true,"x":[1.3300200900791883,1.4477884912851604,0.5148834166638931,2.099558811515335,1.580609976427062,0.27410016870632803,0.20741367370447247,-0.021448972787009368,-0.17557297013531914,0.043923965026334166,-0.8098495955371785,-1.276035645483483,1.0255147611376898,1.6784950878788485,0.6791863591774562,-0.33612095152315175,0.5965557710545969,1.0753052336383822,2.0941647109759325,1.954770784600406,1.4704840738365208,0.5260519375035088,2.413158608678061,0.6519381045476303,1.4106519892406466,1.0833242322738217,0.5170713020880792,1.0494981089839122,2.580462285099893,1.501351073298466,1.7092670573743696,1.4493987291434969],"xaxis":"x","y":[2.1192071821955794,0.9916932272866564,1.8208936722483184,2.0356842690338004,1.5537759579111268,0.7583237739082613,0.25557625797445377,0.39026186392166845,1.4441377468456347,-0.10824122458477177,1.3914314065401234,2.2212563098838136,2.086827837687848,2.8862015126127143,1.609704622494057,1.3662653322860954,1.3976317577384516,0.7746699016921508,2.3727321910025676,1.2269447892165228,1.309717287864907,0.8401105407374216,0.4915911483283024,0.4876661425728567,1.7292019046430613,1.139990996032026,1.5262172610943832,1.8336854711879311,-0.4971004148719844,-0.19123222041023588,-0.364610480234284,4.381463725758711],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=syriaca<br>0=%{x}<br>1=%{y}<extra></extra>","legendgroup":"syriaca","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"syriaca","orientation":"v","showlegend":true,"x":[0.7333002296909379,0.4828770523309809,-0.07791109872276976,0.04386119493306744,0.5672077235077787,1.1559907890944903,1.2149428239941187,1.3753123272737058,0.8952922194895804,-1.1438766163744292,0.2792192626449698,-2.859026249300457,-1.7242032712838689,-2.4097102736942846,-2.555741176405373,-1.792594726020117,-2.2949132358934756,-3.347312403087464,-1.6684706391973954,-1.6037314035515116,-2.365677243029966,-0.4859469489228428,-0.3548865681131155,-0.495938793703257,-1.641342367811855,-0.8416142914036271,-1.1908651917195037,-0.535954788368032,-1.6369887541709243,1.7109446625849154,3.0181911264258106,3.051020674704069,3.5931854316874685,1.1827224363154343,1.5470791931949526,2.4788491867290245,3.376843963648384,0.8953785983096236,0.35542092735110825,0.322407667249675,0.7475388703633847,0.43225598371946383,0.5600639647133053,0.8380063691986774,-0.023284583601907105,0.8222366389929097,0.27841050206793233,0.3826379708491123,1.7186539593644623,-1.784125496077615,-2.3990799583933837,-2.0134229175092475,-2.049678320274325,-3.0825537962933955,-0.007044929935262504,-0.035489504876800214,-0.9498787175770447,-2.3307981047629838,-0.3900251253706248,0.5800191881678555,-1.3030576174314144,-1.342483278514419,-0.748181622127793,-0.495474526825539,-1.621737422970621,-0.6804266687504206,0.2813865774092444,3.3771387050931874,1.7813527218104328,1.9960825165064644,2.499358161348338,1.47473358408218,0.8606642499674861,1.3607299881717971,0.40631727349775704,-0.34753541351803496,0.1658116959865991,0.8970248331808063,1.8498859594892902,2.7755733217552345,0.20528360614023855,0.3106830913189784,-0.7106584251015651,-3.2277550599936498,-1.5788624253839791,-2.4756059820486622,-1.6727405381454397,-1.8633979295209668,-1.8460661062918169,-1.3966312837483827,-3.187452784153 ...

# %% [markdown]
# ## TSNE of Plant Nutrients by Species

# %%
perplexity_value = 4 # Change this to your desired perplexity

tsne = TSNE(n_components=2, perplexity=perplexity_value, random_state=42)
tsne_transformed = tsne.fit_transform(subdf[nutrients])

fig = px.scatter(tsne_transformed, x=0, y=1, color=subdf['species'])
fig.update_layout(title = 'Plant Nutrients by Species TSNE Perplexity-Value =' + str(perplexity_value))
fig.show()
# Out:
# <div>                            <div id="474f3478-2401-4664-b2a6-b385660750a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("474f3478-2401-4664-b2a6-b385660750a8")) {                    Plotly.newPlot(                        "474f3478-2401-4664-b2a6-b385660750a8",                        [{"hovertemplate":"color=exaltata<br>0=%{x}<br>1=%{y}<extra></extra>","legendgroup":"exaltata","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"exaltata","orientation":"v","showlegend":true,"x":[35.19916915893555,28.590585708618164,29.58550262451172,31.750396728515625,30.295516967773438,32.88994598388672,31.09834098815918,31.535261154174805,31.126155853271484,30.291584014892578,15.679335594177246,-17.63397216796875,26.98643684387207,34.560516357421875,20.27940559387207,18.95702362060547,23.017221450805664,28.068193435668945,29.14019203186035,23.831262588500977,26.5148983001709,26.922578811645508,15.661686897277832,14.53836727142334,24.796367645263672,26.5916690826416,24.373092651367188,22.869333267211914,15.574934005737305,16.70794105529785,18.555513381958008,23.182708740234375],"xaxis":"x","y":[-15.63206958770752,-4.309353828430176,-7.795268535614014,-5.694152355194092,-5.886909008026123,-15.847285270690918,-17.369537353515625,-15.034738540649414,-13.028690338134766,-18.567241668701172,2.1837871074676514,31.343673706054688,-2.182640314102173,-5.352080821990967,2.605191707611084,2.343384265899658,-36.087459564208984,-40.42683792114258,-35.4884147644043,-41.61357879638672,-35.07589340209961,-38.84108352661133,-35.007659912109375,-34.24335479736328,-36.021121978759766,-33.09623336791992,-39.34809875488281,-39.3970947265625,-22.91343879699707,-22.825057983398438,-22.365636825561523,1.31504487991333],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=syriaca<br>0=%{x}<br>1=%{y}<extra></extra>","legendgroup":"syriaca","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"syriaca","orientation":"v","showlegend":true,"x":[4.230892658233643,-41.99919891357422,-45.96774673461914,2.8828585147857666,-43.89115524291992,-35.94263458251953,-45.79159927368164,-46.03927230834961,-45.506813049316406,-32.55903625488281,-43.89702224731445,9.234918594360352,13.913509368896484,18.254741668701172,18.799705505371094,12.176729202270508,2.273270845413208,-0.2628120183944702,14.023721694946289,15.891063690185547,10.499024391174316,-10.949198722839355,14.428557395935059,-13.000308990478516,-3.4608426094055176,10.440399169921875,16.40230941772461,-30.610774993896484,-18.172351837158203,-13.437576293945312,-17.785491943359375,-16.504091262817383,-16.10978126525879,-10.832279205322266,11.105700492858887,10.344664573669434,9.236719131469727,-7.968933582305908,-5.850616455078125,-4.497387409210205,-4.317368030548096,-3.5268523693084717,-1.468298316001892,-6.991893768310547,0.032426998019218445,-7.585249900817871,-8.99264144897461,-7.242040157318115,-13.602958679199219,7.8536601066589355,0.6968140006065369,-4.289470672607422,-3.2668235301971436,0.7680606245994568,-2.5698273181915283,-47.13223648071289,-3.2930843830108643,-1.1335927248001099,0.5157579779624939,20.670644760131836,-7.19955587387085,-8.721598625183105,-10.143098831176758,-0.39356154203414917,-9.879941940307617,-45.021278381347656,-32.911834716796875,-15.041914939880371,-37.357215881347656,-37.222564697265625,-41.148223876953125,-38.39223861694336,-42.304931640625,-42.52578353881836,-41.73286819458008,-31.28968620300293,-41.965675354003906,-5.1133551597595215,-11.377504348754883,-13.65008544921875,-10.110543251037598,-3.262716770172119,-2.0137600898742676,6.496004581451416,5.558263301849365,6.0550761222839355,4.723947525024414,5.532652854919434,11.48939037322998,10.468878746032715,7.917832851409912,28.215360641479492,-3.96325182914733 ...

# %% [markdown]
# ## Perform PERMANOVA comparing Syriaca and Exaltata

# %%
X = (subdf[nutrients]).astype(float)

# %%
Y = pd.get_dummies(subdf['species'])
Y
# Out:
#      exaltata  syriaca
# 1        True    False
# 4        True    False
# 5        True    False
# 7        True    False
# 9        True    False
# ..        ...      ...
# 152     False     True
# 153     False     True
# 154      True    False
# 155     False     True
# 157     False     True
#
# [135 rows x 2 columns]

# %%
# Fit the MANOVA model
manova = MANOVA(X, Y)
manova_results = manova.mv_test()

print(manova_results)
# Out:
#                   Multivariate linear model
# ==============================================================
#
# --------------------------------------------------------------
#            x0           Value   Num DF  Den DF  F Value Pr > F
# --------------------------------------------------------------
#           Wilks' lambda 0.3288 13.0000 121.0000 19.0012 0.0000
#          Pillai's trace 0.6712 13.0000 121.0000 19.0012 0.0000
#  Hotelling-Lawley trace 2.0415 13.0000 121.0000 19.0012 0.0000
#     Roy's greatest root 2.0415 13.0000 121.0000 19.0012 0.0000
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#            x1           Value   Num DF  Den DF  F Value Pr > F
# --------------------------------------------------------------
#           Wilks' lambda 0.6162 13.0000 121.0000  5.7962 0.0000
#          Pillai's trace 0.3838 13.0000 121.0000  5.7962 0.0000
#  Hotelling-Lawley trace 0.6227 13.0000 121.0000  5.7962 0.0000
#     Roy's greatest root 0.6227 13.0000 121.0000  5.7962 0.0000
# ==============================================================
