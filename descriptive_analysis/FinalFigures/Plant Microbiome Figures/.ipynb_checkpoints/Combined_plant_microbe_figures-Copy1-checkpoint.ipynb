# %%
import numpy as np
import sqlite3
import plotly.express as px
import pandas as pd
import sqlite3
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
import statsmodels
import statsmodels.api as sm
from statsmodels.multivariate.manova import MANOVA
from useful_functions_2 import *
from pdf2image import convert_from_path
from sklearn.manifold import TSNE

# %%
tables_to_join = ["tPlantMicrobeSpecies", "tSample", "tPlantDNA"]
common_column = "sample_id"
full_df = import_all_data(tables_to_join, common_column)
full_df.shape
# Out:
# (158899, 15)

# %%
full_df = full_df.T.drop_duplicates().T

# %%
full_df.head()
# Out:
#   sample_id                                             genera  \
# 0      RRL1  Bacteria|Actinobacteria|Actinobacteria|Coryneb...
# 1      RRL1  Bacteria|Firmicutes|Bacilli|Lactobacillales|La...
# 2      RRL1  Bacteria|Bacteroidetes|Chitinophagia|Chitinoph...
# 3      RRL1  Bacteria|Actinobacteria|Actinobacteria|Coryneb...
# 4      RRL1  Bacteria|Actinobacteria|Actinobacteria|Propion...
#
#   relative_abundance site_id collect_date        V1        V2   species  \
# 0            0.63429     RRL    6/25/2021  0.753244  0.246756  exaltata
# 1            0.06341     RRL    6/25/2021  0.753244  0.246756  exaltata
# 2            0.04896     RRL    6/25/2021  0.753244  0.246756  exaltata
# 3            0.03646     RRL    6/25/2021  0.753244  0.246756  exaltata
# 4            0.02978     RRL    6/25/2021  0.753244  0.246756  exaltata
#
#         PC1       PC2      PC3       PC4       PC5
# 0  0.194769  0.048276 -0.02388 -0.017138 -0.039842
# 1  0.194769  0.048276 -0.02388 -0.017138 -0.039842
# 2  0.194769  0.048276 -0.02388 -0.017138 -0.039842
# 3  0.194769  0.048276 -0.02388 -0.017138 -0.039842
# 4  0.194769  0.048276 -0.02388 -0.017138 -0.039842

# %%
df = full_df.copy()

# %%
subdf = df.copy()

# %%
subdf.head()
# Out:
#   sample_id                                             genera  \
# 0      RRL1  Bacteria|Actinobacteria|Actinobacteria|Coryneb...
# 1      RRL1  Bacteria|Firmicutes|Bacilli|Lactobacillales|La...
# 2      RRL1  Bacteria|Bacteroidetes|Chitinophagia|Chitinoph...
# 3      RRL1  Bacteria|Actinobacteria|Actinobacteria|Coryneb...
# 4      RRL1  Bacteria|Actinobacteria|Actinobacteria|Propion...
#
#   relative_abundance site_id collect_date        V1        V2   species  \
# 0            0.63429     RRL    6/25/2021  0.753244  0.246756  exaltata
# 1            0.06341     RRL    6/25/2021  0.753244  0.246756  exaltata
# 2            0.04896     RRL    6/25/2021  0.753244  0.246756  exaltata
# 3            0.03646     RRL    6/25/2021  0.753244  0.246756  exaltata
# 4            0.02978     RRL    6/25/2021  0.753244  0.246756  exaltata
#
#         PC1       PC2      PC3       PC4       PC5
# 0  0.194769  0.048276 -0.02388 -0.017138 -0.039842
# 1  0.194769  0.048276 -0.02388 -0.017138 -0.039842
# 2  0.194769  0.048276 -0.02388 -0.017138 -0.039842
# 3  0.194769  0.048276 -0.02388 -0.017138 -0.039842
# 4  0.194769  0.048276 -0.02388 -0.017138 -0.039842

# %%
origin_pivoted_df = subdf.pivot(index=['sample_id', 'site_id', 'species', 'V2'], columns='genera', values='relative_abundance')
origin_pivoted_df.shape

# row_sum = origin_pivoted_df.sum(axis=1)

origin_pivoted_df = origin_pivoted_df.reset_index()

genera_col = origin_pivoted_df.columns
genera_col = genera_col.drop(['sample_id','site_id', 'species', 'V2'])

# sub_pivot = origin_pivoted_df[genera_col].astype(float)

# for row in range(sub_pivot.shape[0]):
#     sub_pivot.loc[row] = sub_pivot.loc[row]/row_sum[row]

# new_sum = sub_pivot.sum(axis=1)
# new_sum

# origin_pivoted_df[genera_col] = sub_pivot

# origin_pivoted_df.head()

# row_sum = origin_pivoted_df[genera_col].sum(axis=1)
# print(row_sum)

# %%
origin_pivoted_df = origin_pivoted_df.reset_index()
origin_pivoted_df.head()
# Out:
# genera  index sample_id site_id  species        V2  \
# 0           0     CMB10     CMB  syriaca  0.999777
# 1           1     CMB11     CMB  syriaca  1.000000
# 2           2     CMB13     CMB  syriaca  0.989131
# 3           3     CMB14     CMB  syriaca  0.999992
# 4           4     CMB15     CMB  syriaca  0.998548
#
# genera Archaea|Euryarchaeota|Halobacteria|Halobacteriales|Haloarculaceae|Halapricum|Halapricum salinum  \
# 0                                                 0.03005
# 1                                                 0.02488
# 2                                                     NaN
# 3                                                 0.02786
# 4                                                 0.00774
#
# genera Archaea|Euryarchaeota|Halobacteria|Halobacteriales|Halobacteriaceae|Halorussus|Halorussus rarus  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#
# genera Archaea|Euryarchaeota|Halobacteria|Halobacteriales|Halococcaceae|Halococcus|Halococcus sediminicola  \
# 0                                                   0.016
# 1                                                 0.00903
# 2                                                     NaN
# 3                                                 0.00968
# 4                                                 0.00315
#
# genera Archaea|Euryarchaeota|Halobacteria|Haloferacales|Haloferacaceae|Halobellus|Halobellus sp. Atlit-31R  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#
# genera Archaea|Euryarchaeota|Halobacteria|Haloferacales|Haloferacaceae|Haloferax|Haloferax alexandrinus  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#
# genera  ...  \
# 0       ...
# 1       ...
# 2       ...
# 3       ...
# 4       ...
#
# genera Eukaryota|Chlorophyta|Mamiellophyceae|Mamiellales|Mamiellaceae|Micromonas|Micromonas commoda  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#
# genera Eukaryota|Chlorophyta|Mamiellophyceae|Mamiellales|Mamiellaceae|Micromonas|Micromonas pusilla  \
# 0                                                     NaN
# 1                                                 0.00011
# 2                                                 0.00792
# 3                                                 0.00013
# 4                                                     NaN
#
# genera Eukaryota|Chlorophyta|Trebouxiophyceae|Chlorellales|Chlorellaceae|Chlorella|Chlorella sorokiniana  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#
# genera Eukaryota|Chlorophyta|Trebouxiophyceae|Chlorellales|Chlorellaceae|Chlorella|Chlorella sp. A99  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#
# genera Eukaryota|Chlorophyta|Trebouxiophyceae|Chlorellales|Chlorellaceae|Prototheca|Prototheca cutis  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#
# genera Eukaryota|Chlorophyta|Trebouxiophyceae|Chlorellales|Chlorellaceae|Prototheca|Prototheca stagnorum  \
# 0                                                     NaN
# 1                                                 0.00016
# 2                                                     NaN
# 3                                                 0.00016
# 4                                                     NaN
#
# genera Eukaryota|Mucoromycota|Mortierellomycetes|Mortierellales|Mortierellaceae|Mortierella|Mortierella verticillata  \
# 0                                                 0.00011
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#
# genera Eukaryota|Mucoromycota|Mucoromycetes|Mucorales|Mucoraceae|Mucor|Mucor circinelloides  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#
# genera Eukaryota|Mucoromycota|Mucoromycetes|Mucorales|Rhizopodaceae|Rhizopus|Rhizopus microsporus  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#
# genera Eukaryota|Mucoromycota|Umbelopsidomycetes|Umbelopsidales|Umbelopsidaceae|Umbelopsis|Umbelopsis isabellina
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#
# [5 rows x 8753 columns]

# %%
genera_col
# Out:
# Index(['Archaea|Euryarchaeota|Halobacteria|Halobacteriales|Haloarculaceae|Halapricum|Halapricum salinum',
#        'Archaea|Euryarchaeota|Halobacteria|Halobacteriales|Halobacteriaceae|Halorussus|Halorussus rarus',
#        'Archaea|Euryarchaeota|Halobacteria|Halobacteriales|Halococcaceae|Halococcus|Halococcus sediminicola',
#        'Archaea|Euryarchaeota|Halobacteria|Haloferacales|Haloferacaceae|Halobellus|Halobellus sp. Atlit-31R',
#        'Archaea|Euryarchaeota|Halobacteria|Haloferacales|Haloferacaceae|Haloferax|Haloferax alexandrinus',
#        'Archaea|Euryarchaeota|Halobacteria|Haloferacales|Haloferacaceae|Halogeometricum|Halogeometricum borinquense',
#        'Archaea|Euryarchaeota|Halobacteria|Haloferacales|Halorubraceae|Halolamina|Halolamina pelagica',
#        'Archaea|Euryarchaeota|Halobacteria|Haloferacales|Halorubraceae|Halorubrum|Halorubrum sp. Ib24',
#        'Archaea|Euryarchaeota|Halobacteria|Haloferacales|Halorubraceae|Halorubrum|Halorubrum sp. J07HR59',
#        'Archaea|Euryarchaeota|Halobacteria|Natrialbales|Natrialbaceae|Saliphagus|Saliphagus sp. LR7',
#        ...
#        'Eukaryota|Chlorophyta|Mamiellophyceae|Mamiellales|Mamiellaceae|Micromonas|Micromonas commoda',
#        'Eukaryota|Chlorophyta|Mamiellophyceae|Mamiellales|Mamiellaceae|Micromonas|Micromonas pusilla',
#        'Eukaryota|Chlorophyta|Trebouxiophyceae|Chlorellales|Chlorellaceae|Chlorella|Chlorella sorokiniana',
#        'Eukaryota|Chlorophyta|Trebouxiophyceae|Chlorellales|Chlorellaceae|Chlorella|Chlorella sp. A99',
#        'Eukaryota|Chlorophyta|Trebouxiophyceae|Chlorellales|Chlorellaceae|Prototheca|Prototheca cutis',
#        'Eukaryota|Chlorophyta|Trebouxiophyceae|Chlorellales|Chlorellaceae|Prototheca|Prototheca stagnorum',
#        'Eukaryota|Mucoromycota|Mortierellomycetes|Mortierellales|Mortierellaceae|Mortierella|Mortierella verticillata',
#        'Eukaryota|Mucoromycota|Mucoromycetes|Mucorales|Mucoraceae|Mucor|Mucor circinelloides',
#        'Eukaryota|Mucoromycota|Mucoromycetes|Mucorales|Rhizopodaceae|Rhizopus|Rhizopus microsporus',
#        'Eukaryota|Mucoromycota|Umbelopsidomycetes|Umbelopsidales|Umbelopsidaceae|Umbelopsis|Umbelopsis isabellina'],
#       dtype='object', name='genera', length=8748)

# %%
origin_pivoted_df[genera_col] = origin_pivoted_df[genera_col].astype(float)
sum_row = origin_pivoted_df[genera_col].sum()

# %%
sum_row = origin_pivoted_df[genera_col].sum()

abundant_genera = sum_row.nlargest(100)

select_columns = (abundant_genera.index).tolist()
select_columns.insert(0, 'V2')
select_columns.insert(0, 'sample_id')
select_columns.insert(0, 'site_id')
select_columns.insert(0, 'species')

origin_pivoted_df = origin_pivoted_df[select_columns]

origin_pivoted_df.head()
# Out:
# genera  species site_id sample_id        V2  \
# 0       syriaca     CMB     CMB10  0.999777
# 1       syriaca     CMB     CMB11  1.000000
# 2       syriaca     CMB     CMB13  0.989131
# 3       syriaca     CMB     CMB14  0.999992
# 4       syriaca     CMB     CMB15  0.998548
#
# genera  Bacteria|Bacteroidetes|Chitinophagia|Chitinophagales|Chitinophagaceae|Asinibacterium|Asinibacterium sp. OR53  \
# 0                                                 0.39443
# 1                                                 0.33576
# 2                                                     NaN
# 3                                                 0.07035
# 4                                                 0.06095
#
# genera  Bacteria|Actinobacteria|Actinobacteria|Corynebacteriales|Corynebacteriaceae|Corynebacterium|Corynebacterium sp. Marseille-P4329  \
# 0                                                 0.00752
# 1                                                 0.01661
# 2                                                     NaN
# 3                                                 0.00451
# 4                                                 0.00558
#
# genera  Bacteria|Firmicutes|Clostridia|Clostridiales|Clostridiaceae|Clostridium|Clostridium cochlearium  \
# 0                                                 0.82605
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                 0.17083
#
# genera  Bacteria|Proteobacteria|Gammaproteobacteria|Pseudomonadales|Pseudomonadaceae|Pseudomonas|Pseudomonas coleopterorum  \
# 0                                                 0.07404
# 1                                                 0.32286
# 2                                                23.92728
# 3                                                 0.08001
# 4                                                 1.01661
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Sphingomonadales|Sphingomonadaceae|Sphingomonas|Sphingomonas sp. PP-CE-3A-406  \
# 0                                                 0.37967
# 1                                                 0.15129
# 2                                                 8.23424
# 3                                                 0.08672
# 4                                                 0.05373
#
# genera  Bacteria|Proteobacteria|Gammaproteobacteria|Pseudomonadales|Pseudomonadaceae|Pseudomonas|Pseudomonas rhizosphaerae  \
# 0                                                 0.12554
# 1                                                 0.30714
# 2                                                     NaN
# 3                                                 0.08784
# 4                                                 0.77762
#
# genera  ...  \
# 0       ...
# 1       ...
# 2       ...
# 3       ...
# 4       ...
#
# genera  Bacteria|Proteobacteria|Gammaproteobacteria|Pseudomonadales|Pseudomonadaceae|Pseudomonas|Pseudomonas sp. NC02  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                 0.08643
#
# genera  Bacteria|Proteobacteria|Betaproteobacteria|Burkholderiales|Burkholderiaceae|Paucimonas|Paucimonas lemoignei  \
# 0                                                 0.01097
# 1                                                 0.02562
# 2                                                     NaN
# 3                                                     NaN
# 4                                                 0.14895
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Bradyrhizobiaceae|Bradyrhizobium|Bradyrhizobium sp. CCGE-LA001  \
# 0                                                 0.02544
# 1                                                 0.02449
# 2                                                     NaN
# 3                                                     NaN
# 4                                                 0.00276
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Sphingomonadales|Sphingomonadaceae|Sphingomonas|Sphingomonas phyllosphaerae  \
# 0                                                 0.09341
# 1                                                 0.02571
# 2                                                     NaN
# 3                                                 0.02041
# 4                                                 0.00639
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Sphingomonadales|Sphingomonadaceae|Sphingomonas|Sphingomonas jaspsi  \
# 0                                                 0.10671
# 1                                                 0.05197
# 2                                                     NaN
# 3                                                     NaN
# 4                                                 0.05810
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Bradyrhizobiaceae|Bradyrhizobium|Bradyrhizobium icense  \
# 0                                                 0.01869
# 1                                                 0.02392
# 2                                                     NaN
# 3                                                 0.00546
# 4                                                 0.00215
#
# genera  Bacteria|Proteobacteria|Gammaproteobacteria|Pseudomonadales|Pseudomonadaceae|Pseudomonas|Pseudomonas sp. A214  \
# 0                                                     NaN
# 1                                                 0.01408
# 2                                                     NaN
# 3                                                 0.00675
# 4                                                 0.08803
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Bradyrhizobiaceae|Bradyrhizobium|Bradyrhizobium lablabi  \
# 0                                                 0.03034
# 1                                                 0.01864
# 2                                                     NaN
# 3                                                 0.00366
# 4                                                 0.00186
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Bradyrhizobiaceae|Bradyrhizobium|Bradyrhizobium erythrophlei  \
# 0                                                 0.07816
# 1                                                 0.00361
# 2                                                     NaN
# 3                                                 0.00186
# 4                                                 0.00134
#
# genera  Eukaryota|Ascomycota|Dothideomycetes|Dothideales|Saccotheciaceae|Aureobasidium|Aureobasidium sp. FSWF8-4
# 0                                                 0.01418
# 1                                                 0.01152
# 2                                                 1.28368
# 3                                                 0.01117
# 4                                                 0.00467
#
# [5 rows x 104 columns]

# %%
opdf = origin_pivoted_df.copy()
opdf = opdf.fillna(0)
microbe_cols = opdf.columns.drop(['species', 'site_id', 'sample_id', 'V2'])
#microbe_cols = abundant_genera.index

# %%
#opdf[microbe_cols] = StandardScaler().fit_transform(opdf[microbe_cols])

# %%
opdf.head()
# Out:
# genera  species site_id sample_id        V2  \
# 0       syriaca     CMB     CMB10  0.999777
# 1       syriaca     CMB     CMB11  1.000000
# 2       syriaca     CMB     CMB13  0.989131
# 3       syriaca     CMB     CMB14  0.999992
# 4       syriaca     CMB     CMB15  0.998548
#
# genera  Bacteria|Bacteroidetes|Chitinophagia|Chitinophagales|Chitinophagaceae|Asinibacterium|Asinibacterium sp. OR53  \
# 0                                                 0.39443
# 1                                                 0.33576
# 2                                                 0.00000
# 3                                                 0.07035
# 4                                                 0.06095
#
# genera  Bacteria|Actinobacteria|Actinobacteria|Corynebacteriales|Corynebacteriaceae|Corynebacterium|Corynebacterium sp. Marseille-P4329  \
# 0                                                 0.00752
# 1                                                 0.01661
# 2                                                 0.00000
# 3                                                 0.00451
# 4                                                 0.00558
#
# genera  Bacteria|Firmicutes|Clostridia|Clostridiales|Clostridiaceae|Clostridium|Clostridium cochlearium  \
# 0                                                 0.82605
# 1                                                 0.00000
# 2                                                 0.00000
# 3                                                 0.00000
# 4                                                 0.17083
#
# genera  Bacteria|Proteobacteria|Gammaproteobacteria|Pseudomonadales|Pseudomonadaceae|Pseudomonas|Pseudomonas coleopterorum  \
# 0                                                 0.07404
# 1                                                 0.32286
# 2                                                23.92728
# 3                                                 0.08001
# 4                                                 1.01661
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Sphingomonadales|Sphingomonadaceae|Sphingomonas|Sphingomonas sp. PP-CE-3A-406  \
# 0                                                 0.37967
# 1                                                 0.15129
# 2                                                 8.23424
# 3                                                 0.08672
# 4                                                 0.05373
#
# genera  Bacteria|Proteobacteria|Gammaproteobacteria|Pseudomonadales|Pseudomonadaceae|Pseudomonas|Pseudomonas rhizosphaerae  \
# 0                                                 0.12554
# 1                                                 0.30714
# 2                                                 0.00000
# 3                                                 0.08784
# 4                                                 0.77762
#
# genera  ...  \
# 0       ...
# 1       ...
# 2       ...
# 3       ...
# 4       ...
#
# genera  Bacteria|Proteobacteria|Gammaproteobacteria|Pseudomonadales|Pseudomonadaceae|Pseudomonas|Pseudomonas sp. NC02  \
# 0                                                 0.00000
# 1                                                 0.00000
# 2                                                 0.00000
# 3                                                 0.00000
# 4                                                 0.08643
#
# genera  Bacteria|Proteobacteria|Betaproteobacteria|Burkholderiales|Burkholderiaceae|Paucimonas|Paucimonas lemoignei  \
# 0                                                 0.01097
# 1                                                 0.02562
# 2                                                 0.00000
# 3                                                 0.00000
# 4                                                 0.14895
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Bradyrhizobiaceae|Bradyrhizobium|Bradyrhizobium sp. CCGE-LA001  \
# 0                                                 0.02544
# 1                                                 0.02449
# 2                                                 0.00000
# 3                                                 0.00000
# 4                                                 0.00276
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Sphingomonadales|Sphingomonadaceae|Sphingomonas|Sphingomonas phyllosphaerae  \
# 0                                                 0.09341
# 1                                                 0.02571
# 2                                                 0.00000
# 3                                                 0.02041
# 4                                                 0.00639
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Sphingomonadales|Sphingomonadaceae|Sphingomonas|Sphingomonas jaspsi  \
# 0                                                 0.10671
# 1                                                 0.05197
# 2                                                 0.00000
# 3                                                 0.00000
# 4                                                 0.05810
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Bradyrhizobiaceae|Bradyrhizobium|Bradyrhizobium icense  \
# 0                                                 0.01869
# 1                                                 0.02392
# 2                                                 0.00000
# 3                                                 0.00546
# 4                                                 0.00215
#
# genera  Bacteria|Proteobacteria|Gammaproteobacteria|Pseudomonadales|Pseudomonadaceae|Pseudomonas|Pseudomonas sp. A214  \
# 0                                                 0.00000
# 1                                                 0.01408
# 2                                                 0.00000
# 3                                                 0.00675
# 4                                                 0.08803
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Bradyrhizobiaceae|Bradyrhizobium|Bradyrhizobium lablabi  \
# 0                                                 0.03034
# 1                                                 0.01864
# 2                                                 0.00000
# 3                                                 0.00366
# 4                                                 0.00186
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Bradyrhizobiaceae|Bradyrhizobium|Bradyrhizobium erythrophlei  \
# 0                                                 0.07816
# 1                                                 0.00361
# 2                                                 0.00000
# 3                                                 0.00186
# 4                                                 0.00134
#
# genera  Eukaryota|Ascomycota|Dothideomycetes|Dothideales|Saccotheciaceae|Aureobasidium|Aureobasidium sp. FSWF8-4
# 0                                                 0.01418
# 1                                                 0.01152
# 2                                                 1.28368
# 3                                                 0.01117
# 4                                                 0.00467
#
# [5 rows x 104 columns]

# %%
opdf = opdf[opdf["species"].isin(['syriaca','exaltata'])]
opdf.shape
# Out:
# (156, 104)

# %%
df = opdf

# %%
site_list = df['site_id']

df['BGR'] = site_list

df['BGR'].replace({'CMB': 1, 'FRW': 1, 'LFS': 1, 'LM': 0, 'MMP': 1, 'MKP': 2,
                    'PNR': 2, 'PTW': 0, 'RF': 2, 'RGT': 0, 'RRL': 0, 'SGC': 0, 'SLG': 1,'HR': 3}, inplace=True) #
df = df[df["BGR"].isin([0,1,2,3])]

df['BGR'] = df['BGR'].replace([0], 'Wintergreen')
df['BGR'] = df['BGR'].replace([1], 'Cole Mountain')
df['BGR'] = df['BGR'].replace([2], 'Blacksburg')
df['BGR'] = df['BGR'].replace([3], 'HR')

# %%
# df = df[df["site_id"].isin(['SGC', 'LFS', 'RF', 'RGT', 'LM', 'PTW', 'MKP', 'HR'])]
# df.shape

# %%
site_list = df['site_id']

df['run_id'] = site_list

df['run_id'].replace({'RRL': 1, 'FRW': 1, 'MMP': 1, 'PNR': 1, 'CMB': 1, 'SLG': 1,
                    'SGC': 2, 'LFS': 2, 'RF': 2, 'RGT': 2, 'LM': 2, 'PTW': 2, 'MKP': 2,'HR': 2, 'GH': 2}, inplace=True) #

df = df[df["run_id"].isin([1, 2])]
df.shape
# Out:
# (156, 106)

# %%
df.head()
# Out:
# genera  species site_id sample_id        V2  \
# 0       syriaca     CMB     CMB10  0.999777
# 1       syriaca     CMB     CMB11  1.000000
# 2       syriaca     CMB     CMB13  0.989131
# 3       syriaca     CMB     CMB14  0.999992
# 4       syriaca     CMB     CMB15  0.998548
#
# genera  Bacteria|Bacteroidetes|Chitinophagia|Chitinophagales|Chitinophagaceae|Asinibacterium|Asinibacterium sp. OR53  \
# 0                                                 0.39443
# 1                                                 0.33576
# 2                                                 0.00000
# 3                                                 0.07035
# 4                                                 0.06095
#
# genera  Bacteria|Actinobacteria|Actinobacteria|Corynebacteriales|Corynebacteriaceae|Corynebacterium|Corynebacterium sp. Marseille-P4329  \
# 0                                                 0.00752
# 1                                                 0.01661
# 2                                                 0.00000
# 3                                                 0.00451
# 4                                                 0.00558
#
# genera  Bacteria|Firmicutes|Clostridia|Clostridiales|Clostridiaceae|Clostridium|Clostridium cochlearium  \
# 0                                                 0.82605
# 1                                                 0.00000
# 2                                                 0.00000
# 3                                                 0.00000
# 4                                                 0.17083
#
# genera  Bacteria|Proteobacteria|Gammaproteobacteria|Pseudomonadales|Pseudomonadaceae|Pseudomonas|Pseudomonas coleopterorum  \
# 0                                                 0.07404
# 1                                                 0.32286
# 2                                                23.92728
# 3                                                 0.08001
# 4                                                 1.01661
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Sphingomonadales|Sphingomonadaceae|Sphingomonas|Sphingomonas sp. PP-CE-3A-406  \
# 0                                                 0.37967
# 1                                                 0.15129
# 2                                                 8.23424
# 3                                                 0.08672
# 4                                                 0.05373
#
# genera  Bacteria|Proteobacteria|Gammaproteobacteria|Pseudomonadales|Pseudomonadaceae|Pseudomonas|Pseudomonas rhizosphaerae  \
# 0                                                 0.12554
# 1                                                 0.30714
# 2                                                 0.00000
# 3                                                 0.08784
# 4                                                 0.77762
#
# genera  ...  \
# 0       ...
# 1       ...
# 2       ...
# 3       ...
# 4       ...
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Bradyrhizobiaceae|Bradyrhizobium|Bradyrhizobium sp. CCGE-LA001  \
# 0                                                 0.02544
# 1                                                 0.02449
# 2                                                 0.00000
# 3                                                 0.00000
# 4                                                 0.00276
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Sphingomonadales|Sphingomonadaceae|Sphingomonas|Sphingomonas phyllosphaerae  \
# 0                                                 0.09341
# 1                                                 0.02571
# 2                                                 0.00000
# 3                                                 0.02041
# 4                                                 0.00639
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Sphingomonadales|Sphingomonadaceae|Sphingomonas|Sphingomonas jaspsi  \
# 0                                                 0.10671
# 1                                                 0.05197
# 2                                                 0.00000
# 3                                                 0.00000
# 4                                                 0.05810
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Bradyrhizobiaceae|Bradyrhizobium|Bradyrhizobium icense  \
# 0                                                 0.01869
# 1                                                 0.02392
# 2                                                 0.00000
# 3                                                 0.00546
# 4                                                 0.00215
#
# genera  Bacteria|Proteobacteria|Gammaproteobacteria|Pseudomonadales|Pseudomonadaceae|Pseudomonas|Pseudomonas sp. A214  \
# 0                                                 0.00000
# 1                                                 0.01408
# 2                                                 0.00000
# 3                                                 0.00675
# 4                                                 0.08803
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Bradyrhizobiaceae|Bradyrhizobium|Bradyrhizobium lablabi  \
# 0                                                 0.03034
# 1                                                 0.01864
# 2                                                 0.00000
# 3                                                 0.00366
# 4                                                 0.00186
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Bradyrhizobiaceae|Bradyrhizobium|Bradyrhizobium erythrophlei  \
# 0                                                 0.07816
# 1                                                 0.00361
# 2                                                 0.00000
# 3                                                 0.00186
# 4                                                 0.00134
#
# genera  Eukaryota|Ascomycota|Dothideomycetes|Dothideales|Saccotheciaceae|Aureobasidium|Aureobasidium sp. FSWF8-4  \
# 0                                                 0.01418
# 1                                                 0.01152
# 2                                                 1.28368
# 3                                                 0.01117
# 4                                                 0.00467
#
# genera            BGR  run_id
# 0       Cole Mountain       1
# 1       Cole Mountain       1
# 2       Cole Mountain       1
# 3       Cole Mountain       1
# 4       Cole Mountain       1
#
# [5 rows x 106 columns]

# %%
df.shape
# Out:
# (156, 106)

# %%
site_list = ['RRL', 'FRW', 'MMP', 'PNR', 'CMB', 'SLG', 'RF', 'LFS', 'PTW', 'LM', 'MKP', 'RGT']

# Predefined set of colors
unique_colors = ['red', 'green', 'blue', 'orange', 'purple', 'cyan', 'pink', 'brown', 'gray', 'olive', 'lime', 'teal']

# Create a dictionary with list elements as keys and corresponding colors as values
site_color_dict = dict(zip(site_list, unique_colors))

print(site_color_dict)
# Out:
# {'RRL': 'red', 'FRW': 'green', 'MMP': 'blue', 'PNR': 'orange', 'CMB': 'purple', 'SLG': 'cyan', 'RF': 'pink', 'LFS': 'brown', 'PTW': 'gray', 'LM': 'olive', 'MKP': 'lime', 'RGT': 'teal'}

# %%
df.shape
# Out:
# (156, 106)

# %%
X = df[microbe_cols]

pca = PCA(n_components=2)
principal_components = pca.fit_transform(X)

# %%
drop_indexs = []
for i in enumerate(principal_components):
    if i[1][0] > 3:
        print(i)
        drop_indexs.append(i[0])
    if i[1][1] > 3:
        print(i)
        drop_indexs.append(i[0])
# Out:
# (2, array([26.98632517,  0.48538669]))
# (31, array([-0.83507403, 18.59039407]))

# %%
df = df.drop(index=drop_indexs)
df.head()
# Out:
# genera  index  species site_id sample_id        V2  \
# 0           0  syriaca     CMB     CMB10  0.999777
# 1           1  syriaca     CMB     CMB11  1.000000
# 3           3  syriaca     CMB     CMB14  0.999992
# 4           4  syriaca     CMB     CMB15  0.998548
# 5           5  syriaca     CMB     CMB16  0.999243
#
# genera  Bacteria|Bacteroidetes|Chitinophagia|Chitinophagales|Chitinophagaceae|Asinibacterium|Asinibacterium sp. OR53  \
# 0                                                 0.39443
# 1                                                 0.33576
# 3                                                 0.07035
# 4                                                 0.06095
# 5                                                 0.27048
#
# genera  Bacteria|Actinobacteria|Actinobacteria|Corynebacteriales|Corynebacteriaceae|Corynebacterium|Corynebacterium sp. Marseille-P4329  \
# 0                                                 0.00752
# 1                                                 0.01661
# 3                                                 0.00451
# 4                                                 0.00558
# 5                                                 0.01727
#
# genera  Bacteria|Firmicutes|Clostridia|Clostridiales|Clostridiaceae|Clostridium|Clostridium cochlearium  \
# 0                                                 0.82605
# 1                                                 0.00000
# 3                                                 0.00000
# 4                                                 0.17083
# 5                                                 0.00000
#
# genera  Bacteria|Proteobacteria|Gammaproteobacteria|Pseudomonadales|Pseudomonadaceae|Pseudomonas|Pseudomonas coleopterorum  \
# 0                                                 0.07404
# 1                                                 0.32286
# 3                                                 0.08001
# 4                                                 1.01661
# 5                                                 0.10680
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Sphingomonadales|Sphingomonadaceae|Sphingomonas|Sphingomonas sp. PP-CE-3A-406  \
# 0                                                 0.37967
# 1                                                 0.15129
# 3                                                 0.08672
# 4                                                 0.05373
# 5                                                 0.37108
#
# genera  ...  \
# 0       ...
# 1       ...
# 3       ...
# 4       ...
# 5       ...
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Bradyrhizobiaceae|Bradyrhizobium|Bradyrhizobium sp. CCGE-LA001  \
# 0                                                 0.02544
# 1                                                 0.02449
# 3                                                 0.00000
# 4                                                 0.00276
# 5                                                 0.00801
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Sphingomonadales|Sphingomonadaceae|Sphingomonas|Sphingomonas phyllosphaerae  \
# 0                                                 0.09341
# 1                                                 0.02571
# 3                                                 0.02041
# 4                                                 0.00639
# 5                                                 0.11389
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Sphingomonadales|Sphingomonadaceae|Sphingomonas|Sphingomonas jaspsi  \
# 0                                                 0.10671
# 1                                                 0.05197
# 3                                                 0.00000
# 4                                                 0.05810
# 5                                                 0.15826
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Bradyrhizobiaceae|Bradyrhizobium|Bradyrhizobium icense  \
# 0                                                 0.01869
# 1                                                 0.02392
# 3                                                 0.00546
# 4                                                 0.00215
# 5                                                 0.01220
#
# genera  Bacteria|Proteobacteria|Gammaproteobacteria|Pseudomonadales|Pseudomonadaceae|Pseudomonas|Pseudomonas sp. A214  \
# 0                                                 0.00000
# 1                                                 0.01408
# 3                                                 0.00675
# 4                                                 0.08803
# 5                                                 0.00000
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Bradyrhizobiaceae|Bradyrhizobium|Bradyrhizobium lablabi  \
# 0                                                 0.03034
# 1                                                 0.01864
# 3                                                 0.00366
# 4                                                 0.00186
# 5                                                 0.02305
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Bradyrhizobiaceae|Bradyrhizobium|Bradyrhizobium erythrophlei  \
# 0                                                 0.07816
# 1                                                 0.00361
# 3                                                 0.00186
# 4                                                 0.00134
# 5                                                 0.01282
#
# genera  Eukaryota|Ascomycota|Dothideomycetes|Dothideales|Saccotheciaceae|Aureobasidium|Aureobasidium sp. FSWF8-4  \
# 0                                                 0.01418
# 1                                                 0.01152
# 3                                                 0.01117
# 4                                                 0.00467
# 5                                                 0.01861
#
# genera            BGR  run_id
# 0       Cole Mountain       1
# 1       Cole Mountain       1
# 3       Cole Mountain       1
# 4       Cole Mountain       1
# 5       Cole Mountain       1
#
# [5 rows x 107 columns]

# %%
X = df[microbe_cols]

pca = PCA(n_components=2)
principal_components = pca.fit_transform(X)



for graph_type in ['site_id', 'species', 'BGR', 'run_id']:
    if graph_type == 'site_id':
        colors = site_color_dict
    elif graph_type == 'species':
        colors = {'syriaca': 'yellow', 'exaltata': 'green'}
    elif graph_type == 'BGR':
        colors = {'Wintergreen': 'green', 'Cole Mountain': 'blue', 'Blacksburg': 'black'}
    else:
        colors = {1: 'red', 2: 'blue'}
    
    fig, ax = plt.subplots()

    for key, color in colors.items():
        mask = (df[graph_type] == key)
        ax.scatter(
            principal_components[mask, 0],
            principal_components[mask, 1],
            c=color,
            label= key
        )
    
    ax.set_xlabel("PC1 " + str(round(100*pca.explained_variance_ratio_[0], 1)) + '%')
    ax.set_ylabel("PC2 " + str(round(100*pca.explained_variance_ratio_[1], 1)) + '%')
    ax.set_title('PCA with ' + graph_type + ' Colored Points')
    ax.legend()
    plt.show()
    if graph_type == 'site_id':
        ax.set_title('PCA of Field Sites and Leaf Microbiome')
        fig1 = fig
    elif graph_type == 'species':
        ax.set_title('PCA of Plant Species and Leaf Microbiome')
        fig2 = fig
    elif graph_type == 'BGR':
        ax.set_title('PCA of Broad Geographic Region and Leaf Microbiome')
        fig3 = fig
    else:
        ax.set_title('PCA of Run Id and Leaf Microbiome')
        fig3 = fig

# %%
perplexity_value = 15 # Change this to your desired perplexity

tsne = TSNE(n_components=2, perplexity=perplexity_value, random_state=42)
tsne_transformed = tsne.fit_transform(df[microbe_cols])


for graph_type in ['site_id', 'species', 'BGR', 'run_id']:
    if graph_type == 'site_id':
        colors = site_color_dict
    elif graph_type == 'species':
        colors = {'syriaca': 'yellow', 'exaltata': 'green'}
    elif graph_type == 'BGR':
        colors = {'Wintergreen': 'green', 'Cole Mountain': 'blue', 'Blacksburg': 'black'}
    else:
        colors = {1: 'red', 2: 'blue'}
    fig, ax = plt.subplots()

    for key, color in colors.items():
        mask = (df[graph_type] == key)
        ax.scatter(
            tsne_transformed[mask, 0],
            tsne_transformed[mask, 1],
            c=color,
            label= key
        )
    
    ax.set_xlabel("TSNE1")
    ax.set_ylabel("TSNE2")
    ax.set_title('TSNE with ' + graph_type + ' Colored Points')
    ax.legend()
    plt.show()

    if graph_type == 'site_id':
        ax.set_title('TSNE of Field Site and Leaf Microbiome, P.V. = ' + str(perplexity_value))
        fig4 = fig
    elif graph_type == 'species':
        ax.set_title('TSNE of Species and Leaf Microbiome, P.V. = ' + str(perplexity_value))
        fig5 = fig
    elif graph_type == 'BGR':
        ax.set_title('TSNE of Broad Geographic Region and Leaf Microbiome')
        fig3 = fig
    else:
        ax.set_title('TSNE of Run Id and Leaf Microbiome')
        fig3 = fig

# %%
### Save Figures and Create Final Figure
fig1.savefig('leaf_microbe_site_id.pdf', dpi=300, bbox_inches='tight')
fig2.savefig('leaf_microbe_species.pdf', dpi=300, bbox_inches='tight')
fig3.savefig('leaf_microbe_bgr.pdf', dpi=300, bbox_inches='tight')
fig4.savefig('leaf_microbe_site_id_tsne.pdf', dpi=300, bbox_inches='tight')
fig5.savefig('leaf_microbe_species_tsne.pdf', dpi=300, bbox_inches='tight')
fig6.savefig('leaf_microbe_bgr_tsne.pdf', dpi=300, bbox_inches='tight')

img1=convert_from_path('leaf_microbe_site_id.pdf')
img2=convert_from_path('leaf_microbe_bgr.pdf')
img3=convert_from_path('leaf_microbe_species.pdf')
img4=convert_from_path('leaf_microbe_site_id_tsne.pdf')
img5=convert_from_path('leaf_microbe_bgr_tsne.pdf')
img6=convert_from_path('leaf_microbe_species_tsne.pdf')



fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(6, 8))

ax[0][0].imshow(img1[0])
ax[0][1].imshow(img4[0])
ax[1][0].imshow(img2[0])
ax[1][1].imshow(img5[0])
ax[2][0].imshow(img3[0])
ax[2][1].imshow(img6[0])

# plot 2 subplots
ax[0][0].axis('off')
ax[0][1].axis('off')
ax[1][0].axis('off')
ax[1][1].axis('off')
ax[2][0].axis('off')
ax[2][1].axis('off')

ax[0][0].annotate("A", xy=(-0.05, 0.9), xycoords="axes fraction")
ax[1][0].annotate("C", xy=(-0.05, 0.9), xycoords="axes fraction")
ax[0][1].annotate("B", xy=(-0.05, 0.9), xycoords="axes fraction")
ax[1][1].annotate("D", xy=(-0.05, 0.9), xycoords="axes fraction")
ax[2][0].annotate("E", xy=(-0.05, 0.9), xycoords="axes fraction")
ax[2][1].annotate("F", xy=(-0.05, 0.9), xycoords="axes fraction")


fig.suptitle('Leaf Microbes can be grouped by Plant Host Species')
plt.tight_layout()
plt.show()

fig.savefig('combined_leaf_microbes.pdf', bbox_inches='tight', dpi = 1000)

# %% [markdown]
# ### Using Top 50 most Abundant Genera, Syriaca and Exaltata were found to have statistically different microbial leaf communities

# %%
bardf = origin_pivoted_df.drop(['site_id', 'species', 'V2'], axis=1)
bardf.head()
# Out:
# genera sample_id  \
# 0          CMB10
# 1          CMB11
# 2          CMB13
# 3          CMB14
# 4          CMB15
#
# genera  Bacteria|Proteobacteria|Gammaproteobacteria|Pseudomonadales|Pseudomonadaceae|Pseudomonas  \
# 0                                                0.052890
# 1                                                0.351091
# 2                                                0.507485
# 3                                                0.219306
# 4                                                0.597191
#
# genera  Bacteria|Actinobacteria|Actinobacteria|Corynebacteriales|Corynebacteriaceae|Corynebacterium  \
# 0                                                0.000553
# 1                                                0.002246
# 2                                                     NaN
# 3                                                0.001425
# 4                                                0.000271
#
# genera  Bacteria|Bacteroidetes|Chitinophagia|Chitinophagales|Chitinophagaceae|Asinibacterium  \
# 0                                                0.030673
# 1                                                0.046866
# 2                                                     NaN
# 3                                                0.020080
# 4                                                0.002920
#
# genera  Bacteria|Firmicutes|Clostridia|Clostridiales|Clostridiaceae|Clostridium  \
# 0                                                0.063167
# 1                                                0.001847
# 2                                                     NaN
# 3                                                0.002951
# 4                                                0.008032
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Sphingomonadales|Sphingomonadaceae|Sphingomonas  \
# 0                                                0.342012
# 1                                                0.167292
# 2                                                0.386377
# 3                                                0.222773
# 4                                                0.077632
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Bradyrhizobiaceae|Bradyrhizobium  \
# 0                                                0.045831
# 1                                                0.051245
# 2                                                0.005194
# 3                                                0.020903
# 4                                                0.002494
#
# genera  Bacteria|Actinobacteria|Actinobacteria|Micrococcales|Microbacteriaceae|Microbacterium  \
# 0                                                0.026025
# 1                                                0.022263
# 2                                                0.004118
# 3                                                0.015966
# 4                                                0.008256
#
# genera  Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Methylobacteriaceae|Methylobacterium  \
# 0                                                0.008458
# 1                                                0.007511
# 2                                                     NaN
# 3                                                0.020184
# 4                                                0.001976
#
# genera  Bacteria|Bacteroidetes|Cytophagia|Cytophagales|Hymenobacteraceae|Hymenobacter  \
# 0                                                0.013746
# 1                                                0.005860
# 2                                                     NaN
# 3                                                0.022240
# 4                                                0.027218
#
# genera  Bacteria|Actinobacteria|Actinobacteria|Corynebacteriales|Dietziaceae|Dietzia
# 0                                                0.010404
# 1                                                0.010029
# 2                                                     NaN
# 3                                                0.005835
# 4                                                0.000415

# %%
bardf.shape
# Out:
# (155, 11)

# %%
import pandas as pd
import matplotlib.pyplot as plt

cumval=0
fig = plt.figure(figsize=(12,8))
for col in bardf.columns[~bardf.columns.isin(['sample_id'])]:
    plt.bar(bardf.sample_id, bardf[col], bottom=cumval, label = col)
    cumval = cumval+bardf[col]
    print(col)

_ = plt.xticks(rotation=30)
_ = plt.legend(fontsize=18)

leg = plt.legend(loc='upper center', bbox_to_anchor=(1.3, 1.05))
# Out:
# Bacteria|Proteobacteria|Gammaproteobacteria|Pseudomonadales|Pseudomonadaceae|Pseudomonas
# Bacteria|Actinobacteria|Actinobacteria|Corynebacteriales|Corynebacteriaceae|Corynebacterium
# Bacteria|Bacteroidetes|Chitinophagia|Chitinophagales|Chitinophagaceae|Asinibacterium
# Bacteria|Firmicutes|Clostridia|Clostridiales|Clostridiaceae|Clostridium
# Bacteria|Proteobacteria|Alphaproteobacteria|Sphingomonadales|Sphingomonadaceae|Sphingomonas
# Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Bradyrhizobiaceae|Bradyrhizobium
# Bacteria|Actinobacteria|Actinobacteria|Micrococcales|Microbacteriaceae|Microbacterium
# Bacteria|Proteobacteria|Alphaproteobacteria|Rhizobiales|Methylobacteriaceae|Methylobacterium
# Bacteria|Bacteroidetes|Cytophagia|Cytophagales|Hymenobacteraceae|Hymenobacter
# Bacteria|Actinobacteria|Actinobacteria|Corynebacteriales|Dietziaceae|Dietzia
