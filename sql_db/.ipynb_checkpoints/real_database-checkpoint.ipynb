# %%
import pandas as pd
import numpy as np
import sqlite3

# %% [markdown]
# # Create DB File and Connect

# %%
# Connect to the database. If it does not exist, it will be created
conn = sqlite3.connect('test3.db')
# Create a cursor object. This is how we interact with the database
curs = conn.cursor()


### IMPORTANT!!! ###
# By default, sqlite does not enforce foreign key constraints. 
# According to the documentation, this is for backwards compatibility. You have to turn them on yourself.
curs.execute('PRAGMA foreign_keys=ON;')

# %% [markdown]
# ## Define and Create TSample

# %%
# Define the tables

# If running this more than once, you'll need to drop the table before you can redefine it

curs.execute("DROP TABLE IF EXISTS tSample;")

sql = """
CREATE TABLE tSample (
    sample_id TEXT PRIMARY KEY,
    site_id TEXT,
    collect_date DATETIME
)
;"""
curs.execute(sql)

# %%
tsampledf = pd.read_csv('./csv_folder/sample.csv')

# %%
# INSERT INTO (column names) VALUES (values to insert)
# The : indicates parameter names.
# They do not need to be the same as the columns we are inserting into, but it helps keep the code clean.
# They are matched up in order. For example, if instead of :lat I called it :x, then :x would be inserted into
# the lat column, since lat is the second column in the list of column names.
sql = """
INSERT INTO tSample (sample_id, site_id, collect_date) VALUES (:sample_id, :site_id, :date)
;"""

# I'm going to loop over the dataframe such that each row will be returned as a dictionary.
# The keys for the dictionary will be the column names, and the values will be the values in the dataframe.
# I've ensured that the names in my dataframe match exactly the parameter names above - the way this works
# is that SQL will look for that key in the dictionary.  For example, since I have a parameter :loc_id, 
# it will look for a key in the dictionary called loc_id.





for row in tsampledf.to_dict(orient='records'):
    # Uncomment this to see the dictionaries
    #print(row)
    
    # The second input for curs.execute() are parameters
    curs.execute(sql, row)

# %%
sql = """
CREATE VIEW tSample AS 

SELECT *
;"""

pd.read_sql("SELECT * FROM tSample;", conn)
# Out:
#     sample_id site_id collect_date
# 0      BLDTT0     BLD    6/29/2020
# 1      BLDTT1     BLD    6/29/2020
# 2      BLDTT2     BLD    6/29/2020
# 3      BLDTT3     BLD    6/29/2020
# 4      BLDTT4     BLD    6/29/2020
# 5      BLDTT5     BLD    6/29/2020
# 6      BLDTT6     BLD    6/29/2020
# 7      BLDTT7     BLD    6/29/2020
# 8      BLDTT8     BLD    6/29/2020
# 9      BLDTT9     BLD    6/29/2020
# 10    BLDTT10     BLD    6/29/2020
# 11    BLDTT11     BLD    6/29/2020
# 12    BLDTT12     BLD    6/29/2020
# 13    BLDTT13     BLD    6/29/2020
# 14    BLDTT14     BLD    6/29/2020
# 15    BLDTT15     BLD    6/29/2020
# 16    BLDTT16     BLD    6/29/2020
# 17    BLDTT17     BLD    6/29/2020
# 18    BLDTT18     BLD    6/29/2020
# 19    BLDTT19     BLD    6/29/2020
# 20    BLDTT20     BLD    6/29/2020
# 21    BLDTT21     BLD    6/29/2020
# 22    BLDTT22     BLD    6/29/2020
# 23    BLDTT23     BLD    6/29/2020
# 24    BLDTT24     BLD    6/29/2020
# 25    BLDTT25     BLD    6/29/2020
# 26    BLDTT26     BLD    6/29/2020
# 27    BLDTT27     BLD    6/29/2020
# 28    BLDTT28     BLD    6/29/2020
# 29    BLDTT29     BLD    6/29/2020
# ..        ...     ...          ...
# 410      RF10      RF     7/6/2021
# 411      RF11      RF     7/6/2021
# 412      RF12      RF     7/6/2021
# 413      RF13      RF     7/6/2021
# 414      TCP1     TCP     7/6/2021
# 415      TCP2     TCP     7/6/2021
# 416      TCP3     TCP     7/6/2021
# 417      TCP4     TCP     7/6/2021
# 418      TCP5     TCP     7/6/2021
# 419      TCP6     TCP     7/6/2021
# 420      TCP7     TCP     7/6/2021
# 421      TCP8     TCP     7/6/2021
# 422      TCP9     TCP     7/6/2021
# 423     TCP10     TCP     7/6/2021
# 424      PNR1     PNR     7/5/2021
# 425      PNR2     PNR     7/5/2021
# 426      PNR3     PNR     7/5/2021
# 427      PNR4     PNR     7/5/2021
# 428      PNR5     PNR     7/5/2021
# 429      PNR6     PNR     7/5/2021
# 430      PNR7     PNR     7/5/2021
# 431      PNR8     PNR     7/5/2021
# 432      PNR9     PNR     7/5/2021
# 433     PNR10     PNR     7/5/2021
# 434     PNR11     PNR     7/5/2021
# 435     PNR12     PNR     7/5/2021
# 436     PNR13     PNR     7/5/2021
# 437     PNR14     PNR     7/5/2021
# 438     PNR15     PNR     7/5/2021
# 439     PNR16     PNR     7/5/2021
#
# [440 rows x 3 columns]

# %% [markdown]
# ## Define and Create TMorphology

# %%
tmorphdf = pd.read_csv('./csv_folder/plant_morphology.csv')
tmorphdf.shape
# Out:
# (493, 12)

# %%
tmorphdf = tmorphdf.rename(columns={'Ht(cm)': 'plant_ht', '# Leaves': 'num_leaves', 'Length LL (cm)': 'longest_leaf_cm',
                                     'Width LL (cm)': 'widest_leaf_cm', 'Stem Diameter (mm)': 'stem_diam_mm',
                                     '# Inflorescences': 'num_inflores', '# Flowers Per (x2)': 'num_flowers',
                                     'Herbivory': 'herbivory', 'Species': 'species'})
tmorphdf = tmorphdf.drop('date', axis= 1)
tmorphdf = tmorphdf.drop('site_id',  axis = 1)
tmorphdf.head()
# Out:
#   sample_id species  plant_ht num_leaves longest_leaf_cm  widest_leaf_cm  \
# 0    BLDTT0     NaN      93.3         22            16.5             7.3
# 1    BLDTT0     NaN       NaN        NaN             NaN             NaN
# 2    BLDTT1     NaN      70.7         14            15.4             7.1
# 3    BLDTT1     NaN       NaN        NaN             NaN             NaN
# 4    BLDTT2     NaN      83.4         18            15.6             7.4
#
#    stem_diam_mm num_inflores   num_flowers herbivory
# 0          10.5            5  46(1), 53(1)  1=5, 2=1
# 1           NaN          NaN           NaN       NaN
# 2           8.9            5  20(2), 25(5)  1=2, 2=3
# 3           NaN          NaN           NaN       NaN
# 4          11.9            7  24(3), 19(4)  1=3, 2=1

# %%
tmorphdf = tmorphdf.drop_duplicates(subset=['sample_id'])
tmorphdf.shape
# Out:
# (440, 10)

# %%
# Define the tables

# If running this more than once, you'll need to drop the table before you can redefine it

curs.execute("DROP TABLE IF EXISTS tMorphology;")

sql = """
CREATE TABLE tMorphology (
    sample_id TEXT PRIMARY KEY,
    species TEXT,
    plant_ht REAL,
    num_leaves INTEGER,
    longest_leaf_cm REAL,
    widest_leaf_cm REAL,
    stem_diam_mm REAL,
    num_inflores INTEGER,
    num_flowers INTEGER,
    herbivory TEXT
)
;"""
curs.execute(sql)

# INSERT INTO (column names) VALUES (values to insert)
# The : indicates parameter names.
# They do not need to be the same as the columns we are inserting into, but it helps keep the code clean.
# They are matched up in order. For example, if instead of :lat I called it :x, then :x would be inserted into
# the lat column, since lat is the second column in the list of column names.
sql = """
INSERT INTO tMorphology (sample_id, species, plant_ht, num_leaves,
    longest_leaf_cm, widest_leaf_cm, stem_diam_mm, num_inflores,
    num_flowers, herbivory) VALUES (:sample_id, :species, :plant_ht, :num_leaves,
    :longest_leaf_cm, :widest_leaf_cm, :stem_diam_mm, :num_inflores,
    :num_flowers, :herbivory)
;"""

# I'm going to loop over the dataframe such that each row will be returned as a dictionary.
# The keys for the dictionary will be the column names, and the values will be the values in the dataframe.
# I've ensured that the names in my dataframe match exactly the parameter names above - the way this works

# is that SQL will look for that key in the dictionary.  For example, since I have a parameter :loc_id, 
# it will look for a key in the dictionary called loc_id.





for row in tmorphdf.to_dict(orient='records'):
    # Uncomment this to see the dictionaries
    #print(row)
    
    # The second input for curs.execute() are parameters
    curs.execute(sql, row)

# %% [markdown]
# ## Create TSoilNutrients

# %%
curs.execute("DROP TABLE IF EXISTS tSoilNutrients;")
#Organic Matter % Rate	Estimated Nitrogen Release (lbs/A)	Cation Exchange Capacity (meq/100g)	
#pH	Buffer pH	Phosphorus ppm	Potassium ppm	Calcium ppm	Magnesium ppm	
#Sulfur ppm	Sodium ppm	Zinc ppm	Manganese ppm	Iron ppm	Copper ppm	Boron ppm

sql = """
CREATE TABLE tSoilNutrients (
    sample_id TEXT NOT NULL REFERENCES tSample(sample_id),
    OM REAL,
    ENR REAL,
    CEC REAL,
    pH REAL,
    BpH REAL,
    Phosphorus REAL,
    Potassium REAL,
    Calcium REAL,
    Magnesium REAL,
    Sulfur REAL,
    Sodium REAL,
    Zinc REAL,
    Manganese REAL,
    Iron REAL,
    Copper REAL,
    Boron REAL,
    PRIMARY KEY (sample_id)
)
;"""

curs.execute(sql)

# %%
tsoilnutrientdf = pd.read_csv('./csv_folder/soil_nutrients.csv')
tsoilnutrientdf.shape
# Out:
# (423, 18)

# %%
tsoilnutrientdf = tsoilnutrientdf.drop('site', axis = 1)

# %%
tsoilnutrientdf = tsoilnutrientdf.drop_duplicates('sample_id')

# %%
tsoilnutrientdf.tail()
# Out:
#     sample_id   OM  ENR   CEC   pH   BpH  Phosphorus  Potassium  Calcium  \
# 418     PNR13  5.8  142  20.4  7.7  6.93          21         78     3777
# 419     PNR14  4.2  110  22.3  7.6  6.93           9         45     4217
# 420     PNR15  3.6   98  18.7  7.7  6.93           8         42     3472
# 421      PNR8  3.7  100  17.9  7.6  6.93          12         37     3335
# 422      PNR9  3.7  100  18.7  7.5  6.93          18         48     3457
#
#      Magnesium  Sulfur  Sodium  Zinc  Manganese  Iron  Copper  Boron
# 418        155      12      13   3.7         98    92     1.1    1.1
# 419        131       9      13   2.1         36   156     1.2    0.5
# 420        143      13      13   2.5         51   135     1.2    0.7
# 421        124       9      14   1.5         35    59     0.7    0.5
# 422        147       7      13   1.6         39    62     0.8    0.7

# %%
soil_list = tsoilnutrientdf['sample_id'].tolist()
temp_list = []
for i in soil_list:
    if i[0] == '8':
        temp_list.append(i)

for i in temp_list:
    tsoilnutrientdf.drop(tsoilnutrientdf[(tsoilnutrientdf['sample_id'] == i)].index, inplace=True)
    tsoilnutrientdf.drop(tsoilnutrientdf[(tsoilnutrientdf['sample_id'] == 'BLDRV1-')].index, inplace=True)
    tsoilnutrientdf.drop_duplicates(subset="sample_id",
                             keep='first', inplace=True)
soil_list = tsoilnutrientdf['sample_id'].tolist()
for i in range(len(soil_list)):
    if soil_list[i][0] == '1':
        soil_list[i] = soil_list[i][1:]
    if soil_list[i][0] == ' ':
        soil_list[i] = soil_list[i][1:]
print(len(soil_list))
# Out:
# 368

# %%
tsoilnutrientdf['sample_id'] = soil_list
tsoilnutrientdf.tail()
# Out:
#     sample_id   OM  ENR   CEC   pH   BpH  Phosphorus  Potassium  Calcium  \
# 418     PNR13  5.8  142  20.4  7.7  6.93          21         78     3777
# 419     PNR14  4.2  110  22.3  7.6  6.93           9         45     4217
# 420     PNR15  3.6   98  18.7  7.7  6.93           8         42     3472
# 421      PNR8  3.7  100  17.9  7.6  6.93          12         37     3335
# 422      PNR9  3.7  100  18.7  7.5  6.93          18         48     3457
#
#      Magnesium  Sulfur  Sodium  Zinc  Manganese  Iron  Copper  Boron
# 418        155      12      13   3.7         98    92     1.1    1.1
# 419        131       9      13   2.1         36   156     1.2    0.5
# 420        143      13      13   2.5         51   135     1.2    0.7
# 421        124       9      14   1.5         35    59     0.7    0.5
# 422        147       7      13   1.6         39    62     0.8    0.7

# %%
# INSERT INTO (column names) VALUES (values to insert)
# The : indicates parameter names.
# They do not need to be the same as the columns we are inserting into, but it helps keep the code clean.
# They are matched up in order. For example, if instead of :lat I called it :x, then :x would be inserted into
# the lat column, since lat is the second column in the list of column names.
sql = """
INSERT INTO tSoilNutrients (sample_id, OM, ENR, CEC, pH, BpH,
    Phosphorus, Potassium, Calcium, Magnesium, Sulfur, Sodium,
    Zinc, Manganese, Iron, Copper, Boron) VALUES (:sample_id, :OM, :ENR, :CEC, :pH, :BpH,
    :Phosphorus, :Potassium, :Calcium, :Magnesium, :Sulfur, :Sodium,
    :Zinc, :Manganese, :Iron, :Copper, :Boron)
;"""


# I'm going to loop over the dataframe such that each row will be returned as a dictionary.
# The keys for the dictionary will be the column names, and the values will be the values in the dataframe.
# I've ensured that the names in my dataframe match exactly the parameter names above - the way this works
# is that SQL will look for that key in the dictionary.  For example, since I have a parameter :loc_id, 
# it will look for a key in the dictionary called loc_id.





for row in tsoilnutrientdf.to_dict(orient='records'):
    # Uncomment this to see the dictionaries
    
    # The second input for curs.execute() are parameters
    curs.execute(sql, row)

# %%
sql = """
CREATE VIEW tSoilNutrients AS 

SELECT *
;"""

pd.read_sql("SELECT * FROM tSoilNutrients;", conn)
# Out:
#     sample_id    OM    ENR   CEC   pH   BpH  Phosphorus  Potassium  Calcium  \
# 0      BLDTT0   4.3  124.0   8.1  6.8  6.91        18.0      180.0   1193.0
# 1     BLDTT11   4.7  135.0   6.6  6.0  6.83        22.0      195.0    781.0
# 2     BLDTT12   4.6  133.0   6.6  6.1  6.84        23.0      266.0    770.0
# 3     BLDTT13   4.9  138.0   6.8  6.1  6.84        24.0      270.0    741.0
# 4     BLDTT14   5.4  148.0   7.3  5.8  6.79        32.0      229.0    766.0
# 5     BLDTT15   4.5  130.0   7.1  6.1  6.83        25.0      335.0    751.0
# 6     BLDTT16   5.0  140.0   7.1  6.0  6.82        14.0      152.0    859.0
# 7     BLDTT17   5.0  139.0   7.6  6.3  6.85        15.0      233.0    931.0
# 8     BLDTT18   4.7  134.0   7.0  5.7  6.78        19.0      112.0    790.0
# 9     BLDTT19   4.8  134.0   8.6  6.4  6.85        18.0      325.0   1042.0
# 10     BLDTT2   4.9  135.0   9.0  6.8  6.90        15.0      177.0   1335.0
# 11    BLDTT20   4.6  132.0   7.3  6.1  6.83        19.0      237.0    871.0
# 12    BLDTT21   5.6  150.0   8.1  6.2  6.83        16.0      281.0    967.0
# 13    BLDTT22   5.1  143.0   6.5  6.0  6.83        17.0      274.0    762.0
# 14    BLDTT23   4.9  140.0   5.9  5.6  6.79        16.0      127.0    659.0
# 15    BLDTT24   5.9  150.0   5.9  5.1  6.71        30.0      117.0    531.0
# 16    BLDTT25   5.0  145.0   3.7  5.7  6.85        19.0      134.0    402.0
# 17    BLDTT26   4.1  124.0   5.3  6.3  6.87        20.0      216.0    618.0
# 18    BLDTT27   4.0  124.0   4.1  5.8  6.85        18.0      143.0    445.0
# 19    BLDTT28   5.9  150.0   6.9  6.2  6.85        23.0      205.0    901.0
# 20    BLDTT29   5.3  149.0   4.9  5.8  6.84        20.0      136.0    574.0
# 21     BLDTT3   5.6  147.0  10.2  7.0  6.93        16.0      249.0   1498.0
# 22    BLDTT30   5.3  150.0   4.4  5.7  6.84        22.0      165.0    476.0
# 23    BLDTT31   5.1  147.0   3.8  6.0  6.87        14.0       61.0    510.0
# 24    BLDTT32   3.8  117.0   6.4  6.0  6.83        20.0      136.0    851.0
# 25    BLDTT33   5.1  143.0   6.5  5.9  6.82        17.0       99.0    869.0
# 26    BLDTT34   5.3  148.0   5.8  6.0  6.84        14.0      165.0    736.0
# 27    BLDTT35   5.4  150.0   5.8  5.7  6.81        17.0      173.0    669.0
# 28    BLDTT36   5.0  142.0   5.9  6.0  6.84        13.0      195.0    703.0
# 29    BLDTT37   3.6  115.0   5.1  5.9  6.84        13.0      163.0    584.0
# ..        ...   ...    ...   ...  ...   ...         ...        ...      ...
# 338       RF3  11.3  150.0  12.3  5.9  6.72        40.0      116.0   1476.0
# 339       RF4  18.4  150.0  13.0  5.8  6.68        78.0      153.0   1341.0
# 340       RF5  12.4  150.0   9.3  5.4  6.67        58.0      108.0    881.0
# 341       RF6  11.8  150.0  11.3  6.2  6.79        50.0      141.0   1353.0
# 342       RF7  13.6  150.0  11.2  5.8  6.72        84.0      191.0   1219.0
# 343       RF8  14.1  150.0  13.1  5.1  6.44        63.0      146.0   1121.0
# 344       RF9  12.8  150.0  12.0  5.6  6.65        69.0      133.0   1346.0
# 345      TCP1   5.7  140.0  22.0  7.3  6.93         6.0       37.0   4189.0
# 346      TCP2   6.8  150.0  16.2  7.3  6.93         9.0       50.0   3011.0
# 347      TCP3   8.3  150.0  17.2  7.2  6.93        10.0       77.0   3179.0
# 348      TCP4   7.5  150.0  17.7  7.0  6.93        10.0       61.0   3303.0
# 349      PNR1   8.7  150.0  11.5  6.4  6.83        12.0       92.0   1647.0
# 350      PNR2   4.9  124.0  20.9  7.6  6.93         7.0       71.0   3814.0
# 351      PNR3   4.4  114.0  18.8  7.7  6.93         7.0       56.0   3478.0
# 352      PNR4   4.3  112.0  18.9  7.7  6.93         8.0       51.0   3536.0
# 353      PNR5   4.7  120.0  20.7  7.6  6.93         6.0       50.0   3862.0
# 354      PNR6   3.1   88.0  19.4  7.8  6.93         9.0       49.0   3615.0
# 355      PNR7   3.8  102.0  20.2  7.8  6.93        10.0       43.0   3771.0
# 356     TCP10   7.2  150.0  17.1  6.9  6.91        10.0       40.0   3193.0
# 357      TCP5   5.4  134.0  17.2  7.5  6.93         8.0       67.0   3237.0
# 358      TCP6   6.2  150.0  19.3  7.3  6.93        10.0       61.0   3611.0
# 359      TCP7   5.9  144.0  19.2  7.3  6.93         8.0       48.0   3605.0
# 360      TCP8   5.8  142.0  16.5  7.2  6.93         7.0       51.0   3098.0
# 361      TCP9   6.5  150.0  17.5  7.1  6.93        10.0       50.0   3301.0
# 362     PNR11   3.6   98.0  21.8  7.7  6.93        44.0       80.0   3965.0
# 363     PNR13   5.8  142.0  20.4  7.7  6.93        21.0       78.0   3777.0
# 364     PNR14   4.2  110.0  22.3  7.6  6.93         9.0       45.0   4217.0
# 365     PNR15   3.6   98.0  18.7  7.7  6.93         8.0       42.0   3472.0
# 366      PNR8   3.7  100.0  17.9  7.6  6.93        12.0       37.0   3335.0
# 367      PNR9   3.7  100.0  18.7  7.5  6.93        18.0       48.0   3457.0
#
#      Magnesium  Sulfur  Sodium  Zinc  Manganese   Iron  Copper  Boron
# 0        178.0     3.0     7.0   2.3      321.0   78.0     1.5    0.5
# 1        138.0     5.0     9.0   1.9       85.0   76.0     1.0    0.4
# 2        131.0     5.0     9.0   1.6       78.0   82.0     0.9    0.3
# 3        175.0     1.0     9.0   2.2       76.0   80.0     1.1    0.3
# 4        172.0     8.0     9.0   2.6       64.0   87.0     1.0    0.3
# 5        177.0     8.0     9.0   2.0       76.0   81.0     1.2    0.4
# 6        151.0    10.0     9.0   1.7      163.0   79.0     1.1    0.4
# 7        180.0     6.0     7.0   2.0      129.0   70.0     1.3    0.4
# 8        144.0     5.0     8.0   2.0       94.0   95.0     1.5    0.4
# 9        201.0     3.0     9.0   2.3      102.0   87.0     1.4    0.5
# 10       188.0     3.0     7.0   3.0      308.0   68.0     1.4    0.6
# 11       159.0     9.0     9.0   2.8      101.0  104.0     1.3    0.4
# 12       184.0     5.0     9.0   3.4      150.0  108.0     1.4    0.5
# 13       110.0     5.0     7.0   2.3      123.0   97.0     1.5    0.4
# 14        98.0     9.0     8.0   2.1      104.0  160.0     1.7    0.4
# 15        82.0     7.0     8.0   2.4      140.0  109.0     1.4    0.3
# 16        65.0     4.0     8.0   2.2      101.0  109.0     1.1    0.2
# 17       122.0     5.0     9.0   2.3      171.0  119.0     1.6    0.3
# 18        82.0     3.0     9.0   1.5      240.0  125.0     1.5    0.2
# 19       127.0    10.0     9.0   3.1      229.0  151.0     1.8    0.5
# 20        84.0     6.0     9.0   2.6      243.0  211.0     2.0    0.4
# 21       247.0     5.0     8.0   3.1      328.0   70.0     1.5    0.8
# 22        83.0    11.0     9.0   2.4      245.0  167.0     1.9    0.3
# 23        56.0     6.0     9.0   1.3      193.0  116.0     1.0    0.3
# 24        90.0    16.0    11.0   2.4      273.0  191.0     2.0    0.5
# 25        97.0     9.0     9.0   2.0      232.0  181.0     1.8    0.4
# 26        96.0    10.0     9.0   2.3      253.0  211.0     2.0    0.5
# 27        88.0     6.0     7.0   2.1      199.0  169.0     1.8    0.5
# 28       116.0     6.0    10.0   1.9      186.0  169.0     1.8    0.4
# 29        97.0     2.0    11.0   1.9      165.0  161.0     1.5    0.4
# ..         ...     ...     ...   ...        ...    ...     ...    ...
# 338      290.0    12.0    15.0   3.8      169.0  106.0     1.0    0.6
# 339      400.0    18.0    16.0   6.5      204.0  121.0     1.0    0.6
# 340      230.0    19.0    15.0   4.8      203.0  144.0     1.0    0.3
# 341      326.0    12.0    16.0   2.9      191.0  123.0     0.9    0.6
# 342      298.0    15.0    14.0   5.9      132.0  113.0     1.1    0.4
# 343      257.0    16.0    14.0   4.9      176.0  115.0     0.9    0.4
# 344      248.0    11.0    14.0   4.7      180.0  110.0     1.0    0.4
# 345      111.0    12.0    15.0   3.5       22.0  122.0     1.4    0.7
# 346      108.0    11.0    16.0   3.7       30.0  126.0     1.1    0.8
# 347      129.0     8.0    15.0   4.6       38.0  132.0     1.2    1.1
# 348      113.0    11.0    14.0   4.1       39.0  130.0     1.2    1.1
# 349      238.0     8.0    13.0   5.0      265.0  102.0     0.9    0.7
# 350      196.0     8.0    13.0   2.3       67.0   61.0     1.3    0.9
# 351      139.0     9.0    15.0   1.6       43.0   72.0     1.0    0.6
# 352      121.0     8.0    14.0   1.4       35.0   93.0     1.0    0.5
# 353      144.0    10.0    15.0   1.5       35.0   95.0     1.4    0.6
# 354      142.0     7.0    13.0   1.5       35.0   65.0     0.8    0.5
# 355      147.0    10.0    13.0   1.7       52.0   79.0     0.8    0.6
# 356       91.0    12.0    16.0   4.7       32.0  149.0     1.4    1.1
# 357       92.0    14.0    15.0   3.7       30.0   95.0     1.1    0.9
# 358      117.0    13.0    21.0   5.7       36.0  132.0     2.0    1.2
# 359      123.0    10.0    16.0   4.8       24.0  145.0     2.3    1.1
# 360       97.0    12.0    14.0   3.5       28.0  130.0     1.6    1.1
# 361       95.0    15.0    16.0   4.9       34.0  104.0     1.6    1.0
# 362      205.0    11.0    13.0   3.8       70.0   97.0     1.2    1.0
# 363      155.0    12.0    13.0   3.7       98.0   92.0     1.1    1.1
# 364      131.0     9.0    13.0   2.1       36.0  156.0     1.2    0.5
# 365      143.0    13.0    13.0   2.5       51.0  135.0     1.2    0.7
# 366      124.0     9.0    14.0   1.5       35.0   59.0     0.7    0.5
# 367      147.0     7.0    13.0   1.6       39.0   62.0     0.8    0.7
#
# [368 rows x 17 columns]

# %% [markdown]
# ## Create and fill table TPlantNutrients

# %%
curs.execute("DROP TABLE IF EXISTS tPlantNutrients;")


sql = """
CREATE TABLE tPlantNutrients (
    sample_id TEXT NOT NULL REFERENCES tSample(sample_id),
    N_percent_dm REAL,
    P_percent_dm REAL,
    K_percent_dm REAL,
    Ca_percent_dm REAL,
    Mg_percent_dm REAL,
    Na_percent_dm REAL,
    S_percent_dm REAL,
    Zn_ppm_dm REAL,
    Mn_ppm_dm REAL,
    Fe_ppm_dm REAL,
    Cu_ppm_dm REAL,
    B_ppm_dm REAL,
    Al_ppm_dm REAL,
    PRIMARY KEY (sample_id)
)
;"""
curs.execute(sql)

# %%
tleafnutrientdf = pd.read_csv('./csv_folder/leaf_nutrients.csv')

# %%
tleafnutrientdf.shape
# Out:
# (223, 14)

# %%
sql = """
INSERT INTO tPlantNutrients (sample_id, N_percent_dm, P_percent_dm, K_percent_dm, Ca_percent_dm, 
Mg_percent_dm, Na_percent_dm, S_percent_dm, Zn_ppm_dm, Mn_ppm_dm, Fe_ppm_dm, Cu_ppm_dm, B_ppm_dm, Al_ppm_dm)
VALUES (:Sample_ID, :N_percent_dm, :P_percent_dm, :K_percent_dm, :Ca_percent_dm, 
:Mg_percent_dm, :Na_percent_dm, :S_percent_dm, :Zn_ppm_dm, :Mn_ppm_dm, :Fe_ppm_dm, :Cu_ppm_dm, :B_ppm_dm, :Al_ppm_dm)
;"""

# I'm going to loop over the dataframe such that each row will be returned as a dictionary.
# The keys for the dictionary will be the column names, and the values will be the values in the dataframe.
# I've ensured that the names in my dataframe match exactly the parameter names above - the way this works
# is that SQL will look for that key in the dictionary.  For example, since I have a parameter :loc_id, 
# it will look for a key in the dictionary called loc_id.





for row in tleafnutrientdf.to_dict(orient='records'):
    # Uncomment this to see the dictionaries
    #print(row)
    
    # The second input for curs.execute() are parameters
    curs.execute(sql, row)

# %%
sql = """
CREATE VIEW tPlantNutrients AS 

SELECT *
;"""

pd.read_sql("SELECT * FROM tPlantNutrients;", conn)
# Out:
#     sample_id  N_percent_dm  P_percent_dm  K_percent_dm  Ca_percent_dm  \
# 0        RRL1           NaN          0.21          4.01           0.83
# 1        RRL2          2.24          0.16          5.34           1.05
# 2        RRL3           NaN          0.20          4.75           0.63
# 3        RRL4           NaN          0.18          4.74           1.25
# 4        RRL5          3.00          0.26          3.51           1.20
# 5        RRL6          3.26          0.19          2.55           0.73
# 6        RRL7           NaN          0.21          3.67           0.88
# 7        RRL8           NaN          0.19          3.14           0.70
# 8        RRL9          3.39          0.18          3.23           0.65
# 9       RRL10           NaN          0.18          3.29           1.37
# 10      RRL11          3.28          0.22          2.56           0.64
# 11      RRL12           NaN          0.18          2.51           0.77
# 12      RRL13           NaN          0.18          2.83           1.91
# 13      RRL14          2.57          0.18          3.32           1.34
# 14      RRL15          2.44          0.16          3.13           1.91
# 15      RRL16          2.75          0.20          4.15           1.11
# 16      RRL17          2.75          0.22          4.53           1.02
# 17      RRL18           NaN          0.20          2.59           1.60
# 18      RRL19          2.68          0.24          3.42           1.22
# 19      RRL20          2.45          0.16          3.01           1.36
# 20      RRL21          2.75          0.17          4.61           1.26
# 21      RRL22           NaN          0.20          4.68           1.38
# 22       FRW1          3.46          0.27          2.20           1.08
# 23       FRW2          3.19          0.22          3.83           2.18
# 24       FRW3          2.83          0.33          3.67           2.74
# 25       FRW4          3.64          0.26          2.49           0.84
# 26       FRW5          3.00          0.26          3.74           2.45
# 27       FRW6          3.35          0.29          3.56           1.92
# 28       FRW8          3.19          0.41          3.12           2.03
# 29       FRW9          3.20          0.27          4.30           1.84
# ..        ...           ...           ...           ...            ...
# 193       RF8          2.35          0.23          1.96           0.86
# 194       RF9          2.68          0.24          2.43           0.59
# 195      RF10          2.26          0.25          2.75           1.09
# 196      RF11          2.84          0.37          3.20           0.97
# 197      RF12          2.48          0.23          2.41           1.16
# 198      RF13          2.69          0.18          1.31           0.54
# 199      TCP1          2.08          0.15          1.28           1.82
# 200      TCP2          2.50          0.15          1.54           1.41
# 201      TCP3          2.53          0.15          2.09           1.87
# 202      TCP4          2.31          0.16          1.65           1.78
# 203      TCP5          2.45          0.17          1.75           1.96
# 204      TCP6          2.66          0.14          1.95           1.23
# 205      TCP7          3.17          0.14          1.81           1.74
# 206      TCP8          2.62          0.14          1.25           1.65
# 207      TCP9          2.85          0.14          1.97           1.82
# 208     TCP10          3.22          0.19          2.37           1.63
# 209      PNR1          2.23          0.28          3.38           1.25
# 210      PNR2          2.55          0.40          4.21           2.00
# 211      PNR3          2.64          0.42          3.92           1.57
# 212      PNR4          2.57          0.37          4.12           1.96
# 213      PNR5          2.68          0.34          4.49           2.05
# 214      PNR6          3.09          0.45          2.85           1.62
# 215      PNR7          2.91          0.51          1.95           2.08
# 216      PNR8          2.59          0.48          1.74           2.23
# 217      PNR9          3.21          0.50          2.51           2.00
# 218     PNR11          3.34          0.48          3.56           1.50
# 219     PNR13          1.91          0.21          1.55           2.33
# 220     PNR14          2.91          0.24          2.32           2.03
# 221     PNR15          2.72          0.22          2.13           2.40
# 222     PNR16          2.00          0.20          1.48           2.89
#
#      Mg_percent_dm  Na_percent_dm  S_percent_dm  Zn_ppm_dm  Mn_ppm_dm  \
# 0             0.29           0.01          0.37       29.0      281.0
# 1             0.32           0.01          0.29       20.0      423.0
# 2             0.27           0.04          0.22       21.0      469.0
# 3             0.32           0.01          0.28       18.0      680.0
# 4             0.44           0.01          0.29       29.0      507.0
# 5             0.50           0.01          0.28       21.0      324.0
# 6             0.22           0.01          0.32       17.0      509.0
# 7             0.25           0.01          0.39       15.0      276.0
# 8             0.30           0.01          0.35       17.0      476.0
# 9             0.38           0.01          0.28       28.0      538.0
# 10            0.30           0.01          0.30       26.0      432.0
# 11            0.38           0.01          0.32       15.0      226.0
# 12            0.44           0.01          0.25       28.0      320.0
# 13            0.38           0.01          0.34       32.0      448.0
# 14            0.63           0.01          0.23       38.0      392.0
# 15            0.25           0.01          0.29       24.0      297.0
# 16            0.39           0.01          0.19       29.0      249.0
# 17            0.52           0.01          0.27       46.0      391.0
# 18            0.47           0.01          0.26       24.0      282.0
# 19            0.55           0.01          0.31       27.0      405.0
# 20            0.44           0.01          0.20       30.0      207.0
# 21            0.37           0.01          0.17       26.0      343.0
# 22            0.28           0.01          0.26       17.0       32.0
# 23            0.34           0.01          0.23       16.0       43.0
# 24            0.44           0.01          0.24       21.0       66.0
# 25            0.23           0.01          0.24       15.0       24.0
# 26            0.34           0.01          0.21       17.0       47.0
# 27            0.33           0.01          0.27       17.0       50.0
# 28            0.31           0.01          0.28       25.0       36.0
# 29            0.27           0.01          0.27       29.0       67.0
# ..             ...            ...           ...        ...        ...
# 193           0.59           0.01          0.16       13.0      108.0
# 194           0.40           0.01          0.19       17.0       81.0
# 195           0.60           0.01          0.34       26.0      212.0
# 196           0.49           0.03          0.24       31.0      117.0
# 197           0.60           0.01          0.27       22.0      388.0
# 198           0.23           0.01          0.25       34.0      515.0
# 199           0.41           0.01          0.37       11.0       26.0
# 200           0.30           0.01          0.34       11.0       25.0
# 201           0.27           0.01          0.30       17.0       28.0
# 202           0.25           0.01          0.30       12.0       21.0
# 203           0.27           0.01          0.33       15.0       16.0
# 204           0.22           0.01          0.24       14.0       20.0
# 205           0.33           0.01          0.47       19.0       28.0
# 206           0.33           0.01          0.40       15.0       26.0
# 207           0.31           0.01          0.42       19.0       20.0
# 208           0.29           0.01          0.19       14.0       14.0
# 209           0.60           0.01          0.17       14.0       86.0
# 210           0.39           0.01          0.34       20.0       29.0
# 211           0.33           0.01          0.26       22.0       26.0
# 212           0.35           0.01          0.42       23.0       35.0
# 213           0.29           0.01          0.43       18.0       38.0
# 214           0.51           0.01          0.32       19.0       58.0
# 215           0.59           0.01          0.27       54.0      103.0
# 216           0.64           0.01          0.24       19.0       73.0
# 217           0.53           0.01          0.27       18.0       75.0
# 218           0.36           0.01          0.28       24.0       90.0
# 219           0.55           0.01          0.35       13.0       39.0
# 220           0.53           0.08          0.32       14.0       71.0
# 221           0.60           0.06          0.38       12.0       30.0
# 222           0.71           0.01          0.45       16.0       38.0
#
#      Fe_ppm_dm  Cu_ppm_dm  B_ppm_dm  Al_ppm_dm
# 0        234.0        8.0      24.0      130.0
# 1         76.0        5.0      27.0       36.0
# 2         68.0        5.0      32.0       18.0
# 3         78.0        6.0      36.0       27.0
# 4         66.0        7.0      23.0       22.0
# 5         69.0        6.0      21.0       26.0
# 6         65.0        8.0      25.0       18.0
# 7         91.0        8.0      22.0       58.0
# 8         72.0        8.0      30.0       23.0
# 9         61.0        6.0      25.0       26.0
# 10        68.0        8.0      27.0       21.0
# 11        85.0        7.0      35.0       36.0
# 12        77.0        7.0      31.0       25.0
# 13        66.0        5.0      24.0       16.0
# 14        57.0        5.0      30.0       16.0
# 15        45.0        4.0      26.0       11.0
# 16        57.0        5.0      29.0       16.0
# 17        54.0        6.0      45.0       11.0
# 18        58.0        5.0      27.0       13.0
# 19        57.0        5.0      24.0       21.0
# 20        54.0        5.0      40.0       13.0
# 21        67.0        5.0      49.0       29.0
# 22        79.0        7.0      24.0       20.0
# 23        68.0        8.0      33.0       19.0
# 24        51.0        7.0      35.0       10.0
# 25        53.0        6.0      24.0        8.0
# 26        45.0        7.0      34.0        9.0
# 27        48.0        8.0      38.0        7.0
# 28        65.0        8.0      26.0       12.0
# 29        51.0       10.0      33.0        6.0
# ..         ...        ...       ...        ...
# 193       33.0        4.0      18.0       17.0
# 194       42.0        5.0      12.0       20.0
# 195       34.0        4.0      16.0       20.0
# 196       46.0        7.0      24.0       25.0
# 197       55.0        7.0      20.0       51.0
# 198       66.0        8.0      23.0       84.0
# 199       52.0        5.0      16.0       22.0
# 200       66.0        5.0      17.0       26.0
# 201       63.0        6.0      26.0       23.0
# 202       74.0        6.0      21.0       30.0
# 203       53.0        6.0      28.0       17.0
# 204       60.0        8.0      21.0       24.0
# 205       69.0        6.0      22.0       20.0
# 206       59.0        5.0      19.0       20.0
# 207       53.0        8.0      30.0       24.0
# 208       57.0        7.0      35.0       28.0
# 209       39.0        6.0      27.0       10.0
# 210       43.0        7.0      36.0       11.0
# 211       42.0        8.0      22.0       10.0
# 212       42.0       10.0      27.0        9.0
# 213       51.0        7.0      42.0       13.0
# 214      100.0       11.0      28.0       68.0
# 215       53.0       11.0      34.0       14.0
# 216       60.0        8.0      26.0       21.0
# 217       54.0       10.0      40.0       17.0
# 218       53.0       14.0      33.0       18.0
# 219      103.0        5.0      21.0       40.0
# 220       67.0        6.0      25.0       21.0
# 221       50.0        6.0      34.0       26.0
# 222       48.0        4.0      28.0       17.0
#
# [223 rows x 14 columns]

# %% [markdown]
# ## Create and Fill Soil Micro Table

# %%
curs.execute("DROP TABLE IF EXISTS tSoilMicrobeGenera;")

sql = """
CREATE TABLE tSoilMicrobeGenera (
    sample_id TEXT NOT NULL REFERENCES tSample(sample_id),
    genera TEXT,
    relative_abundance REAL,
    PRIMARY KEY (sample_id, genera)
)
;"""
curs.execute(sql)

# %%
tsoilmicrobe = pd.read_csv('./csv_folder/final_soil_microbe.csv')

# %%
sql = """
INSERT INTO tSoilMicrobeGenera (sample_id, genera, relative_abundance)
VALUES (:sample_id, :genera, :relative_abundance)
;"""

# I'm going to loop over the dataframe such that each row will be returned as a dictionary.
# The keys for the dictionary will be the column names, and the values will be the values in the dataframe.
# I've ensured that the names in my dataframe match exactly the parameter names above - the way this works
# is that SQL will look for that key in the dictionary.  For example, since I have a parameter :loc_id, 
# it will look for a key in the dictionary called loc_id.





for row in tsoilmicrobe.to_dict(orient='records'):
    # Uncomment this to see the dictionaries
    #print(row)
    
    # The second input for curs.execute() are parameters
    curs.execute(sql, row)

# %%
sql = """
CREATE VIEW tSoilMicrobeGenera AS 

SELECT *
;"""

testdf = pd.read_sql("SELECT * FROM tSoilMicrobeGenera;", conn)

# %% [markdown]
# ## Create and Fill Plant Micro Table

# %%
plant_micro = pd.read_csv('./csv_folder/final_plant_microbe.csv')

# %%
plant_micro.head()
# Out:
#    Unnamed: 0 sample_id                                             genera  \
# 0           0      RRL1  Archaea|Euryarchaeota|Halobacteria|Halobacteri...
# 1           1      RRL2  Archaea|Euryarchaeota|Halobacteria|Halobacteri...
# 2           2      RRL3  Archaea|Euryarchaeota|Halobacteria|Halobacteri...
# 3           3      RRL4  Archaea|Euryarchaeota|Halobacteria|Halobacteri...
# 4           4      RRL5  Archaea|Euryarchaeota|Halobacteria|Halobacteri...
#
#    relative_abundance
# 0             0.00000
# 1             0.01333
# 2             0.00000
# 3             0.00943
# 4             0.00581

# %%
curs.execute("DROP TABLE IF EXISTS tPlantMicrobeGenera;")

sql = """
CREATE TABLE tPlantMicrobeGenera (
    sample_id TEXT NOT NULL REFERENCES tSample(sample_id),
    genera TEXT,
    relative_abundance REAL,
    PRIMARY KEY (sample_id, genera)
)
;"""
curs.execute(sql)

# %%
sql = """
INSERT INTO tPlantMicrobeGenera (sample_id, genera, relative_abundance)
VALUES (:sample_id, :genera, :relative_abundance)
;"""

# I'm going to loop over the dataframe such that each row will be returned as a dictionary.
# The keys for the dictionary will be the column names, and the values will be the values in the dataframe.
# I've ensured that the names in my dataframe match exactly the parameter names above - the way this works
# is that SQL will look for that key in the dictionary.  For example, since I have a parameter :loc_id, 
# it will look for a key in the dictionary called loc_id.





for row in plant_micro.to_dict(orient='records'):
    # Uncomment this to see the dictionaries
    #print(row)
    
    # The second input for curs.execute() are parameters
    curs.execute(sql, row)

conn.commit()
conn.close()

# %%
sql = """
CREATE VIEW tPlantMicrobeGenera AS 

SELECT *
;"""

test_df = pd.read_sql("SELECT * FROM tPlantMicrobeGenera;", conn)

# %%
test_df.shape
# Out:
# (0, 3)

# %%
conn.close()

# %% [markdown]
# ## Create and Fill Plant DNA Table

# %%
plant_dna = pd.read_csv('./csv_folder/final_plant_dna.csv')

# %%
plant_dna.head()
# Out:
#    Unnamed: 0        V1        V2   Name   Species       PC1       PC2  \
# 0           0  0.753244  0.246756   RRL1  exaltata  0.194769  0.048276
# 1           1  0.581366  0.418634   RRL9  exaltata  0.097719  0.094733
# 2           2  0.591513  0.408487  RRL17  exaltata  0.099527  0.091996
# 3           3  0.048066  0.951934   FRW3   syriaca -0.139465 -0.064022
# 4           4  0.003946  0.996054  FRW12   syriaca -0.155135  0.055455
#
#         PC3       PC4       PC5
# 0 -0.023880 -0.017138 -0.039842
# 1 -0.006560  0.012822 -0.022248
# 2  0.004098 -0.021347  0.007190
# 3 -0.009963 -0.047536  0.024757
# 4  0.009907 -0.043334 -0.009337

# %%
curs.execute("DROP TABLE IF EXISTS tPlantDNA;")

sql = """
CREATE TABLE tPlantDNA (
    sample_id TEXT NOT NULL REFERENCES tSample(sample_id),
    V1 REAL,
    V2 REAL,
    species TEXT,
    PC1 REAL,
    PC2 REAL,
    PC3 REAL,
    PC4 REAL,
    PC5 REAL,
    PRIMARY KEY (sample_id)
)
;"""
curs.execute(sql)

# %%
sql = """
INSERT INTO tPlantDNA (
    sample_id,
    V1,
    V2,
    species,
    PC1,
    PC2,
    PC3,
    PC4,
    PC5
)
VALUES (
    :Name,
    :V1,
    :V2,
    :Species,
    :PC1,
    :PC2,
    :PC3,
    :PC4,
    :PC5
)
;"""

# I'm going to loop over the dataframe such that each row will be returned as a dictionary.
# The keys for the dictionary will be the column names, and the values will be the values in the dataframe.
# I've ensured that the names in my dataframe match exactly the parameter names above - the way this works
# is that SQL will look for that key in the dictionary.  For example, since I have a parameter :loc_id, 
# it will look for a key in the dictionary called loc_id.





for row in plant_dna.to_dict(orient='records'):
    # Uncomment this to see the dictionaries
    print(row)
    
    # The second input for curs.execute() are parameters
    curs.execute(sql, row)
# Out:
# {'PC1': 0.19476886, 'PC2': 0.048276406, 'PC4': -0.017137507, 'Unnamed: 0': 0, 'Name': 'RRL1', 'PC3': -0.023879902, 'Species': 'exaltata', 'V1': 0.753243943, 'PC5': -0.039841764, 'V2': 0.246756057}
# {'PC1': 0.09771936, 'PC2': 0.094733246, 'PC4': 0.012822087, 'Unnamed: 0': 1, 'Name': 'RRL9', 'PC3': -0.006560023000000001, 'Species': 'exaltata', 'V1': 0.581365683, 'PC5': -0.022248093, 'V2': 0.418634317}
# {'PC1': 0.099527225, 'PC2': 0.09199582, 'PC4': -0.021346599, 'Unnamed: 0': 2, 'Name': 'RRL17', 'PC3': 0.004098483, 'Species': 'exaltata', 'V1': 0.591513172, 'PC5': 0.007190188, 'V2': 0.408486828}
# {'PC1': -0.13946539, 'PC2': -0.064021535, 'PC4': -0.047536157, 'Unnamed: 0': 3, 'Name': 'FRW3', 'PC3': -0.009963222, 'Species': 'syriaca', 'V1': 0.04806566, 'PC5': 0.024756748, 'V2': 0.95193434}
# {'PC1': -0.15513538, 'PC2': 0.05545539, 'PC4': -0.04333402, 'Unnamed: 0': 4, 'Name': 'FRW12', 'PC3': 0.009907202, 'Species': 'syriaca', 'V1': 0.003946191, 'PC5': -0.009336631, 'V2': 0.996053809}
# {'PC1': -0.14547096, 'PC2': 0.040481266, 'PC4': 0.08940963, 'Unnamed: 0': 5, 'Name': 'MMP7', 'PC3': -0.012633025, 'Species': 'syriaca', 'V1': 0.016870491, 'PC5': -0.026201207, 'V2': 0.983129509}
# {'PC1': -0.14178735, 'PC2': 0.05248844, 'PC4': 0.011315407, 'Unnamed: 0': 6, 'Name': 'MMP15', 'PC3': -0.001292027, 'Species': 'syriaca', 'V1': 0.014152273, 'PC5': 0.00531649, 'V2': 0.985847727}
# {'PC1': -0.15617183, 'PC2': 0.034307807999999995, 'PC4': -0.012745836000000002, 'Unnamed: 0': 7, 'Name': 'PNR3', 'PC3': 0.008759816, 'Species': 'syriaca', 'V1': 0.000952179, 'PC5': -0.0212565, 'V2': 0.999047821}
# {'PC1': -0.15489268, 'PC2': 0.10821225, 'PC4': 0.027256494, 'Unnamed: 0': 8, 'Name': 'CMB13', 'PC3': -0.006325664, 'Species': 'syriaca', 'V1': 0.010869404, 'PC5': 0.015136438, 'V2': 0.989130596}
# {'PC1': -0.15260035, 'PC2': 0.048849713, 'PC4': 0.030490328, 'Unnamed: 0': 9, 'Name': 'CMB21', 'PC3': -0.030659795, 'Species': 'syriaca', 'V1': 5.63e-06, 'PC5': 0.028277326, 'V2': 0.999994372}
# {'PC1': 0.07330604, 'PC2': 0.12488815, 'PC4': -0.01747493, 'Unnamed: 0': 10, 'Name': 'SLG1', 'PC3': -0.018602598, 'Species': 'exaltata', 'V1': 0.5264428520000001, 'PC5': -0.015559977, 'V2': 0.473557148}
# {'PC1': -0.115932696, 'PC2': -0.03501165, 'PC4': 0.09201267, 'Unnamed: 0': 11, 'Name': 'SLG13', 'PC3': -0.033363014, 'Species': 'syriaca', 'V1': 0.13011230699999998, 'PC5': -0.017057965, 'V2': 0.869887693}
# {'PC1': 0.15492405, 'PC2': 0.07127726, 'PC4': -0.025829716000000003, 'Unnamed: 0': 12, 'Name': 'RRL2', 'PC3': 0.000923, 'Species': 'exaltata', 'V1': 0.7084121879999999, 'PC5': 0.005591766, 'V2': 0.291587812}
# {'PC1': 0.113937445, 'PC2': 0.08656046, 'PC4': 0.007765446999999998, 'Unnamed: 0': 13, 'Name': 'RRL10', 'PC3': -0.018321296, 'Species': 'exaltata', 'V1': 0.592773065, 'PC5': -0.027254667000000003, 'V2': 0.407226935}
# {'PC1': 0.19181943, 'PC2': 0.06233021, 'PC4': 0.033918124, 'Unnamed: 0': 14, 'Name': 'RRL18', 'PC3': -0.007967645, 'Species': 'exaltata', 'V1': 0.756434368, 'PC5': 0.011057355, 'V2': 0.243565632}
# {'PC1': -0.024369499, 'PC2': 0.04692084, 'PC4': -0.06399772, 'Unnamed: 0': 15, 'Name': 'FRW4', 'PC3': 0.017316611000000003, 'Species': 'syriaca', 'V1': 0.343453135, 'PC5': 0.016132452, 'V2': 0.656546865}
# {'PC1': -0.1372694, 'PC2': -0.11946941, 'PC4': -0.0465973, 'Unnamed: 0': 16, 'Name': 'FRW13', 'PC3': -0.032234807000000004, 'Species': 'syriaca', 'V1': 0.06199869, 'PC5': 0.029122096, 'V2': 0.93800131}
# {'PC1': -0.13802943, 'PC2': 0.06567472, 'PC4': 0.05549799, 'Unnamed: 0': 17, 'Name': 'MMP8', 'PC3': -0.014048361, 'Species': 'syriaca', 'V1': 8.58e-08, 'PC5': -0.034023013, 'V2': 0.999999914}
# {'PC1': -0.15363626, 'PC2': 0.035954002, 'PC4': 0.000921, 'Unnamed: 0': 18, 'Name': 'MMP16', 'PC3': 0.003064853, 'Species': 'syriaca', 'V1': 0.000119851, 'PC5': 0.012418235, 'V2': 0.999880149}
# {'PC1': 0.11661796, 'PC2': 0.0891488, 'PC4': -0.005142925, 'Unnamed: 0': 19, 'Name': 'CMB6', 'PC3': -0.011358734, 'Species': 'syriaca', 'V1': 0.6113055070000001, 'PC5': -0.015048585, 'V2': 0.388694493}
# {'PC1': -0.15588981, 'PC2': 0.12228034, 'PC4': 0.009375772, 'Unnamed: 0': 20, 'Name': 'CMB14', 'PC3': 0.01648242, 'Species': 'syriaca', 'V1': 7.95e-06, 'PC5': 0.01676111, 'V2': 0.99999205}
# {'PC1': -0.16008991, 'PC2': 0.09054671, 'PC4': 0.024092108, 'Unnamed: 0': 21, 'Name': 'CMB22', 'PC3': -0.007357171, 'Species': 'syriaca', 'V1': 0.00102335, 'PC5': 0.010499325, 'V2': 0.99897665}
# {'PC1': 0.14779317, 'PC2': 0.05916474400000001, 'PC4': -0.011129295, 'Unnamed: 0': 22, 'Name': 'SLG2', 'PC3': -0.024548963, 'Species': 'exaltata', 'V1': 0.68195383, 'PC5': -0.034775235, 'V2': 0.31804617}
# {'PC1': -0.1523847, 'PC2': 0.000196, 'PC4': -0.004950215, 'Unnamed: 0': 23, 'Name': 'SLG14', 'PC3': -0.014774608, 'Species': 'syriaca', 'V1': 0.000187968, 'PC5': 0.034156594, 'V2': 0.999812032}
# {'PC1': 0.18774958, 'PC2': 0.035009198, 'PC4': -0.01252884, 'Unnamed: 0': 24, 'Name': 'RRL3', 'PC3': -0.016006002, 'Species': 'exaltata', 'V1': 0.778046182, 'PC5': -0.011169495, 'V2': 0.221953818}
# {'PC1': 0.10689447, 'PC2': 0.08874242, 'PC4': -0.007987799, 'Unnamed: 0': 25, 'Name': 'RRL11', 'PC3': 0.0075185719999999985, 'Species': 'exaltata', 'V1': 0.584172845, 'PC5': 0.002289367, 'V2': 0.415827155}
# {'PC1': 0.13543402, 'PC2': 0.06626358, 'PC4': -0.02772644, 'Unnamed: 0': 26, 'Name': 'RRL19', 'PC3': 0.001924889, 'Species': 'exaltata', 'V1': 0.67808708, 'PC5': -0.02744266, 'V2': 0.32191292}
# {'PC1': -0.15812914, 'PC2': 0.12986201, 'PC4': 0.009137278, 'Unnamed: 0': 28, 'Name': 'MMP1', 'PC3': 0.027166383, 'Species': 'syriaca', 'V1': 1.25e-05, 'PC5': 5.710000000000001e-05, 'V2': 0.999987456}
# {'PC1': -0.13185757, 'PC2': -0.002844415, 'PC4': 0.09842658, 'Unnamed: 0': 29, 'Name': 'MMP9', 'PC3': -0.01855865, 'Species': 'syriaca', 'V1': 0.095047513, 'PC5': -0.007394800000000002, 'V2': 0.904952487}
# {'PC1': -0.15201826, 'PC2': 0.00150741, 'PC4': 0.04145332, 'Unnamed: 0': 30, 'Name': 'MMP17', 'PC3': -0.001208941, 'Species': 'syriaca', 'V1': 0.00387861, 'PC5': -0.025159882, 'V2': 0.99612139}
# {'PC1': -0.15964453, 'PC2': 0.09443791, 'PC4': 0.030247176, 'Unnamed: 0': 31, 'Name': 'CMB15', 'PC3': 0.000697, 'Species': 'syriaca', 'V1': 0.001452347, 'PC5': 0.01359877, 'V2': 0.998547653}
# {'PC1': -0.14976375, 'PC2': 0.08615787, 'PC4': 0.049274176, 'Unnamed: 0': 32, 'Name': 'CMB23', 'PC3': 0.002160819, 'Species': 'syriaca', 'V1': 0.017364404, 'PC5': 0.0041028390000000005, 'V2': 0.982635596}
# {'PC1': 0.07380083, 'PC2': 0.12801777, 'PC4': -0.004363012, 'Unnamed: 0': 33, 'Name': 'SLG3', 'PC3': 2.1600000000000007e-05, 'Species': 'exaltata', 'V1': 0.55184294, 'PC5': 0.007745206, 'V2': 0.44815706}
# {'PC1': -0.1455948, 'PC2': 0.049154915, 'PC4': 0.017174711000000002, 'Unnamed: 0': 34, 'Name': 'SLG16', 'PC3': 0.007177047, 'Species': 'syriaca', 'V1': 0.000478191, 'PC5': -0.03511055, 'V2': 0.999521809}
# {'PC1': 0.16716675, 'PC2': 0.046052895, 'PC4': -0.01619174, 'Unnamed: 0': 35, 'Name': 'RRL4', 'PC3': -0.03275362, 'Species': 'exaltata', 'V1': 0.7203666320000001, 'PC5': -0.028987776, 'V2': 0.279633368}
# {'PC1': 0.11151429, 'PC2': 0.09284633, 'PC4': -0.010786428, 'Unnamed: 0': 36, 'Name': 'RRL12', 'PC3': -0.022550507, 'Species': 'exaltata', 'V1': 0.621389434, 'PC5': 0.02173912, 'V2': 0.378610566}
# {'PC1': 0.24481441, 'PC2': -0.029296784, 'PC4': 0.022966, 'Unnamed: 0': 37, 'Name': 'RRL20', 'PC3': -0.05097307, 'Species': 'exaltata', 'V1': 0.8875281690000001, 'PC5': -0.003321986, 'V2': 0.112471831}
# {'PC1': -0.14287516, 'PC2': 0.017579366000000003, 'PC4': -0.042355277, 'Unnamed: 0': 38, 'Name': 'FRW6', 'PC3': -0.017795293, 'Species': 'syriaca', 'V1': 0.036645926, 'PC5': 0.0013509, 'V2': 0.963354074}
# {'PC1': -0.12417936, 'PC2': -0.015794229, 'PC4': 0.10663601, 'Unnamed: 0': 39, 'Name': 'MMP2', 'PC3': -0.04933872, 'Species': 'syriaca', 'V1': 0.071215825, 'PC5': -0.011737339, 'V2': 0.928784175}
# {'PC1': -0.14457679999999998, 'PC2': 0.04187835, 'PC4': 0.08724277, 'Unnamed: 0': 40, 'Name': 'MMP10', 'PC3': -0.019908447, 'Species': 'syriaca', 'V1': 0.007940276, 'PC5': -0.028641338, 'V2': 0.992059724}
# {'PC1': -0.14317183, 'PC2': -0.038980447, 'PC4': 0.059778072, 'Unnamed: 0': 41, 'Name': 'MMP18', 'PC3': -0.022789845, 'Species': 'syriaca', 'V1': 0.033889231, 'PC5': 0.000602, 'V2': 0.966110769}
# {'PC1': -0.15503271, 'PC2': 0.037725743, 'PC4': 0.05303768, 'Unnamed: 0': 42, 'Name': 'CMB8', 'PC3': -0.01931601, 'Species': 'syriaca', 'V1': 3.39e-08, 'PC5': 0.030728143, 'V2': 0.999999966}
# {'PC1': -0.15571678, 'PC2': 0.10368895, 'PC4': 0.03675893, 'Unnamed: 0': 43, 'Name': 'CMB16', 'PC3': 0.007176627, 'Species': 'syriaca', 'V1': 0.000756517, 'PC5': 0.009531777, 'V2': 0.999243483}
# {'PC1': -0.15495738, 'PC2': 0.075662374, 'PC4': 0.039805334, 'Unnamed: 0': 44, 'Name': 'CMB24', 'PC3': -0.0045086990000000006, 'Species': 'syriaca', 'V1': 7.56e-14, 'PC5': 0.012562014, 'V2': 1.0}
# {'PC1': 0.11107878, 'PC2': 0.09837058, 'PC4': -0.010208701, 'Unnamed: 0': 45, 'Name': 'SLG4', 'PC3': -0.010987682, 'Species': 'exaltata', 'V1': 0.58747301, 'PC5': 0.012288958, 'V2': 0.41252699}
# {'PC1': -0.13163866, 'PC2': 0.06414740000000001, 'PC4': 0.045087833, 'Unnamed: 0': 46, 'Name': 'SLG18', 'PC3': 0.023457406, 'Species': 'syriaca', 'V1': 0.039166073, 'PC5': -0.019971902, 'V2': 0.960833927}
# {'PC1': 0.099801056, 'PC2': 0.089800246, 'PC4': -0.004978875, 'Unnamed: 0': 47, 'Name': 'RRL5', 'PC3': 0.0006129999999999999, 'Species': 'exaltata', 'V1': 0.572487362, 'PC5': 0.017524144, 'V2': 0.427512638}
# {'PC1': 0.22435994, 'PC2': 0.00349323, 'PC4': 0.012705103999999998, 'Unnamed: 0': 48, 'Name': 'RRL13', 'PC3': -0.048505127, 'Species': 'exaltata', 'V1': 0.85686537, 'PC5': -6.64e-05, 'V2': 0.14313463}
# {'PC1': 0.18486333, 'PC2': 0.038645357000000005, 'PC4': -0.0068817190000000006, 'Unnamed: 0': 49, 'Name': 'RRL21', 'PC3': -0.017773215, 'Species': 'exaltata', 'V1': 0.7884016490000001, 'PC5': -0.02167732, 'V2': 0.211598351}
# {'PC1': -0.030449254, 'PC2': 0.061606746, 'PC4': -0.043926768, 'Unnamed: 0': 50, 'Name': 'FRW8', 'PC3': 0.033927687000000005, 'Species': 'syriaca', 'V1': 0.307026774, 'PC5': 0.028653517000000007, 'V2': 0.6929732259999999}
# {'PC1': -0.12796435, 'PC2': -0.003279877, 'PC4': 0.07243126, 'Unnamed: 0': 51, 'Name': 'MMP3', 'PC3': -0.026042145, 'Species': 'syriaca', 'V1': 0.078399348, 'PC5': -0.015351015, 'V2': 0.921600652}
# {'PC1': -0.12527741, 'PC2': 0.026658397, 'PC4': 0.03462207, 'Unnamed: 0': 52, 'Name': 'MMP11', 'PC3': -0.01715776, 'Species': 'syriaca', 'V1': 0.0906216, 'PC5': -0.0017897000000000004, 'V2': 0.9093784}
# {'PC1': -0.14824419, 'PC2': -0.04528984, 'PC4': 0.017110271, 'Unnamed: 0': 53, 'Name': 'MMP19', 'PC3': -0.009745454, 'Species': 'syriaca', 'V1': 0.049977275, 'PC5': -0.001419017, 'V2': 0.950022725}
# {'PC1': -0.14337261, 'PC2': 0.04853314, 'PC4': 0.051594134000000014, 'Unnamed: 0': 54, 'Name': 'CMB9', 'PC3': -0.034413423, 'Species': 'syriaca', 'V1': 1.93e-06, 'PC5': 0.030147282, 'V2': 0.999998074}
# {'PC1': -0.15460451, 'PC2': 0.093484275, 'PC4': 0.015420239, 'Unnamed: 0': 55, 'Name': 'CMB17', 'PC3': -0.010877034, 'Species': 'syriaca', 'V1': 1.55e-16, 'PC5': 0.037434727, 'V2': 1.0}
# {'PC1': -0.14028692, 'PC2': 0.06712972, 'PC4': 0.051795714000000014, 'Unnamed: 0': 56, 'Name': 'CMB25', 'PC3': 0.003471289, 'Species': 'syriaca', 'V1': 0.030505643, 'PC5': 0.030155314, 'V2': 0.969494357}
# {'PC1': 0.13135345, 'PC2': 0.08150223, 'PC4': 0.00689031, 'Unnamed: 0': 57, 'Name': 'SLG5', 'PC3': 0.007732876, 'Species': 'exaltata', 'V1': 0.692085273, 'PC5': 0.019974845, 'V2': 0.307914727}
# {'PC1': -0.1487375, 'PC2': 0.030116305, 'PC4': -0.042565916, 'Unnamed: 0': 58, 'Name': 'SLG15', 'PC3': -0.008810903, 'Species': 'syriaca', 'V1': 0.000162188, 'PC5': 0.002475466, 'V2': 0.999837812}
# {'PC1': 0.12861019999999998, 'PC2': 0.07695500599999999, 'PC4': -0.053479098, 'Unnamed: 0': 59, 'Name': 'RRL6', 'PC3': 0.020429322, 'Species': 'exaltata', 'V1': 0.653961475, 'PC5': 0.015590372, 'V2': 0.346038525}
# {'PC1': 0.19200355, 'PC2': 0.02269861, 'PC4': -0.021896966, 'Unnamed: 0': 60, 'Name': 'RRL22', 'PC3': -0.027640121, 'Species': 'exaltata', 'V1': 0.791174713, 'PC5': 0.010762544, 'V2': 0.208825287}
# {'PC1': -0.13071892, 'PC2': -0.0482077, 'PC4': -0.056307882, 'Unnamed: 0': 61, 'Name': 'FRW9', 'PC3': 0.020033317, 'Species': 'syriaca', 'V1': 0.050382793, 'PC5': -0.00951446, 'V2': 0.949617207}
# {'PC1': -0.1499364, 'PC2': 0.01495103, 'PC4': 0.07605076, 'Unnamed: 0': 62, 'Name': 'MMP4', 'PC3': -0.04016587, 'Species': 'syriaca', 'V1': 6.25e-05, 'PC5': -0.011182042, 'V2': 0.999937501}
# {'PC1': -0.14666118, 'PC2': 0.104787, 'PC4': -0.000857, 'Unnamed: 0': 63, 'Name': 'MMP12', 'PC3': 0.029031765, 'Species': 'syriaca', 'V1': 0.011954583, 'PC5': -0.019812906, 'V2': 0.988045417}
# {'PC1': -0.14998247, 'PC2': 0.07842438, 'PC4': -0.036443803, 'Unnamed: 0': 64, 'Name': 'MMP20', 'PC3': 0.040867843, 'Species': 'syriaca', 'V1': 1.72e-06, 'PC5': -0.003423307, 'V2': 0.999998278}
# {'PC1': -0.15026888, 'PC2': 0.041661996, 'PC4': 0.06184924, 'Unnamed: 0': 65, 'Name': 'CMB10', 'PC3': -0.01522678, 'Species': 'syriaca', 'V1': 0.000222879, 'PC5': 0.043956388, 'V2': 0.999777121}
# {'PC1': -0.14834158, 'PC2': 0.08543351, 'PC4': 0.022763671, 'Unnamed: 0': 66, 'Name': 'CMB18', 'PC3': 0.008185689, 'Species': 'syriaca', 'V1': 4.41e-09, 'PC5': -0.005446793, 'V2': 0.999999996}
# {'PC1': -0.15305771, 'PC2': 0.09113132, 'PC4': 0.034102075, 'Unnamed: 0': 67, 'Name': 'CMB26', 'PC3': -0.011045889, 'Species': 'syriaca', 'V1': 0.0016491829999999998, 'PC5': 0.012588766, 'V2': 0.998350817}
# {'PC1': 0.075027965, 'PC2': 0.11497988, 'PC4': -0.03001013, 'Unnamed: 0': 68, 'Name': 'SLG6', 'PC3': 0.009830424, 'Species': 'exaltata', 'V1': 0.51705625, 'PC5': -0.020084528, 'V2': 0.48294375}
# {'PC1': -0.15051605, 'PC2': 0.099330224, 'PC4': 0.014137201, 'Unnamed: 0': 69, 'Name': 'SLG20', 'PC3': 0.018743245, 'Species': 'syriaca', 'V1': 1.67e-13, 'PC5': -0.00397468, 'V2': 1.0}
# {'PC1': 0.18453191, 'PC2': 0.03136763, 'PC4': 0.016763268, 'Unnamed: 0': 70, 'Name': 'RRL7', 'PC3': -0.018564975, 'Species': 'exaltata', 'V1': 0.7754815159999999, 'PC5': -0.017642364, 'V2': 0.224518484}
# {'PC1': -0.05060773, 'PC2': 0.109213494, 'PC4': -0.06312501400000001, 'Unnamed: 0': 71, 'Name': 'FRW1', 'PC3': 0.031232597, 'Species': 'syriaca', 'V1': 0.214752199, 'PC5': 0.010424474, 'V2': 0.7852478009999999}
# {'PC1': -0.15024582, 'PC2': -0.003146688, 'PC4': -0.053870805, 'Unnamed: 0': 72, 'Name': 'FRW10', 'PC3': 0.013740771, 'Species': 'syriaca', 'V1': 4.96e-06, 'PC5': 0.01422722, 'V2': 0.99999504}
# {'PC1': -0.1299282, 'PC2': 0.025127431, 'PC4': 0.072516136, 'Unnamed: 0': 73, 'Name': 'MMP5', 'PC3': -0.021422682, 'Species': 'syriaca', 'V1': 0.079517924, 'PC5': -0.02272686, 'V2': 0.920482076}
# {'PC1': -0.13782565, 'PC2': 0.025051307, 'PC4': -0.011191883, 'Unnamed: 0': 74, 'Name': 'MMP13', 'PC3': 0.011632821000000002, 'Species': 'syriaca', 'V1': 0.038666205, 'PC5': 0.026637172, 'V2': 0.961333795}
# {'PC1': -0.15115465, 'PC2': 0.037809648, 'PC4': -0.016429191, 'Unnamed: 0': 75, 'Name': 'PNR1', 'PC3': -0.00031800000000000003, 'Species': 'syriaca', 'V1': 7.21e-08, 'PC5': -0.011034707, 'V2': 0.999999928}
# {'PC1': -0.14594585, 'PC2': 0.06738358, 'PC4': 0.050858676, 'Unnamed: 0': 76, 'Name': 'CMB11', 'PC3': -0.011765838999999998, 'Species': 'syriaca', 'V1': 1.74e-08, 'PC5': 0.034067996, 'V2': 0.999999983}
# {'PC1': -0.15302579, 'PC2': 0.06539814, 'PC4': 0.037721425, 'Unnamed: 0': 77, 'Name': 'CMB19', 'PC3': -0.002525497, 'Species': 'syriaca', 'V1': 6.48e-05, 'PC5': 0.030975468, 'V2': 0.999935194}
# {'PC1': -0.1576714, 'PC2': 0.034235477, 'PC4': 0.055057595999999986, 'Unnamed: 0': 78, 'Name': 'CMB27', 'PC3': 0.008253193, 'Species': 'syriaca', 'V1': 1.33e-10, 'PC5': 0.03212818, 'V2': 1.0}
# {'PC1': -0.14859495, 'PC2': -0.0032713670000000003, 'PC4': -0.002811593, 'Unnamed: 0': 79, 'Name': 'SLG8', 'PC3': -0.008316635, 'Species': 'syriaca', 'V1': 0.000496485, 'PC5': 0.016608605, 'V2': 0.999503515}
# {'PC1': -0.14970806, 'PC2': 0.07580838, 'PC4': 0.043004792, 'Unnamed: 0': 80, 'Name': 'SLG23', 'PC3': -0.004923468, 'Species': 'syriaca', 'V1': 4.85e-07, 'PC5': -0.006737571, 'V2': 0.999999515}
# {'PC1': 0.10260651, 'PC2': 0.08454814, 'PC4': -0.04579149, 'Unnamed: 0': 81, 'Name': 'RRL16', 'PC3': 0.005238342, 'Species': 'exaltata', 'V1': 0.623128833, 'PC5': 0.001691488, 'V2': 0.376871167}
# {'PC1': -0.15063846, 'PC2': 0.046492666, 'PC4': -0.05429167, 'Unnamed: 0': 82, 'Name': 'FRW2', 'PC3': 0.002480024, 'Species': 'syriaca', 'V1': 0.004733621, 'PC5': -0.014998959, 'V2': 0.995266379}
# {'PC1': -0.1579392, 'PC2': 0.043121707, 'PC4': -0.054458883, 'Unnamed: 0': 83, 'Name': 'FRW11', 'PC3': 0.013293673999999998, 'Species': 'syriaca', 'V1': 0.00013309, 'PC5': 0.011560479, 'V2': 0.99986691}
# {'PC1': -0.17312850000000002, 'PC2': 0.044026997000000005, 'PC4': 0.00563753, 'Unnamed: 0': 84, 'Name': 'MMP6', 'PC3': -0.012078056, 'Species': 'syriaca', 'V1': 6.99e-06, 'PC5': -0.018861938, 'V2': 0.999993011}
# {'PC1': -0.15130396, 'PC2': 0.06555398, 'PC4': 0.01898534, 'Unnamed: 0': 85, 'Name': 'MMP14', 'PC3': 0.008235991, 'Species': 'syriaca', 'V1': 3.83e-06, 'PC5': -0.002064494, 'V2': 0.999996167}
# {'PC1': -0.16445285, 'PC2': 0.07848246, 'PC4': -0.018959748, 'Unnamed: 0': 86, 'Name': 'PNR2', 'PC3': 0.019091861, 'Species': 'hybrid', 'V1': 9.220000000000002e-12, 'PC5': -0.015882438000000002, 'V2': 1.0}
# {'PC1': 0.0015362210000000002, 'PC2': 0.16885471, 'PC4': -0.015274061, 'Unnamed: 0': 87, 'Name': 'RF13', 'PC3': -0.009236567, 'Species': 'exaltata', 'V1': 0.34430792200000004, 'PC5': -0.02560931, 'V2': 0.655692078}
# {'PC1': -0.14990556, 'PC2': 0.0565575, 'PC4': 0.048744097, 'Unnamed: 0': 88, 'Name': 'CMB20', 'PC3': -0.01603368, 'Species': 'syriaca', 'V1': 0.005588913, 'PC5': 0.021707367, 'V2': 0.994411087}
# {'PC1': -0.14759964, 'PC2': 0.06258631, 'PC4': 0.04185907, 'Unnamed: 0': 89, 'Name': 'CMB28', 'PC3': -0.026102945, 'Species': 'syriaca', 'V1': 0.000153566, 'PC5': 0.018085547, 'V2': 0.999846434}
# {'PC1': -0.14696942, 'PC2': 0.13452645, 'PC4': -0.033381626, 'Unnamed: 0': 90, 'Name': 'SLG10', 'PC3': 0.020129044, 'Species': 'syriaca', 'V1': 5.06e-06, 'PC5': 0.00568278, 'V2': 0.999994941}
# {'PC1': 0.14893982, 'PC2': 0.09393406, 'PC4': 0.000167, 'Unnamed: 0': 91, 'Name': 'LFS1', 'PC3': -0.005926215, 'Species': 'exaltata', 'V1': 0.6682836329999999, 'PC5': 0.022491459, 'V2': 0.331716367}
# {'PC1': 0.20754763, 'PC2': 0.041964617, 'PC4': -0.022188267, 'Unnamed: 0': 92, 'Name': 'LFS2', 'PC3': -0.029116265, 'Species': 'exaltata', 'V1': 0.8011131340000001, 'PC5': -0.01943102, 'V2': 0.198886866}
# {'PC1': 0.23806697, 'PC2': -0.011749635, 'PC4': 0.002113408, 'Unnamed: 0': 93, 'Name': 'LFS11', 'PC3': -0.036106534, 'Species': 'exaltata', 'V1': 0.849467133, 'PC5': 0.005927893, 'V2': 0.150532867}
# {'PC1': 0.16198444, 'PC2': 0.008937688000000001, 'PC4': -0.026320282, 'Unnamed: 0': 95, 'Name': 'HR1', 'PC3': 0.012163058, 'Species': 'quadrifolia', 'V1': 0.738083374, 'PC5': 0.112699404, 'V2': 0.26191662600000004}
# {'PC1': 0.18071818, 'PC2': 0.047848243, 'PC4': -0.018857608, 'Unnamed: 0': 96, 'Name': 'PTW3', 'PC3': -0.027452221, 'Species': 'exaltata', 'V1': 0.75375204, 'PC5': -0.003543879, 'V2': 0.24624796}
# {'PC1': -0.16255394, 'PC2': 0.026945088, 'PC4': -0.00162205, 'Unnamed: 0': 98, 'Name': 'LM7', 'PC3': 0.005793692, 'Species': 'quadrifolia', 'V1': 0.000614008, 'PC5': -0.010924076, 'V2': 0.999385992}
# {'PC1': -0.14562039999999998, 'PC2': 0.011852978, 'PC4': 0.060479973, 'Unnamed: 0': 99, 'Name': 'LM15', 'PC3': -0.022589222000000003, 'Species': 'syriaca', 'V1': 0.023169081, 'PC5': 0.00362982, 'V2': 0.976830919}
# {'PC1': -0.14562447, 'PC2': 0.011604244, 'PC4': 0.000627, 'Unnamed: 0': 100, 'Name': 'LM23', 'PC3': 0.00401791, 'Species': 'syriaca', 'V1': 0.017437742, 'PC5': 0.037859425, 'V2': 0.982562258}
# {'PC1': -0.13889363, 'PC2': 0.008105108, 'PC4': -0.02436999, 'Unnamed: 0': 101, 'Name': 'MKP5', 'PC3': 0.023663571, 'Species': 'syriaca', 'V1': 0.013291859, 'PC5': 0.01749765, 'V2': 0.986708141}
# {'PC1': -0.124611475, 'PC2': -0.096212015, 'PC4': 0.006478561999999999, 'Unnamed: 0': 102, 'Name': 'RF5', 'PC3': -0.02139789, 'Species': 'syriaca', 'V1': 0.104022933, 'PC5': -0.002464153, 'V2': 0.895977067}
# {'PC1': 0.1909399, 'PC2': -0.019070385, 'PC4': -0.048950788, 'Unnamed: 0': 103, 'Name': 'LFS3', 'PC3': -0.024701202, 'Species': 'exaltata', 'V1': 0.778834365, 'PC5': -0.05607062, 'V2': 0.221165635}
# {'PC1': 0.16673444, 'PC2': 0.06515192, 'PC4': -0.03801759, 'Unnamed: 0': 104, 'Name': 'LFS12', 'PC3': -0.015066069, 'Species': 'exaltata', 'V1': 0.7453528509999999, 'PC5': 0.04161193, 'V2': 0.254647149}
# {'PC1': -0.15168317, 'PC2': 0.033857502000000005, 'PC4': -0.04868778, 'Unnamed: 0': 106, 'Name': 'RGT1', 'PC3': 0.011453482, 'Species': 'syriaca', 'V1': 7.290000000000001e-05, 'PC5': -0.019132653, 'V2': 0.999927077}
# {'PC1': 0.25719288, 'PC2': -0.12759417, 'PC4': -0.0003, 'Unnamed: 0': 107, 'Name': 'HR2', 'PC3': 0.000147, 'Species': 'quadrifolia', 'V1': 0.931272096, 'PC5': 0.15151070000000005, 'V2': 0.068727904}
# {'PC1': 0.19568281, 'PC2': 0.048862513, 'PC4': -0.024012506, 'Unnamed: 0': 108, 'Name': 'PTW4', 'PC3': -0.008012439, 'Species': 'exaltata', 'V1': 0.809388787, 'PC5': 0.031458203, 'V2': 0.190611213}
# {'PC1': -0.1480471, 'PC2': -0.00400479, 'PC4': 0.004427984, 'Unnamed: 0': 109, 'Name': 'LM8', 'PC3': -0.012604088, 'Species': 'quadrifolia', 'V1': 0.004824874, 'PC5': 0.011341558, 'V2': 0.995175126}
# {'PC1': -0.13836296, 'PC2': -0.009065274, 'PC4': 0.03991587, 'Unnamed: 0': 110, 'Name': 'LM16', 'PC3': -0.036967956, 'Species': 'syriaca', 'V1': 0.068588136, 'PC5': 0.025614455, 'V2': 0.931411864}
# {'PC1': -0.13736762, 'PC2': -0.015967635, 'PC4': 0.034792203, 'Unnamed: 0': 111, 'Name': 'LM25', 'PC3': 0.010379391, 'Species': 'syriaca', 'V1': 0.054029707, 'PC5': 0.03588726, 'V2': 0.945970293}
# {'PC1': -0.13843215, 'PC2': -0.0021776, 'PC4': -0.019851288, 'Unnamed: 0': 112, 'Name': 'MKP6', 'PC3': 0.012263763, 'Species': 'syriaca', 'V1': 0.035200284, 'PC5': 0.023509206, 'V2': 0.964799716}
# {'PC1': 0.31233385, 'PC2': -0.045830548, 'PC4': 0.017252767, 'Unnamed: 0': 113, 'Name': 'LFS4', 'PC3': -0.018572476, 'Species': 'exaltata', 'V1': 0.999998537, 'PC5': 0.011663171000000002, 'V2': 1.46e-06}
# {'PC1': 0.23658775, 'PC2': -0.001880563, 'PC4': -0.01921562, 'Unnamed: 0': 114, 'Name': 'LFS13', 'PC3': -0.033371627, 'Species': 'exaltata', 'V1': 0.889442528, 'PC5': 0.024184303, 'V2': 0.110557472}
# {'PC1': -0.14450678, 'PC2': 0.07140057, 'PC4': -0.044223584, 'Unnamed: 0': 115, 'Name': 'RGT2', 'PC3': 0.001306511, 'Species': 'syriaca', 'V1': 0.0007171069999999999, 'PC5': 0.016544733, 'V2': 0.999282893}
# {'PC1': 0.08099741, 'PC2': 0.05230351, 'PC4': -0.028569177, 'Unnamed: 0': 116, 'Name': 'HR3', 'PC3': 0.03623921, 'Species': 'quadrifolia', 'V1': 0.5561274629999999, 'PC5': 0.11539169, 'V2': 0.443872537}
# {'PC1': 0.18941139, 'PC2': 0.02003968, 'PC4': 0.003272759, 'Unnamed: 0': 117, 'Name': 'PTW5', 'PC3': -0.026029779, 'Species': 'exaltata', 'V1': 0.75492487, 'PC5': -0.02584784, 'V2': 0.24507513}
# {'PC1': -0.15242015, 'PC2': -0.009695889, 'PC4': 0.003387529, 'Unnamed: 0': 118, 'Name': 'LM1', 'PC3': -0.003288573, 'Species': 'quadrifolia', 'V1': 0.003948025, 'PC5': 0.028237233, 'V2': 0.996051975}
# {'PC1': -0.14238282, 'PC2': -0.017038868999999998, 'PC4': 0.0767193, 'Unnamed: 0': 119, 'Name': 'LM9', 'PC3': -0.027967053, 'Species': 'syriaca', 'V1': 0.052886087000000005, 'PC5': 0.048977003, 'V2': 0.947113913}
# {'PC1': -0.14447051, 'PC2': 0.026225943, 'PC4': 0.054391693, 'Unnamed: 0': 120, 'Name': 'LM17', 'PC3': -0.03602906, 'Species': 'syriaca', 'V1': 0.029370801, 'PC5': 0.04143836, 'V2': 0.970629199}
# {'PC1': -0.1463313, 'PC2': 0.000605, 'PC4': -0.005275035, 'Unnamed: 0': 121, 'Name': 'SLG21', 'PC3': -0.001109625, 'Species': 'syriaca', 'V1': 0.001928329, 'PC5': 0.018053228, 'V2': 0.998071671}
# {'PC1': -0.15203074, 'PC2': 0.052147165, 'PC4': -0.035952263, 'Unnamed: 0': 122, 'Name': 'MKP7', 'PC3': 0.016380873, 'Species': 'syriaca', 'V1': 2.07e-05, 'PC5': 0.023267692000000003, 'V2': 0.99997927}
# {'PC1': 0.2647414, 'PC2': -0.046811126, 'PC4': -0.025663568, 'Unnamed: 0': 123, 'Name': 'LFS5', 'PC3': -0.01501116, 'Species': 'exaltata', 'V1': 0.939530535, 'PC5': 0.02080563, 'V2': 0.060469465}
# {'PC1': 0.08968435, 'PC2': 0.08626045, 'PC4': -0.035358656, 'Unnamed: 0': 124, 'Name': 'LFS14', 'PC3': -0.02500519, 'Species': 'exaltata', 'V1': 0.5846500020000001, 'PC5': 0.012624532, 'V2': 0.415349998}
# {'PC1': -0.15584128, 'PC2': 0.07518308, 'PC4': -0.02951843, 'Unnamed: 0': 125, 'Name': 'RGT3', 'PC3': 0.003723146, 'Species': 'syriaca', 'V1': 4.05e-13, 'PC5': -0.011775681, 'V2': 1.0}
# {'PC1': 0.29728264, 'PC2': -0.15390638, 'PC4': 0.007508005, 'Unnamed: 0': 126, 'Name': 'HR4', 'PC3': 0.004265179, 'Species': 'quadrifolia', 'V1': 0.985029884, 'PC5': 0.14744575, 'V2': 0.014970116}
# {'PC1': 0.23300663, 'PC2': -0.012623372, 'PC4': 0.011245348999999998, 'Unnamed: 0': 127, 'Name': 'PTW6', 'PC3': -0.028743105, 'Species': 'exaltata', 'V1': 0.889679778, 'PC5': -0.004305593, 'V2': 0.110320222}
# {'PC1': -0.13248827, 'PC2': -0.09354293, 'PC4': 0.098862045, 'Unnamed: 0': 128, 'Name': 'SLG17', 'PC3': -0.024119437, 'Species': 'syriaca', 'V1': 0.119788247, 'PC5': 0.015781797, 'V2': 0.880211753}
# {'PC1': -0.15124053, 'PC2': 0.058192227, 'PC4': 0.031059628, 'Unnamed: 0': 129, 'Name': 'LM10', 'PC3': -0.005669976, 'Species': 'syriaca', 'V1': 1.1e-05, 'PC5': 0.01991905, 'V2': 0.99998903}
# {'PC1': -0.13517128, 'PC2': -0.072032504, 'PC4': 0.05020922, 'Unnamed: 0': 130, 'Name': 'LM18', 'PC3': -0.04245437, 'Species': 'syriaca', 'V1': 0.078839017, 'PC5': 0.04545799, 'V2': 0.921160983}
# {'PC1': -0.15968429, 'PC2': -0.011477605, 'PC4': -0.005382933, 'Unnamed: 0': 131, 'Name': 'LM28', 'PC3': -0.008866748, 'Species': 'syriaca', 'V1': 0.022240909, 'PC5': -0.032888845, 'V2': 0.977759091}
# {'PC1': -0.141526, 'PC2': -0.008287003000000001, 'PC4': -0.010369375, 'Unnamed: 0': 132, 'Name': 'MKP8', 'PC3': -0.005920811999999999, 'Species': 'syriaca', 'V1': 0.0014069579999999998, 'PC5': 0.014277453999999997, 'V2': 0.998593042}
# {'PC1': -0.14614856, 'PC2': 0.022480957000000003, 'PC4': -0.025468005, 'Unnamed: 0': 133, 'Name': 'RF8', 'PC3': -0.003261458, 'Species': 'syriaca', 'V1': 1.27e-05, 'PC5': 0.00607383, 'V2': 0.999987321}
# {'PC1': 0.19801289, 'PC2': 0.024757607, 'PC4': 0.000781, 'Unnamed: 0': 134, 'Name': 'LFS6', 'PC3': -0.00892086, 'Species': 'exaltata', 'V1': 0.749654248, 'PC5': 0.01066535, 'V2': 0.250345752}
# {'PC1': 0.16714054, 'PC2': 0.047781292, 'PC4': -0.021874605, 'Unnamed: 0': 135, 'Name': 'LFS15', 'PC3': -0.0247278, 'Species': 'exaltata', 'V1': 0.7502237009999999, 'PC5': -0.034045044, 'V2': 0.249776299}
# {'PC1': -0.15540215, 'PC2': 0.12540714, 'PC4': -0.04463607, 'Unnamed: 0': 136, 'Name': 'RGT4', 'PC3': 0.02480554, 'Species': 'syriaca', 'V1': 5.87e-08, 'PC5': -0.01361748, 'V2': 0.999999941}
# {'PC1': 0.22797821, 'PC2': -0.0738076, 'PC4': -0.013360748, 'Unnamed: 0': 137, 'Name': 'HR5', 'PC3': 0.011613997, 'Species': 'quadrifolia', 'V1': 0.871563798, 'PC5': 0.15522833, 'V2': 0.128436202}
# {'PC1': 0.23331234, 'PC2': -0.025517404, 'PC4': -0.021589246, 'Unnamed: 0': 138, 'Name': 'PTW7', 'PC3': -0.045188393, 'Species': 'exaltata', 'V1': 0.858935193, 'PC5': -0.045538723, 'V2': 0.141064807}
# {'PC1': 0.2342754, 'PC2': -0.10005462, 'PC4': -0.01407674, 'Unnamed: 0': 139, 'Name': 'LM3', 'PC3': -0.003106752, 'Species': 'quadrifolia', 'V1': 0.900746891, 'PC5': 0.14931569, 'V2': 0.099253109}
# {'PC1': -0.15644804, 'PC2': 0.03973245, 'PC4': 0.05426307, 'Unnamed: 0': 140, 'Name': 'LM11', 'PC3': -0.001802433, 'Species': 'syriaca', 'V1': 2.79e-06, 'PC5': 0.033506904, 'V2': 0.999997212}
# {'PC1': -0.14044514, 'PC2': -0.02565258, 'PC4': -0.002687147, 'Unnamed: 0': 141, 'Name': 'MKP1', 'PC3': 0.003046721, 'Species': 'syriaca', 'V1': 0.03928805, 'PC5': 0.011338972, 'V2': 0.96071195}
# {'PC1': -0.13320608, 'PC2': -0.08687521, 'PC4': -0.008473865, 'Unnamed: 0': 142, 'Name': 'RF1', 'PC3': -0.014813569, 'Species': 'syriaca', 'V1': 0.099873754, 'PC5': -0.022269186, 'V2': 0.9001262459999999}
# {'PC1': -0.15105805, 'PC2': 0.002563866, 'PC4': -0.037288498, 'Unnamed: 0': 143, 'Name': 'RF9', 'PC3': 0.013095847, 'Species': 'syriaca', 'V1': 0.010697208, 'PC5': -0.0138433, 'V2': 0.989302792}
# {'PC1': 0.17719644, 'PC2': 0.05958963, 'PC4': 0.002330665, 'Unnamed: 0': 144, 'Name': 'LFS7', 'PC3': -0.010165001, 'Species': 'exaltata', 'V1': 0.729682582, 'PC5': -0.008198241, 'V2': 0.27031741800000003}
# {'PC1': -0.15488304, 'PC2': 0.13445702, 'PC4': -0.04662212, 'Unnamed: 0': 147, 'Name': 'RGT5', 'PC3': 0.042844284, 'Species': 'syriaca', 'V1': 0.0004915809999999999, 'PC5': 0.011376651000000002, 'V2': 0.999508419}
# {'PC1': 0.17038587, 'PC2': 0.001165478, 'PC4': -0.026297715, 'Unnamed: 0': 148, 'Name': 'HR6', 'PC3': 0.016023548000000002, 'Species': 'quadrifolia', 'V1': 0.740682725, 'PC5': 0.13365489, 'V2': 0.259317275}
# {'PC1': 0.1286828, 'PC2': 0.037533168, 'PC4': -0.02621381, 'Unnamed: 0': 149, 'Name': 'PTW8', 'PC3': 0.02752873, 'Species': 'exaltata', 'V1': 0.622845958, 'PC5': 0.11247898, 'V2': 0.377154042}
# {'PC1': -0.14721128, 'PC2': -0.002324198, 'PC4': 0.05884237, 'Unnamed: 0': 150, 'Name': 'LM12', 'PC3': -0.01882453, 'Species': 'syriaca', 'V1': 0.006060674, 'PC5': 0.016840542, 'V2': 0.993939326}
# {'PC1': -0.14461689, 'PC2': 0.055093754, 'PC4': 0.006439617, 'Unnamed: 0': 151, 'Name': 'LM20', 'PC3': 0.02695653, 'Species': 'syriaca', 'V1': 3.15e-07, 'PC5': 0.024980776, 'V2': 0.999999685}
# {'PC1': -0.14775181, 'PC2': -4.52e-05, 'PC4': -0.025417019, 'Unnamed: 0': 152, 'Name': 'MKP2', 'PC3': 0.001904717, 'Species': 'syriaca', 'V1': 0.022972569, 'PC5': 0.02902095, 'V2': 0.977027431}
# {'PC1': -0.13806543, 'PC2': -0.001010613, 'PC4': -0.017658273000000002, 'Unnamed: 0': 153, 'Name': 'RF2', 'PC3': 0.003304543, 'Species': 'syriaca', 'V1': 0.073558211, 'PC5': -0.021717524, 'V2': 0.926441789}
# {'PC1': -0.13720673, 'PC2': 0.029903393, 'PC4': -0.04876577, 'Unnamed: 0': 154, 'Name': 'RF10', 'PC3': 0.022271907, 'Species': 'syriaca', 'V1': 0.040955178, 'PC5': -0.010880322, 'V2': 0.959044822}
# {'PC1': 0.18760914, 'PC2': 0.018774865, 'PC4': -0.0299861, 'Unnamed: 0': 155, 'Name': 'LFS8', 'PC3': -0.0498852, 'Species': 'exaltata', 'V1': 0.757396793, 'PC5': 0.019067645, 'V2': 0.242603207}
# {'PC1': -0.15684064, 'PC2': 0.05008417, 'PC4': -0.00561308, 'Unnamed: 0': 158, 'Name': 'RGT6', 'PC3': -0.008351219, 'Species': 'syriaca', 'V1': 2.87e-05, 'PC5': 0.016766625, 'V2': 0.999971273}
# {'PC1': 0.2555181, 'PC2': -0.016012326, 'PC4': -0.002274369, 'Unnamed: 0': 159, 'Name': 'PTW1', 'PC3': -0.029967714, 'Species': 'exaltata', 'V1': 0.91275769, 'PC5': -0.010248253, 'V2': 0.08724231}
# {'PC1': 0.13831177, 'PC2': 0.001287779, 'PC4': -0.025895609, 'Unnamed: 0': 160, 'Name': 'PTW9', 'PC3': 0.00131856, 'Species': 'exaltata', 'V1': 0.6860401159999999, 'PC5': 0.11134447, 'V2': 0.313959884}
# {'PC1': -0.15562636, 'PC2': 0.023697168, 'PC4': 0.053919375, 'Unnamed: 0': 161, 'Name': 'LM13', 'PC3': -0.018368958, 'Species': 'syriaca', 'V1': 0.006113067, 'PC5': 0.04733111, 'V2': 0.993886933}
# {'PC1': -0.16491607, 'PC2': 0.112124786, 'PC4': -0.015419437, 'Unnamed: 0': 162, 'Name': 'LM21', 'PC3': 0.027006945, 'Species': 'syriaca', 'V1': 0.000919164, 'PC5': 0.016364114, 'V2': 0.999080836}
# {'PC1': -0.13771477, 'PC2': -0.029469365, 'PC4': 0.002276755, 'Unnamed: 0': 163, 'Name': 'MKP3', 'PC3': 0.015887395, 'Species': 'syriaca', 'V1': 0.0583956, 'PC5': 0.042584646, 'V2': 0.9416044}
# {'PC1': -0.13893817, 'PC2': -0.028526489, 'PC4': -0.030669004, 'Unnamed: 0': 164, 'Name': 'RF3', 'PC3': 0.006190492, 'Species': 'syriaca', 'V1': 0.015852256999999998, 'PC5': -0.01667366, 'V2': 0.984147743}
# {'PC1': -0.14768954, 'PC2': 0.014420991, 'PC4': -0.031881016, 'Unnamed: 0': 165, 'Name': 'RF11', 'PC3': 0.010717831, 'Species': 'syriaca', 'V1': 0.006685551, 'PC5': -0.0052710890000000005, 'V2': 0.993314449}
# {'PC1': 0.05297256, 'PC2': 0.14661801, 'PC4': -0.01699149, 'Unnamed: 0': 166, 'Name': 'LFS9', 'PC3': 0.003782139, 'Species': 'exaltata', 'V1': 0.465791189, 'PC5': 0.0017241429999999998, 'V2': 0.5342088110000001}
# {'PC1': -0.15302967, 'PC2': 0.06914793, 'PC4': 0.0008300000000000001, 'Unnamed: 0': 169, 'Name': 'RGT7', 'PC3': 0.015915968, 'Species': 'syriaca', 'V1': 6.5e-07, 'PC5': -0.008221841, 'V2': 0.99999935}
# {'PC1': 0.2551193, 'PC2': -0.039583184, 'PC4': -0.017520392, 'Unnamed: 0': 170, 'Name': 'PTW2', 'PC3': -0.014060517, 'Species': 'exaltata', 'V1': 0.900575798, 'PC5': -0.018805088, 'V2': 0.099424202}
# {'PC1': -0.06581477, 'PC2': 0.06480811, 'PC4': -0.016633323999999998, 'Unnamed: 0': 171, 'Name': 'PTW10', 'PC3': -0.019444795, 'Species': 'exaltata', 'V1': 0.211879229, 'PC5': -0.014888222, 'V2': 0.7881207709999999}
# {'PC1': -0.14492443, 'PC2': 0.056391615, 'PC4': 0.038071696, 'Unnamed: 0': 172, 'Name': 'LM14', 'PC3': -0.007988784, 'Species': 'syriaca', 'V1': 3.79e-06, 'PC5': 0.01377531, 'V2': 0.999996209}
# {'PC1': -0.15881658, 'PC2': 0.06644624, 'PC4': -0.005051349, 'Unnamed: 0': 173, 'Name': 'LM22', 'PC3': 0.016647764, 'Species': 'syriaca', 'V1': 0.00386255, 'PC5': 0.025458593, 'V2': 0.99613745}
# {'PC1': -0.15207084, 'PC2': 0.014235663, 'PC4': -0.018206552, 'Unnamed: 0': 174, 'Name': 'MKP4', 'PC3': 0.012283466000000002, 'Species': 'syriaca', 'V1': 2.38e-06, 'PC5': 0.018659767, 'V2': 0.999997617}
# {'PC1': -0.13496968, 'PC2': -0.003746383, 'PC4': -0.003660792, 'Unnamed: 0': 175, 'Name': 'RF4', 'PC3': -0.002667669, 'Species': 'syriaca', 'V1': 0.067115809, 'PC5': -0.008746539000000001, 'V2': 0.932884191}
# {'PC1': -0.13687366, 'PC2': 0.008389514, 'PC4': -0.002656518, 'Unnamed: 0': 176, 'Name': 'RF12', 'PC3': 0.022290774, 'Species': 'syriaca', 'V1': 0.066615797, 'PC5': -0.010559208, 'V2': 0.933384203}

# %%
conn.commit()

# %%
sql = """
CREATE VIEW tPlantDNA AS 

SELECT *
;"""

test_df = pd.read_sql("SELECT * FROM tPlantDNA;", conn)

# %%
test_df.head()
# Out:
#   sample_id        V1        V2   species       PC1       PC2       PC3  \
# 0      RRL1  0.753244  0.246756  exaltata  0.194769  0.048276 -0.023880
# 1      RRL9  0.581366  0.418634  exaltata  0.097719  0.094733 -0.006560
# 2     RRL17  0.591513  0.408487  exaltata  0.099527  0.091996  0.004098
# 3      FRW3  0.048066  0.951934   syriaca -0.139465 -0.064022 -0.009963
# 4     FRW12  0.003946  0.996054   syriaca -0.155135  0.055455  0.009907
#
#         PC4       PC5
# 0 -0.017138 -0.039842
# 1  0.012822 -0.022248
# 2 -0.021347  0.007190
# 3 -0.047536  0.024757
# 4 -0.043334 -0.009337

# %%
conn.close()
