# %%
import pandas as pd
import numpy as np
import sqlite3

# %% [markdown]
# # Create DB File and Connect

# %%
# can add STRICT to the end of generating a table to produce a strict adherence to data types

# can use "CHECK(len(loc_id) == 1)"
# can use anything that evaluates to true or false

# %%
# Connect to the database. If it does not exist, it will be created
conn = sqlite3.connect('test3.db')
# Create a cursor object. This is how we interact with the database
curs = conn.cursor()


### IMPORTANT!!! ###
# By default, sqlite does not enforce foreign key constraints. 
# According to the documentation, this is for backwards compatibility. You have to turn them on yourself.
curs.execute('PRAGMA foreign_keys=ON;')

# %% [markdown]
# ## Define and Create TSample

# %%
# Define the tables

# If running this more than once, you'll need to drop the table before you can redefine it

curs.execute("DROP TABLE IF EXISTS tSample;")

sql = """
CREATE TABLE tSample (
    sample_id TEXT PRIMARY KEY,
    site_id TEXT,
    collect_date DATETIME
)
;"""
curs.execute(sql)

# %%
tsampledf = pd.read_csv('./csv_folder/sample.csv')

# %%
# INSERT INTO (column names) VALUES (values to insert)
# The : indicates parameter names.
# They do not need to be the same as the columns we are inserting into, but it helps keep the code clean.
# They are matched up in order. For example, if instead of :lat I called it :x, then :x would be inserted into
# the lat column, since lat is the second column in the list of column names.
sql = """
INSERT INTO tSample (sample_id, site_id, collect_date) VALUES (:sample_id, :site_id, :date)
;"""

# I'm going to loop over the dataframe such that each row will be returned as a dictionary.
# The keys for the dictionary will be the column names, and the values will be the values in the dataframe.
# I've ensured that the names in my dataframe match exactly the parameter names above - the way this works
# is that SQL will look for that key in the dictionary.  For example, since I have a parameter :loc_id, 
# it will look for a key in the dictionary called loc_id.





for row in tsampledf.to_dict(orient='records'):
    # Uncomment this to see the dictionaries
    #print(row)
    
    # The second input for curs.execute() are parameters
    curs.execute(sql, row)

# %%
sql = """
CREATE VIEW tSample AS 

SELECT *
;"""

pd.read_sql("SELECT * FROM tSample;", conn)
# Out:
#     sample_id site_id collect_date
# 0      BLDTT0     BLD    6/29/2020
# 1      BLDTT1     BLD    6/29/2020
# 2      BLDTT2     BLD    6/29/2020
# 3      BLDTT3     BLD    6/29/2020
# 4      BLDTT4     BLD    6/29/2020
# ..        ...     ...          ...
# 435     PNR12     PNR     7/5/2021
# 436     PNR13     PNR     7/5/2021
# 437     PNR14     PNR     7/5/2021
# 438     PNR15     PNR     7/5/2021
# 439     PNR16     PNR     7/5/2021
#
# [440 rows x 3 columns]

# %% [markdown]
# ## Define and Create TMorphology

# %%
tmorphdf = pd.read_csv('./csv_folder/plant_morphology.csv')
tmorphdf.shape
# Out:
# (493, 12)

# %%
tmorphdf = tmorphdf.rename(columns={'Ht(cm)': 'plant_ht', '# Leaves': 'num_leaves', 'Length LL (cm)': 'longest_leaf_cm',
                                     'Width LL (cm)': 'widest_leaf_cm', 'Stem Diameter (mm)': 'stem_diam_mm',
                                     '# Inflorescences': 'num_inflores', '# Flowers Per (x2)': 'num_flowers',
                                     'Herbivory': 'herbivory', 'Species': 'species'})
tmorphdf = tmorphdf.drop('date', axis= 1)
tmorphdf = tmorphdf.drop('site_id',  axis = 1)
tmorphdf.head()
# Out:
#   sample_id species  plant_ht num_leaves longest_leaf_cm  widest_leaf_cm  \
# 0    BLDTT0     NaN      93.3         22            16.5             7.3
# 1    BLDTT0     NaN       NaN        NaN             NaN             NaN
# 2    BLDTT1     NaN      70.7         14            15.4             7.1
# 3    BLDTT1     NaN       NaN        NaN             NaN             NaN
# 4    BLDTT2     NaN      83.4         18            15.6             7.4
#
#    stem_diam_mm num_inflores   num_flowers herbivory
# 0          10.5            5  46(1), 53(1)  1=5, 2=1
# 1           NaN          NaN           NaN       NaN
# 2           8.9            5  20(2), 25(5)  1=2, 2=3
# 3           NaN          NaN           NaN       NaN
# 4          11.9            7  24(3), 19(4)  1=3, 2=1

# %%
tmorphdf = tmorphdf.drop_duplicates(subset=['sample_id'])
tmorphdf.shape
# Out:
# (440, 10)

# %%
# Define the tables

# If running this more than once, you'll need to drop the table before you can redefine it

curs.execute("DROP TABLE IF EXISTS tMorphology;")

sql = """
CREATE TABLE tMorphology (
    sample_id TEXT PRIMARY KEY,
    species TEXT,
    plant_ht REAL,
    num_leaves INTEGER,
    longest_leaf_cm REAL,
    widest_leaf_cm REAL,
    stem_diam_mm REAL,
    num_inflores INTEGER,
    num_flowers INTEGER,
    herbivory TEXT
)
;"""
curs.execute(sql)

# INSERT INTO (column names) VALUES (values to insert)
# The : indicates parameter names.
# They do not need to be the same as the columns we are inserting into, but it helps keep the code clean.
# They are matched up in order. For example, if instead of :lat I called it :x, then :x would be inserted into
# the lat column, since lat is the second column in the list of column names.
sql = """
INSERT INTO tMorphology (sample_id, species, plant_ht, num_leaves,
    longest_leaf_cm, widest_leaf_cm, stem_diam_mm, num_inflores,
    num_flowers, herbivory) VALUES (:sample_id, :species, :plant_ht, :num_leaves,
    :longest_leaf_cm, :widest_leaf_cm, :stem_diam_mm, :num_inflores,
    :num_flowers, :herbivory)
;"""

# I'm going to loop over the dataframe such that each row will be returned as a dictionary.
# The keys for the dictionary will be the column names, and the values will be the values in the dataframe.
# I've ensured that the names in my dataframe match exactly the parameter names above - the way this works

# is that SQL will look for that key in the dictionary.  For example, since I have a parameter :loc_id, 
# it will look for a key in the dictionary called loc_id.





for row in tmorphdf.to_dict(orient='records'):
    # Uncomment this to see the dictionaries
    #print(row)
    
    # The second input for curs.execute() are parameters
    curs.execute(sql, row)

# %% [markdown]
# ## Create TSoilNutrients

# %%
curs.execute("DROP TABLE IF EXISTS tSoilNutrients;")
#Organic Matter % Rate	Estimated Nitrogen Release (lbs/A)	Cation Exchange Capacity (meq/100g)	
#pH	Buffer pH	Phosphorus ppm	Potassium ppm	Calcium ppm	Magnesium ppm	
#Sulfur ppm	Sodium ppm	Zinc ppm	Manganese ppm	Iron ppm	Copper ppm	Boron ppm

sql = """
CREATE TABLE tSoilNutrients (
    sample_id TEXT NOT NULL REFERENCES tSample(sample_id),
    OM REAL,
    ENR REAL,
    CEC REAL,
    pH REAL,
    BpH REAL,
    Phosphorus REAL,
    Potassium REAL,
    Calcium REAL,
    Magnesium REAL,
    Sulfur REAL,
    Sodium REAL,
    Zinc REAL,
    Manganese REAL,
    Iron REAL,
    Copper REAL,
    Boron REAL,
    PRIMARY KEY (sample_id)
)
;"""

curs.execute(sql)

# %%
tsoilnutrientdf = pd.read_csv('./csv_folder/soil_nutrients.csv')
tsoilnutrientdf.shape
# Out:
# (423, 18)

# %%
tsoilnutrientdf = tsoilnutrientdf.drop('site', axis = 1)

# %%
tsoilnutrientdf = tsoilnutrientdf.drop_duplicates('sample_id')

# %%
tsoilnutrientdf.tail()
# Out:
#     sample_id   OM  ENR   CEC   pH   BpH  Phosphorus  Potassium  Calcium  \
# 418     PNR13  5.8  142  20.4  7.7  6.93          21         78     3777
# 419     PNR14  4.2  110  22.3  7.6  6.93           9         45     4217
# 420     PNR15  3.6   98  18.7  7.7  6.93           8         42     3472
# 421      PNR8  3.7  100  17.9  7.6  6.93          12         37     3335
# 422      PNR9  3.7  100  18.7  7.5  6.93          18         48     3457
#
#      Magnesium  Sulfur  Sodium  Zinc  Manganese  Iron  Copper  Boron
# 418        155      12      13   3.7         98    92     1.1    1.1
# 419        131       9      13   2.1         36   156     1.2    0.5
# 420        143      13      13   2.5         51   135     1.2    0.7
# 421        124       9      14   1.5         35    59     0.7    0.5
# 422        147       7      13   1.6         39    62     0.8    0.7

# %%
soil_list = tsoilnutrientdf['sample_id'].tolist()
temp_list = []
for i in soil_list:
    if i[0] == '8':
        temp_list.append(i)

for i in temp_list:
    tsoilnutrientdf.drop(tsoilnutrientdf[(tsoilnutrientdf['sample_id'] == i)].index, inplace=True)
    tsoilnutrientdf.drop(tsoilnutrientdf[(tsoilnutrientdf['sample_id'] == 'BLDRV1-')].index, inplace=True)
    tsoilnutrientdf.drop_duplicates(subset="sample_id",
                             keep='first', inplace=True)
soil_list = tsoilnutrientdf['sample_id'].tolist()
for i in range(len(soil_list)):
    if soil_list[i][0] == '1':
        soil_list[i] = soil_list[i][1:]
    if soil_list[i][0] == ' ':
        soil_list[i] = soil_list[i][1:]
print(len(soil_list))
# Out:
# 368

# %%
tsoilnutrientdf['sample_id'] = soil_list
tsoilnutrientdf.tail()
# Out:
#     sample_id   OM  ENR   CEC   pH   BpH  Phosphorus  Potassium  Calcium  \
# 418     PNR13  5.8  142  20.4  7.7  6.93          21         78     3777
# 419     PNR14  4.2  110  22.3  7.6  6.93           9         45     4217
# 420     PNR15  3.6   98  18.7  7.7  6.93           8         42     3472
# 421      PNR8  3.7  100  17.9  7.6  6.93          12         37     3335
# 422      PNR9  3.7  100  18.7  7.5  6.93          18         48     3457
#
#      Magnesium  Sulfur  Sodium  Zinc  Manganese  Iron  Copper  Boron
# 418        155      12      13   3.7         98    92     1.1    1.1
# 419        131       9      13   2.1         36   156     1.2    0.5
# 420        143      13      13   2.5         51   135     1.2    0.7
# 421        124       9      14   1.5         35    59     0.7    0.5
# 422        147       7      13   1.6         39    62     0.8    0.7

# %%
# INSERT INTO (column names) VALUES (values to insert)
# The : indicates parameter names.
# They do not need to be the same as the columns we are inserting into, but it helps keep the code clean.
# They are matched up in order. For example, if instead of :lat I called it :x, then :x would be inserted into
# the lat column, since lat is the second column in the list of column names.
sql = """
INSERT INTO tSoilNutrients (sample_id, OM, ENR, CEC, pH, BpH,
    Phosphorus, Potassium, Calcium, Magnesium, Sulfur, Sodium,
    Zinc, Manganese, Iron, Copper, Boron) VALUES (:sample_id, :OM, :ENR, :CEC, :pH, :BpH,
    :Phosphorus, :Potassium, :Calcium, :Magnesium, :Sulfur, :Sodium,
    :Zinc, :Manganese, :Iron, :Copper, :Boron)
;"""


# I'm going to loop over the dataframe such that each row will be returned as a dictionary.
# The keys for the dictionary will be the column names, and the values will be the values in the dataframe.
# I've ensured that the names in my dataframe match exactly the parameter names above - the way this works
# is that SQL will look for that key in the dictionary.  For example, since I have a parameter :loc_id, 
# it will look for a key in the dictionary called loc_id.





for row in tsoilnutrientdf.to_dict(orient='records'):
    # Uncomment this to see the dictionaries
    
    # The second input for curs.execute() are parameters
    curs.execute(sql, row)

# %%
sql = """
CREATE VIEW tSoilNutrients AS 

SELECT *
;"""

pd.read_sql("SELECT * FROM tSoilNutrients;", conn)
# Out:
#     sample_id   OM    ENR   CEC   pH   BpH  Phosphorus  Potassium  Calcium  \
# 0      BLDTT0  4.3  124.0   8.1  6.8  6.91        18.0      180.0   1193.0
# 1     BLDTT11  4.7  135.0   6.6  6.0  6.83        22.0      195.0    781.0
# 2     BLDTT12  4.6  133.0   6.6  6.1  6.84        23.0      266.0    770.0
# 3     BLDTT13  4.9  138.0   6.8  6.1  6.84        24.0      270.0    741.0
# 4     BLDTT14  5.4  148.0   7.3  5.8  6.79        32.0      229.0    766.0
# ..        ...  ...    ...   ...  ...   ...         ...        ...      ...
# 363     PNR13  5.8  142.0  20.4  7.7  6.93        21.0       78.0   3777.0
# 364     PNR14  4.2  110.0  22.3  7.6  6.93         9.0       45.0   4217.0
# 365     PNR15  3.6   98.0  18.7  7.7  6.93         8.0       42.0   3472.0
# 366      PNR8  3.7  100.0  17.9  7.6  6.93        12.0       37.0   3335.0
# 367      PNR9  3.7  100.0  18.7  7.5  6.93        18.0       48.0   3457.0
#
#      Magnesium  Sulfur  Sodium  Zinc  Manganese   Iron  Copper  Boron
# 0        178.0     3.0     7.0   2.3      321.0   78.0     1.5    0.5
# 1        138.0     5.0     9.0   1.9       85.0   76.0     1.0    0.4
# 2        131.0     5.0     9.0   1.6       78.0   82.0     0.9    0.3
# 3        175.0     1.0     9.0   2.2       76.0   80.0     1.1    0.3
# 4        172.0     8.0     9.0   2.6       64.0   87.0     1.0    0.3
# ..         ...     ...     ...   ...        ...    ...     ...    ...
# 363      155.0    12.0    13.0   3.7       98.0   92.0     1.1    1.1
# 364      131.0     9.0    13.0   2.1       36.0  156.0     1.2    0.5
# 365      143.0    13.0    13.0   2.5       51.0  135.0     1.2    0.7
# 366      124.0     9.0    14.0   1.5       35.0   59.0     0.7    0.5
# 367      147.0     7.0    13.0   1.6       39.0   62.0     0.8    0.7
#
# [368 rows x 17 columns]

# %% [markdown]
# ## Create and fill table TPlantNutrients

# %%
curs.execute("DROP TABLE IF EXISTS tPlantNutrients;")


sql = """
CREATE TABLE tPlantNutrients (
    sample_id TEXT NOT NULL REFERENCES tSample(sample_id),
    N_percent_dm REAL,
    P_percent_dm REAL,
    K_percent_dm REAL,
    Ca_percent_dm REAL,
    Mg_percent_dm REAL,
    Na_percent_dm REAL,
    S_percent_dm REAL,
    Zn_ppm_dm REAL,
    Mn_ppm_dm REAL,
    Fe_ppm_dm REAL,
    Cu_ppm_dm REAL,
    B_ppm_dm REAL,
    Al_ppm_dm REAL,
    PRIMARY KEY (sample_id)
)
;"""
curs.execute(sql)

# %%
tleafnutrientdf = pd.read_csv('./csv_folder/leaf_nutrients.csv')

# %%
tleafnutrientdf.shape
# Out:
# (223, 14)

# %%
sql = """
INSERT INTO tPlantNutrients (sample_id, N_percent_dm, P_percent_dm, K_percent_dm, Ca_percent_dm, 
Mg_percent_dm, Na_percent_dm, S_percent_dm, Zn_ppm_dm, Mn_ppm_dm, Fe_ppm_dm, Cu_ppm_dm, B_ppm_dm, Al_ppm_dm)
VALUES (:Sample_ID, :N_percent_dm, :P_percent_dm, :K_percent_dm, :Ca_percent_dm, 
:Mg_percent_dm, :Na_percent_dm, :S_percent_dm, :Zn_ppm_dm, :Mn_ppm_dm, :Fe_ppm_dm, :Cu_ppm_dm, :B_ppm_dm, :Al_ppm_dm)
;"""

# I'm going to loop over the dataframe such that each row will be returned as a dictionary.
# The keys for the dictionary will be the column names, and the values will be the values in the dataframe.
# I've ensured that the names in my dataframe match exactly the parameter names above - the way this works
# is that SQL will look for that key in the dictionary.  For example, since I have a parameter :loc_id, 
# it will look for a key in the dictionary called loc_id.





for row in tleafnutrientdf.to_dict(orient='records'):
    # Uncomment this to see the dictionaries
    #print(row)
    
    # The second input for curs.execute() are parameters
    curs.execute(sql, row)

# %%
sql = """
CREATE VIEW tPlantNutrients AS 

SELECT *
;"""

pd.read_sql("SELECT * FROM tPlantNutrients;", conn)
# Out:
#     sample_id  N_percent_dm  P_percent_dm  K_percent_dm  Ca_percent_dm  \
# 0        RRL1           NaN          0.21          4.01           0.83
# 1        RRL2          2.24          0.16          5.34           1.05
# 2        RRL3           NaN          0.20          4.75           0.63
# 3        RRL4           NaN          0.18          4.74           1.25
# 4        RRL5          3.00          0.26          3.51           1.20
# ..        ...           ...           ...           ...            ...
# 218     PNR11          3.34          0.48          3.56           1.50
# 219     PNR13          1.91          0.21          1.55           2.33
# 220     PNR14          2.91          0.24          2.32           2.03
# 221     PNR15          2.72          0.22          2.13           2.40
# 222     PNR16          2.00          0.20          1.48           2.89
#
#      Mg_percent_dm  Na_percent_dm  S_percent_dm  Zn_ppm_dm  Mn_ppm_dm  \
# 0             0.29           0.01          0.37       29.0      281.0
# 1             0.32           0.01          0.29       20.0      423.0
# 2             0.27           0.04          0.22       21.0      469.0
# 3             0.32           0.01          0.28       18.0      680.0
# 4             0.44           0.01          0.29       29.0      507.0
# ..             ...            ...           ...        ...        ...
# 218           0.36           0.01          0.28       24.0       90.0
# 219           0.55           0.01          0.35       13.0       39.0
# 220           0.53           0.08          0.32       14.0       71.0
# 221           0.60           0.06          0.38       12.0       30.0
# 222           0.71           0.01          0.45       16.0       38.0
#
#      Fe_ppm_dm  Cu_ppm_dm  B_ppm_dm  Al_ppm_dm
# 0        234.0        8.0      24.0      130.0
# 1         76.0        5.0      27.0       36.0
# 2         68.0        5.0      32.0       18.0
# 3         78.0        6.0      36.0       27.0
# 4         66.0        7.0      23.0       22.0
# ..         ...        ...       ...        ...
# 218       53.0       14.0      33.0       18.0
# 219      103.0        5.0      21.0       40.0
# 220       67.0        6.0      25.0       21.0
# 221       50.0        6.0      34.0       26.0
# 222       48.0        4.0      28.0       17.0
#
# [223 rows x 14 columns]

# %% [markdown]
# ## Create and Fill Soil Micro Table

# %%
curs.execute("DROP TABLE IF EXISTS tSoilMicrobeGenera;")

sql = """
CREATE TABLE tSoilMicrobeGenera (
    sample_id TEXT NOT NULL REFERENCES tSample(sample_id),
    genera REAL,
    relative_abundance REAL,
    PRIMARY KEY (sample_id, genera)
)
;"""
curs.execute(sql)

# %%
tsoilmicrobe = pd.read_csv('./csv_folder/final_soil_microbe.csv')

# %%
sql = """
INSERT INTO tSoilMicrobeGenera (sample_id, genera, relative_abundance)
VALUES (:sample_id, :genera, :relative_abundance)
;"""

# I'm going to loop over the dataframe such that each row will be returned as a dictionary.
# The keys for the dictionary will be the column names, and the values will be the values in the dataframe.
# I've ensured that the names in my dataframe match exactly the parameter names above - the way this works
# is that SQL will look for that key in the dictionary.  For example, since I have a parameter :loc_id, 
# it will look for a key in the dictionary called loc_id.





for row in tsoilmicrobe.to_dict(orient='records'):
    # Uncomment this to see the dictionaries
    #print(row)
    
    # The second input for curs.execute() are parameters
    curs.execute(sql, row)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Input In [58], in <cell line: 16>()
#       6 # I'm going to loop over the dataframe such that each row will be returned as a dictionary.
#       7 # The keys for the dictionary will be the column names, and the values will be the values in the dataframe.
#       8 # I've ensured that the names in my dataframe match exactly the parameter names above - the way this works
#       9 # is that SQL will look for that key in the dictionary.  For example, since I have a parameter :loc_id,
#      10 # it will look for a key in the dictionary called loc_id.
#      16 for row in tsoilmicrobe.to_dict(orient='records'):
#      17     # Uncomment this to see the dictionaries
#      18     #print(row)
#      19
#      20     # The second input for curs.execute() are parameters
# ---> 21     curs.execute(sql, row)
#
# IntegrityError: FOREIGN KEY constraint failed

# %%
sql = """
CREATE VIEW tMorphology AS 

SELECT *
;"""

pd.read_sql("SELECT * FROM tMorphology;", conn)
# Out:
#     sample_id   species  plant_ht        num_leaves longest_leaf_cm  \
# 0      BLDTT0      None      93.3                22            16.5
# 1      BLDTT1      None      70.7                14            15.4
# 2      BLDTT2      None      83.4                18            15.6
# 3      BLDTT3      None      44.9                 9             7.5
# 4      BLDTT4      None      78.8                17            13.9
# 5      BLDTT5      None      49.4                10             8.5
# 6      BLDTT6      None      70.4                16            11.6
# 7      BLDTT7      None      40.1                 1             5.1
# 8      BLDTT8      None      41.8                 6             6.3
# 9      BLDTT9      None      59.9                15            11.2
# 10    BLDTT10      None      37.6                 8             7.5
# 11    BLDTT11      None      67.1                14            10.4
# 12    BLDTT12      None      39.9                 8             8.2
# 13    BLDTT13      None      39.1                12            11.8
# 14    BLDTT14      None      26.4                10             9.8
# 15    BLDTT15      None      69.8                16            13.8
# 16    BLDTT16      None      53.5                16            13.1
# 17    BLDTT17      None      57.4                15            12.6
# 18    BLDTT18      None      42.9                10              10
# 19    BLDTT19      None      75.8                17              15
# 20    BLDTT20      None      65.6                16            14.6
# 21    BLDTT21      None      31.1                11              11
# 22    BLDTT22      None      66.8                18            14.6
# 23    BLDTT23      None      39.4                11            10.2
# 24    BLDTT24      None      76.2                22            16.4
# 25    BLDTT25      None      61.3                18            12.8
# 26    BLDTT26      None      34.1                13              10
# 27    BLDTT27      None      45.5                19            11.7
# 28    BLDTT28      None      49.2                13            12.4
# 29    BLDTT29      None      72.5                18            13.5
# ..        ...       ...       ...               ...             ...
# 410      RF10   syriaca     112.0                26            None
# 411      RF11   syriaca     103.0                22            None
# 412      RF12   syriaca     103.0                19            None
# 413      RF13  exaltata      92.0  [nothing listed]            None
# 414      TCP1   syriaca       NaN              None            None
# 415      TCP2   syriaca       NaN              None            None
# 416      TCP3   syriaca       NaN              None            None
# 417      TCP4   syriaca       NaN              None            None
# 418      TCP5   syriaca       NaN              None            None
# 419      TCP6   syriaca       NaN              None            None
# 420      TCP7   syriaca       NaN              None            None
# 421      TCP8   syriaca       NaN              None            None
# 422      TCP9   syriaca       NaN              None            None
# 423     TCP10   syriaca       NaN              None            None
# 424      PNR1   syriaca     104.0                17            None
# 425      PNR2    hybrid     114.0                17            None
# 426      PNR3   syriaca      96.0                19            None
# 427      PNR4    hybrid     101.0                20            None
# 428      PNR5   syriaca     123.0                20            None
# 429      PNR6    hybrid     135.0                20            None
# 430      PNR7    hybrid     148.0                19            None
# 431      PNR8    hybrid     132.0                22            None
# 432      PNR9    hybrid     149.0                19            None
# 433     PNR10      None       NaN              None            None
# 434     PNR11    hybrid     145.0                19            None
# 435     PNR12      None       NaN              None            None
# 436     PNR13   syriaca     144.0                22            None
# 437     PNR14    hybrid     150.0                14            None
# 438     PNR15   syriaca     146.0                13            None
# 439     PNR16   syriaca     172.0                24            None
#
#      widest_leaf_cm  stem_diam_mm num_inflores   num_flowers  \
# 0               7.3          10.5            5  46(1), 53(1)
# 1               7.1           8.9            5  20(2), 25(5)
# 2               7.4          11.9            7  24(3), 19(4)
# 3               3.6           3.6            0          None
# 4               7.2          10.5            3  21(5), 26(2)
# 5               4.3           5.4            0          None
# 6               5.6           6.7            0          None
# 7               3.4           6.8            0          None
# 8               3.3           4.4            0          None
# 9               5.9           8.7            0          None
# 10              3.3           3.3            0          None
# 11              5.7           7.3            2   NA(7), 2(6)
# 12              3.9           5.0            0          None
# 13              5.3           7.6            0          None
# 14              4.1           4.5            0          None
# 15              6.5          13.5            4  62(1), 58(1)
# 16              6.2           8.5            2   5(0), 65(0)
# 17              5.7           8.4            2  61(1), 57(0)
# 18              7.5           6.4            0          None
# 19              7.0          14.0            5  61(5), 57(5)
# 20              6.9          13.0            6  50(1), 61(1)
# 21              4.2           5.4            0          None
# 22              6.8          10.7            4  45(5), 48(2)
# 23              3.9           7.4            0          None
# 24              8.0          12.7            5  51(5), 53(1)
# 25              7.5          16.1            3  65(0), 58(0)
# 26              4.1           4.0            0          None
# 27              4.1           6.0            0          None
# 28              5.6           6.8            3  47(2), 13(1)
# 29              5.5           9.4            5  54(5), 41(3)
# ..              ...           ...          ...           ...
# 410             NaN          14.0            5          None
# 411             NaN          12.0            1          None
# 412             NaN           9.0            4          None
# 413             NaN           7.0            4          None
# 414             NaN           NaN         None          None
# 415             NaN           NaN         None          None
# 416             NaN           NaN         None          None
# 417             NaN           NaN         None          None
# 418             NaN           NaN         None          None
# 419             NaN           NaN         None          None
# 420             NaN           NaN         None          None
# 421             NaN           NaN         None          None
# 422             NaN           NaN         None          None
# 423             NaN           NaN         None          None
# 424             NaN           9.0            0          None
# 425             NaN          12.0            1          None
# 426             NaN          10.0            0          None
# 427             NaN           9.0            0          None
# 428             NaN          11.0            1          None
# 429             NaN          13.0            2          None
# 430             NaN          14.0            3          None
# 431             NaN          11.0            1          None
# 432             NaN          15.0            3          None
# 433             NaN           NaN         None          None
# 434             NaN          12.0            2          None
# 435             NaN           NaN         None          None
# 436             NaN           8.0            5          None
# 437             NaN           9.0            6          None
# 438             NaN           9.0            5          None
# 439             NaN          11.0            4          None
#
#               herbivory
# 0              1=5, 2=1
# 1              1=2, 2=3
# 2              1=3, 2=1
# 3              1=3, 2=5
# 4              1=3, 2=2
# 5              1=2, 2=4
# 6         1=9, 2=4, 3=1
# 7                   2=1
# 8              1=1, 2=3
# 9              1=6, 2=5
# 10        1=2, 2=2, 3=1
# 11             1=3, 2=2
# 12             1=3, 2=5
# 13             1=1, 2=5
# 14   1=4, 2=3, 3=1, 4=1
# 15             1=2, 2=2
# 16             1=3, 2=2
# 17                  2=2
# 18             1=6, 2=3
# 19             1=3, 2=1
# 20                  1=3
# 21             1=3, 2=1
# 22             1=1, 2=1
# 23                  1=1
# 24             1=2, 2=2
# 25             1=2, 2=2
# 26             1=2, 2=3
# 27                  1=4
# 28             1=5, 2=1
# 29                  1=3
# ..                  ...
# 410                none
# 411                none
# 412                none
# 413                 1=1
# 414                None
# 415                None
# 416                None
# 417                None
# 418                None
# 419                None
# 420                None
# 421                None
# 422                None
# 423                None
# 424                 1=2
# 425                 1=1
# 426                none
# 427                none
# 428                 1=1
# 429                none
# 430                none
# 431                none
# 432                none
# 433                None
# 434                none
# 435                None
# 436                none
# 437                none
# 438                none
# 439                none
#
# [440 rows x 10 columns]

# %%
plant_micro = pd.read_csv('./csv_folder/plant_microbe_phylum.csv')

# %%
plant_micro.head()
# Out:
#    Unnamed: 0 sample_id Site  Archaea|Crenarchaeota  Archaea|Euryarchaeota  \
# 0           0      RRL1  RRL                    0.0                0.17797
# 1           1      RRL2  RRL                    0.0                0.15614
# 2           2      RRL3  RRL                    0.0                0.17023
# 3           3      RRL4  RRL                    0.0                0.15893
# 4           4      RRL5  RRL                    0.0                0.14098
#
#    Archaea|Thaumarchaeota  Bacteria|Abditibacteriota  Bacteria|Acidobacteria  \
# 0                     0.0                        0.0                 0.08643
# 1                     0.0                        0.0                 0.00198
# 2                     0.0                        0.0                 0.08687
# 3                     0.0                        0.0                 0.05855
# 4                     0.0                        0.0                 0.00024
#
#    Bacteria|Actinobacteria  Bacteria|Aquificae           ...             \
# 0                  4.71047             0.14310           ...
# 1                  4.87482             0.20014           ...
# 2                  3.52737             0.10634           ...
# 3                  4.61111             0.11605           ...
# 4                  3.05559             0.13950           ...
#
#    Eukaryota|Bacillariophyta  Eukaryota|Basidiomycota  \
# 0                    0.00033                  0.09698
# 1                    0.00050                  0.06678
# 2                    0.00045                  0.07855
# 3                    0.00026                  0.06440
# 4                    0.00027                  0.03485
#
#    Eukaryota|Blastocladiomycota  Eukaryota|Chlorophyta  \
# 0                           0.0                0.04030
# 1                           0.0                0.02993
# 2                           0.0                0.03326
# 3                           0.0                0.03055
# 4                           0.0                0.02211
#
#    Eukaryota|Chytridiomycota  Eukaryota|Cryptomycota  Eukaryota|Microsporidia  \
# 0                        0.0                 0.00016                  0.00073
# 1                        0.0                 0.00051                  0.00049
# 2                        0.0                 0.00032                  0.00040
# 3                        0.0                 0.00055                  0.00039
# 4                        0.0                 0.00023                  0.00049
#
#    Eukaryota|Mucoromycota  Eukaryota|Streptophyta  Eukaryota|Zoopagomycota
# 0                 0.00599                     0.0                      0.0
# 1                 0.00390                     0.0                      0.0
# 2                 0.00311                     0.0                      0.0
# 3                 0.00539                     0.0                      0.0
# 4                 0.00220                     0.0                      0.0
#
# [5 rows x 92 columns]

# %%
import pandas as pd

# my_data = pd.read_csv("my_input_file.csv")
my_data = plant_micro

curs.execute("DROP TABLE IF EXISTS my_table;")

## connect to database
import sqlite3

conn = sqlite3.connect("test1.db")

##push the dataframe to sql 
#my_data.to_sql("my_data", conn, if_exists="replace")

my_data.to_sql("my_data", conn, if_exists="replace")


##create the table

conn.execute(
    """
    create table my_table as 
    select * from my_data
    """)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-15-41aa700af957> in <module>()
#       4 my_data = plant_micro
#       5
# ----> 6 curs.execute("DROP TABLE IF EXISTS my_table;")
#       7
#       8 ## connect to database
#
# OperationalError: database is locked

# %%
# In case it already exists:
#curs.execute("DROP VIEW IF EXISTS tSample;")


sql = """
CREATE VIEW my_table AS 

SELECT *
;"""

pd.read_sql("SELECT * FROM my_table;", conn)
# Out:
#      index  Unnamed: 0 sample_id Site  Archaea|Crenarchaeota  \
# 0        0           0      RRL1  RRL                    0.0
# 1        1           1      RRL2  RRL                    0.0
# 2        2           2      RRL3  RRL                    0.0
# 3        3           3      RRL4  RRL                    0.0
# 4        4           4      RRL5  RRL                    0.0
# 5        5           5      RRL6  RRL                    0.0
# 6        6           6      RRL7  RRL                    0.0
# 7        7           7      RRL8  RRL                    0.0
# 8        8           8      RRL9  RRL                    0.0
# 9        9           9     RRL10  RRL                    0.0
# 10      10          10     RRL11  RRL                    0.0
# 11      11          11     RRL12  RRL                    0.0
# 12      12          12     RRL13  RRL                    0.0
# 13      13          13     RRL14  RRL                    0.0
# 14      14          14     RRL15  RRL                    0.0
# 15      15          15     RRL16  RRL                    0.0
# 16      16          16     RRL17  RRL                    0.0
# 17      17          17     RRL18  RRL                    0.0
# 18      18          18     RRL19  RRL                    0.0
# 19      19          19     RRL20  RRL                    0.0
# 20      20          20     RRL21  RRL                    0.0
# 21      21          21     RRL22  RRL                    0.0
# 22      22          22      FRW1  FRW                    0.0
# 23      23          23      FRW2  FRW                    0.0
# 24      24          24      FRW3  FRW                    0.0
# 25      25          25      FRW4  FRW                    0.0
# 26      26          26     FRW 5  FRW                    0.0
# 27      27          27      FRW6  FRW                    0.0
# 28      28          28      FRW8  FRW                    0.0
# 29      29          29      FRW9  FRW                    0.0
# ..     ...         ...       ...  ...                    ...
# 160    160         160      LM17   LM                    0.0
# 161    161         161      LM18   LM                    0.0
# 178                0.15026                     0.0                        0.0
# 179                0.14774                     0.0                        0.0
# 180                0.13817                     0.0                        0.0
# 181                0.17599                     0.0                        0.0
# 182                0.12646                     0.0                        0.0
# 183                0.00000                     0.0                        0.0
# 184                0.00000                     0.0                        0.0
# 185                0.10884                     0.0                        0.0
# 186                0.15341                     0.0                        0.0
# 187                0.16476                     0.0                        0.0
# 188                0.13096                     0.0                        0.0
# 189                0.17623                     0.0                        0.0
#
#      Bacteria|Acidobacteria  Bacteria|Actinobacteria           ...             \
# 0                   0.08643                  4.71047           ...
# 1                   0.00198                  4.87482           ...
# 2                   0.08687                  3.52737           ...
# 3                   0.05855                  4.61111           ...
# 4                   0.00024                  3.05559           ...
# 5                   0.08300                  4.35181           ...
# 6                   0.09393                  8.44138           ...
# 7                   0.00000                  5.17185           ...
# 8                   0.00400                  6.45114           ...
# 9                   0.00016                  2.38119           ...
# 10                  0.10175                  3.97643           ...
# 11                  0.15922                  5.82162           ...
# 12                  0.06208                  3.06852           ...
# 13                  0.08006                  3.29641           ...
# 14                  0.03861                  3.69929           ...
# 15                  0.05039                  3.62825           ...
# 16                  0.16964                  5.44963           ...
# 17                  0.00064                  3.46605           ...
# 18                  0.00000                  3.42467           ...
# 19                  0.11455                  5.14588           ...
# 20                  0.09905                  3.11721           ...
# 21                  0.08306                  3.08142           ...
# 22                  0.08961                  4.63377           ...
# 23                  0.00163                  3.42432           ...
# 24                  0.06111                  2.87362           ...
# 25                  0.05822                  3.98016           ...
# 26                  0.05418                  3.83156           ...
# 27                  0.07568                  3.83732           ...
# 28                  0.06225                  3.73230           ...
# 29                  0.03008                  3.26424           ...
# ..                      ...                      ...           ...
# 160                 0.05758                  3.07861           ...
# 161                 0.05612                  3.02685           ...
# 162                 0.05555                  3.33856           ...
# 163                 0.05507                  2.94150           ...
# 164                 0.03704                  2.40038           ...
# 165                 0.04271                  2.90488           ...
# 166                 0.00193                  1.89188           ...
# 167                 0.05727                  3.26494           ...
# 168                 0.00073                  1.87711           ...
# 169                 0.02137                  2.10213           ...
# 170                 0.04420                  2.27666           ...
# 171                 0.03750                  1.47981           ...
# 172                 0.03712                  1.44031           ...
# 173                 0.02682                  1.59838           ...
# 174                 0.05861                  2.81683           ...
# 175                 0.02376                  2.85870           ...
# 176                 0.02044                  1.94543           ...
# 177                 0.00016                  2.36878           ...
# 178                 0.00000                  3.38635           ...
# 179                 0.07034                  3.13025           ...
# 180                 0.03906                  2.24964           ...
# 181                 0.04157                  2.87788           ...
# 182                 0.00197                  1.73207           ...
# 183                 0.00000                  5.71398           ...
# 184                 0.00000                  8.62726           ...
# 185                 0.00081                  1.75697           ...
# 186                 0.05259                  3.21738           ...
# 187                 0.02670                  1.78896           ...
# 188                 0.00000                  2.65974           ...
# 189                 0.08471                  1.45164           ...
#
#      Eukaryota|Bacillariophyta  Eukaryota|Basidiomycota  \
# 0                      0.00033                  0.09698
# 1                      0.00050                  0.06678
# 2                      0.00045                  0.07855
# 3                      0.00026                  0.06440
# 4                      0.00027                  0.03485
# 5                      0.00039                  0.06259
# 6                      0.00053                  0.09069
# 7                      0.00061                  0.04317
# 8                      0.00079                  0.06047
