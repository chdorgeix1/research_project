# %%
import pandas as pd

# %%
df1 = pd.read_csv("202107_phylum_without_site.csv")
df2 = pd.read_csv("202107_site_list.csv")

# %%
df1.head()
# Out:
#    Unnamed: 0 samples paired_end  Archaea|Euryarchaeota  \
# 0           0     A01         R1                0.09709
# 1           1     A03         R2                0.15444
# 2           2     A05         R1                0.08200
# 3           3     A07         R2                0.12350
# 4           4     A09         R1                0.16543
#
#    Archaea|Thaumarchaeota  Bacteria|Acidobacteria  Bacteria|Actinobacteria  \
# 0                     0.0                 0.05260                  2.28435
# 1                     0.0                 0.28245                  3.94682
# 2                     0.0                 0.04850                  3.04700
# 3                     0.0                 0.12223                  3.79800
# 4                     0.0                 0.14183                  3.65170
#
#    Bacteria|Aquificae  Bacteria|Armatimonadetes  Bacteria|Bacteroidetes  ...  \
# 0             0.23518                   0.00000                 0.53916  ...
# 1             0.23356                   0.00014                 0.32229  ...
# 2             0.18302                   0.00000                 0.12106  ...
# 3             0.00133                   0.00000                 0.26494  ...
# 4             0.14374                   0.00000                 0.40374  ...
#
#    Eukaryota|Ascomycota  Eukaryota|Bacillariophyta  Eukaryota|Basidiomycota  \
# 0               0.14960                    0.00031                  0.02912
# 1               0.22396                    0.00062                  0.03889
# 2               0.12129                    0.00000                  0.08449
# 3               0.25446                    0.00030                  0.09569
# 4               0.24398                    0.00022                  0.05253
#
#    Eukaryota|Blastocladiomycota  Eukaryota|Chlorophyta  \
# 0                           0.0                0.01320
# 1                           0.0                0.04182
# 2                           0.0                0.02365
# 3                           0.0                0.06760
# 4                           0.0                0.02940
#
#    Eukaryota|Cryptomycota  Eukaryota|Microsporidia  Eukaryota|Mucoromycota  \
# 0                 0.00000                  0.00110                 0.00406
# 1                 0.00041                  0.00194                 0.00458
# 2                 0.00022                  0.00107                 0.00460
# 3                 0.00020                  0.00146                 0.00506
# 4                 0.00021                  0.00256                 0.00756
#
#    Eukaryota|Streptophyta  Eukaryota|Zoopagomycota
# 0                     0.0                  0.00121
# 1                     0.0                  0.00012
# 2                     0.0                  0.00000
# 3                     0.0                  0.00015
# 4                     0.0                  0.00033
#
# [5 rows x 73 columns]

# %%
df2.head()
# Out:
#    A01  SLG1  SLG
# 0  B01  SLG2  SLG
# 1  C01  SLG3  SLG
# 2  D01  SLG4  SLG
# 3  E01  SLG5  SLG
# 4  F01  SLG6  SLG

# %%
list1 = []
for items in df2.columns:
    list1.append(items)

# %%
print(list1)
# Out:
# ['A01', 'SLG1', 'SLG']

# %%
df2.loc[-1] = list1
df2.index = df2.index + 1  # shifting index
df2 = df2.sort_index()  # sorting by index
df2.head()
# Out:
#    A01  SLG1  SLG
# 0  A01  SLG1  SLG
# 1  B01  SLG2  SLG
# 2  C01  SLG3  SLG
# 3  D01  SLG4  SLG
# 4  E01  SLG5  SLG

# %%
df2.columns[1]
# Out:
# 'SLG1'

# %%
df2.rename(columns = {df2.columns[0]:'meta_id', df2.columns[1]: 'sample_id', df2.columns[2]: 'site'}, inplace = True)

# %%
df2.head()
# Out:
#   meta_id sample_id site
# 0     A01      SLG1  SLG
# 1     B01      SLG2  SLG
# 2     C01      SLG3  SLG
# 3     D01      SLG4  SLG
# 4     E01      SLG5  SLG

# %%
df3 = (pd.merge(df1, df2, left_on='samples', right_on='meta_id', how='left').drop('meta_id', axis=1))

# %%
df3.head()
# Out:
#    Unnamed: 0 samples paired_end  Archaea|Euryarchaeota  \
# 0           0     A01         R1                0.09709
# 1           1     A03         R2                0.15444
# 2           2     A05         R1                0.08200
# 3           3     A07         R2                0.12350
# 4           4     A09         R1                0.16543
#
#    Archaea|Thaumarchaeota  Bacteria|Acidobacteria  Bacteria|Actinobacteria  \
# 0                     0.0                 0.05260                  2.28435
# 1                     0.0                 0.28245                  3.94682
# 2                     0.0                 0.04850                  3.04700
# 3                     0.0                 0.12223                  3.79800
# 4                     0.0                 0.14183                  3.65170
#
#    Bacteria|Aquificae  Bacteria|Armatimonadetes  Bacteria|Bacteroidetes  ...  \
# 0             0.23518                   0.00000                 0.53916  ...
# 1             0.23356                   0.00014                 0.32229  ...
# 2             0.18302                   0.00000                 0.12106  ...
# 3             0.00133                   0.00000                 0.26494  ...
# 4             0.14374                   0.00000                 0.40374  ...
#
#    Eukaryota|Basidiomycota  Eukaryota|Blastocladiomycota  \
# 0                  0.02912                           0.0
# 1                  0.03889                           0.0
# 2                  0.08449                           0.0
# 3                  0.09569                           0.0
# 4                  0.05253                           0.0
#
#    Eukaryota|Chlorophyta  Eukaryota|Cryptomycota  Eukaryota|Microsporidia  \
# 0                0.01320                 0.00000                  0.00110
# 1                0.04182                 0.00041                  0.00194
# 2                0.02365                 0.00022                  0.00107
# 3                0.06760                 0.00020                  0.00146
# 4                0.02940                 0.00021                  0.00256
#
#    Eukaryota|Mucoromycota  Eukaryota|Streptophyta  Eukaryota|Zoopagomycota  \
# 0                 0.00406                     0.0                  0.00121
# 1                 0.00458                     0.0                  0.00012
# 2                 0.00460                     0.0                  0.00000
# 3                 0.00506                     0.0                  0.00015
# 4                 0.00756                     0.0                  0.00033
#
#    sample_id  site
# 0       SLG1   SLG
# 1      SLG17   SLG
# 2      PNR11   PNR
# 3       RF13    RF
# 4      FRW17   FRW
#
# [5 rows x 75 columns]

# %%
cols = list(df3.columns.values)
print(cols)
# Out:
# ['Unnamed: 0', 'samples', 'paired_end', 'Archaea|Euryarchaeota', 'Archaea|Thaumarchaeota', 'Bacteria|Acidobacteria', 'Bacteria|Actinobacteria', 'Bacteria|Aquificae', 'Bacteria|Armatimonadetes', 'Bacteria|Bacteroidetes', 'Bacteria|Balneolaeota', 'Bacteria|Calditrichaeota', 'Bacteria|Candidatus Aminicenantes', 'Bacteria|Candidatus Atribacteria', 'Bacteria|Candidatus Curtissbacteria', 'Bacteria|Candidatus Dadabacteria', 'Bacteria|Candidatus Eisenbacteria', 'Bacteria|Candidatus Falkowbacteria', 'Bacteria|Candidatus Fermentibacteria', 'Bacteria|Candidatus Gracilibacteria', 'Bacteria|Candidatus Kaiserbacteria', 'Bacteria|Candidatus Marinimicrobia', 'Bacteria|Candidatus Melainabacteria', 'Bacteria|Candidatus Microgenomates', 'Bacteria|Candidatus Nomurabacteria', 'Bacteria|Candidatus Omnitrophica', 'Bacteria|Candidatus Peregrinibacteria', 'Bacteria|Candidatus Poribacteria', 'Bacteria|Candidatus Portnoybacteria', 'Bacteria|Candidatus Rokubacteria', 'Bacteria|Candidatus Saccharibacteria', 'Bacteria|Candidatus Staskawiczbacteria', 'Bacteria|Candidatus Taylorbacteria', 'Bacteria|Candidatus Tectomicrobia', 'Bacteria|Candidatus Terrybacteria', 'Bacteria|Candidatus Woesebacteria', 'Bacteria|Chlamydiae', 'Bacteria|Chlorobi', 'Bacteria|Chloroflexi', 'Bacteria|Chrysiogenetes', 'Bacteria|Cyanobacteria', 'Bacteria|Deinococcus-Thermus', 'Bacteria|Elusimicrobia', 'Bacteria|Firmicutes', 'Bacteria|Fusobacteria', 'Bacteria|Gemmatimonadetes', 'Bacteria|Ignavibacteriae', 'Bacteria|Nitrospinae', 'Bacteria|Nitrospirae', 'Bacteria|Planctomycetes', 'Bacteria|Proteobacteria', 'Bacteria|Rhodothermaeota', 'Bacteria|Spirochaetes', 'Bacteria|Synergistetes', 'Bacteria|Tenericutes', 'Bacteria|Thermodesulfobacteria', 'Bacteria|Thermotogae', 'Bacteria|Verrucomicrobia', 'Bacteria|candidate division AD3', 'Bacteria|candidate division NC10', 'Bacteria|candidate division WWE3', 'Bacteria|candidate division Zixibacteria', 'Eukaryota|Apicomplexa', 'Eukaryota|Ascomycota', 'Eukaryota|Bacillariophyta', 'Eukaryota|Basidiomycota', 'Eukaryota|Blastocladiomycota', 'Eukaryota|Chlorophyta', 'Eukaryota|Cryptomycota', 'Eukaryota|Microsporidia', 'Eukaryota|Mucoromycota', 'Eukaryota|Streptophyta', 'Eukaryota|Zoopagomycota', 'sample_id', 'site']

# %%
df3.head()
# Out:
#    Unnamed: 0 samples paired_end  Archaea|Euryarchaeota  \
# 0           0     A01         R1                0.09709
# 1           1     A03         R2                0.15444
# 2           2     A05         R1                0.08200
# 3           3     A07         R2                0.12350
# 4           4     A09         R1                0.16543
#
#    Archaea|Thaumarchaeota  Bacteria|Acidobacteria  Bacteria|Actinobacteria  \
# 0                     0.0                 0.05260                  2.28435
# 1                     0.0                 0.28245                  3.94682
# 2                     0.0                 0.04850                  3.04700
# 3                     0.0                 0.12223                  3.79800
# 4                     0.0                 0.14183                  3.65170
#
#    Bacteria|Aquificae  Bacteria|Armatimonadetes  Bacteria|Bacteroidetes  ...  \
# 0             0.23518                   0.00000                 0.53916  ...
# 1             0.23356                   0.00014                 0.32229  ...
# 2             0.18302                   0.00000                 0.12106  ...
# 3             0.00133                   0.00000                 0.26494  ...
# 4             0.14374                   0.00000                 0.40374  ...
#
#    Eukaryota|Basidiomycota  Eukaryota|Blastocladiomycota  \
# 0                  0.02912                           0.0
# 1                  0.03889                           0.0
# 2                  0.08449                           0.0
# 3                  0.09569                           0.0
# 4                  0.05253                           0.0
#
#    Eukaryota|Chlorophyta  Eukaryota|Cryptomycota  Eukaryota|Microsporidia  \
# 0                0.01320                 0.00000                  0.00110
# 1                0.04182                 0.00041                  0.00194
# 2                0.02365                 0.00022                  0.00107
# 3                0.06760                 0.00020                  0.00146
# 4                0.02940                 0.00021                  0.00256
#
#    Eukaryota|Mucoromycota  Eukaryota|Streptophyta  Eukaryota|Zoopagomycota  \
# 0                 0.00406                     0.0                  0.00121
# 1                 0.00458                     0.0                  0.00012
# 2                 0.00460                     0.0                  0.00000
# 3                 0.00506                     0.0                  0.00015
# 4                 0.00756                     0.0                  0.00033
#
#    sample_id  site
# 0       SLG1   SLG
# 1      SLG17   SLG
# 2      PNR11   PNR
# 3       RF13    RF
# 4      FRW17   FRW
#
# [5 rows x 75 columns]

# %%
df3 = df3.drop('Unnamed: 0', axis = 1)

# %%
df3.head()
# Out:
#   samples paired_end  Archaea|Euryarchaeota  Archaea|Thaumarchaeota  \
# 0     A01         R1                0.09709                     0.0
# 1     A03         R2                0.15444                     0.0
# 2     A05         R1                0.08200                     0.0
# 3     A07         R2                0.12350                     0.0
# 4     A09         R1                0.16543                     0.0
#
#    Bacteria|Acidobacteria  Bacteria|Actinobacteria  Bacteria|Aquificae  \
# 0                 0.05260                  2.28435             0.23518
# 1                 0.28245                  3.94682             0.23356
# 2                 0.04850                  3.04700             0.18302
# 3                 0.12223                  3.79800             0.00133
# 4                 0.14183                  3.65170             0.14374
#
#    Bacteria|Armatimonadetes  Bacteria|Bacteroidetes  Bacteria|Balneolaeota  \
# 0                   0.00000                 0.53916                 0.0000
# 1                   0.00014                 0.32229                 0.0000
# 2                   0.00000                 0.12106                 0.0000
# 3                   0.00000                 0.26494                 0.0000
# 4                   0.00000                 0.40374                 0.0082
#
#    ...  Eukaryota|Basidiomycota  Eukaryota|Blastocladiomycota  \
# 0  ...                  0.02912                           0.0
# 1  ...                  0.03889                           0.0
# 2  ...                  0.08449                           0.0
# 3  ...                  0.09569                           0.0
# 4  ...                  0.05253                           0.0
#
#    Eukaryota|Chlorophyta  Eukaryota|Cryptomycota  Eukaryota|Microsporidia  \
# 0                0.01320                 0.00000                  0.00110
# 1                0.04182                 0.00041                  0.00194
# 2                0.02365                 0.00022                  0.00107
# 3                0.06760                 0.00020                  0.00146
# 4                0.02940                 0.00021                  0.00256
#
#    Eukaryota|Mucoromycota  Eukaryota|Streptophyta  Eukaryota|Zoopagomycota  \
# 0                 0.00406                     0.0                  0.00121
# 1                 0.00458                     0.0                  0.00012
# 2                 0.00460                     0.0                  0.00000
# 3                 0.00506                     0.0                  0.00015
# 4                 0.00756                     0.0                  0.00033
#
#    sample_id  site
# 0       SLG1   SLG
# 1      SLG17   SLG
# 2      PNR11   PNR
# 3       RF13    RF
# 4      FRW17   FRW
#
# [5 rows x 74 columns]

# %%
df3.insert(1, 'sample_id', df3.pop('sample_id'))
df3.insert(2, 'site', df3.pop('site'))
df3.head()
# Out:
#   samples sample_id site paired_end  Archaea|Euryarchaeota  \
# 0     A01      SLG1  SLG         R1                0.09709
# 1     A03     SLG17  SLG         R2                0.15444
# 2     A05     PNR11  PNR         R1                0.08200
# 3     A07      RF13   RF         R2                0.12350
# 4     A09     FRW17  FRW         R1                0.16543
#
#    Archaea|Thaumarchaeota  Bacteria|Acidobacteria  Bacteria|Actinobacteria  \
# 0                     0.0                 0.05260                  2.28435
# 1                     0.0                 0.28245                  3.94682
# 2                     0.0                 0.04850                  3.04700
# 3                     0.0                 0.12223                  3.79800
# 4                     0.0                 0.14183                  3.65170
#
#    Bacteria|Aquificae  Bacteria|Armatimonadetes  ...  Eukaryota|Ascomycota  \
# 0             0.23518                   0.00000  ...               0.14960
# 1             0.23356                   0.00014  ...               0.22396
# 2             0.18302                   0.00000  ...               0.12129
# 3             0.00133                   0.00000  ...               0.25446
# 4             0.14374                   0.00000  ...               0.24398
#
#    Eukaryota|Bacillariophyta  Eukaryota|Basidiomycota  \
# 0                    0.00031                  0.02912
# 1                    0.00062                  0.03889
# 2                    0.00000                  0.08449
# 3                    0.00030                  0.09569
# 4                    0.00022                  0.05253
#
#    Eukaryota|Blastocladiomycota  Eukaryota|Chlorophyta  \
# 0                           0.0                0.01320
# 1                           0.0                0.04182
# 2                           0.0                0.02365
# 3                           0.0                0.06760
# 4                           0.0                0.02940
#
#    Eukaryota|Cryptomycota  Eukaryota|Microsporidia  Eukaryota|Mucoromycota  \
# 0                 0.00000                  0.00110                 0.00406
# 1                 0.00041                  0.00194                 0.00458
# 2                 0.00022                  0.00107                 0.00460
# 3                 0.00020                  0.00146                 0.00506
# 4                 0.00021                  0.00256                 0.00756
#
#    Eukaryota|Streptophyta  Eukaryota|Zoopagomycota
# 0                     0.0                  0.00121
# 1                     0.0                  0.00012
# 2                     0.0                  0.00000
# 3                     0.0                  0.00015
# 4                     0.0                  0.00033
#
# [5 rows x 74 columns]

# %%
df3.to_csv('202107_phylum_with_site.csv', index=False)
