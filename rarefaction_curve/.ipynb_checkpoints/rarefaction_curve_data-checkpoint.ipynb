# %%
from os import listdir
from os.path import isfile, join
import numpy as np
import re
import pandas as pd
import numpy as np
import dataProcessing as DP

# %%
my_path = '/Users/15404/Documents/GitHub/research_project/rarefaction_curve/rarefaction_curve_data_202109/'
df = DP.data_processing(my_path, 'phylum', False)
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-037e3d21f50a> in <module>()
#       1 my_path = '/Users/15404/Documents/GitHub/research_project/rarefaction_curve/rarefaction_curve_data_202109/'
# ----> 2 df = DP.data_processing(my_path, 'phylum', False, length_09_list = [745096, 200864, 1956530, 245000, 2084321, 1379168, 3224382, 6772713])
#       3 df.head()
#
# TypeError: data_processing() got an unexpected keyword argument 'length_09_list'

# %%
length_09_list = [745096, 200864, 1956530, 245000, 2084321, 1379168, 3224382, 6772713]
final_list = []
for item in length_09_list:
    final_list.append((int(item/4)))
print(final_list)
# Out:
# [186274, 50216, 489132, 61250, 521080, 344792, 806095, 1693178]

# %%
#df.mul([1, 100], axis=0)

df.mul(final_list, axis=0)
# Out:
#                                              samples  \
# 0  A01A01A01A01A01A01A01A01A01A01A01A01A01A01A01A...
# 1  B01B01B01B01B01B01B01B01B01B01B01B01B01B01B01B...
# 2  C01C01C01C01C01C01C01C01C01C01C01C01C01C01C01C...
# 3  D01D01D01D01D01D01D01D01D01D01D01D01D01D01D01D...
# 4  E01E01E01E01E01E01E01E01E01E01E01E01E01E01E01E...
# 5  F01F01F01F01F01F01F01F01F01F01F01F01F01F01F01F...
# 6  G01G01G01G01G01G01G01G01G01G01G01G01G01G01G01G...
# 7  H01H01H01H01H01H01H01H01H01H01H01H01H01H01H01H...
#
#                                           paired_end  \
# 0  R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1...
# 1  R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2...
# 2  R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1...
# 3  R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2...
# 4  R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1...
# 5  R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2...
# 6  R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1R1...
# 7  R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2R2...
#
# ...

# %%
df.head()
# Out:
#   samples paired_end Archaea|Crenarchaeota Archaea|Euryarchaeota  \
# 0     A01         R1               0.00025               0.00288
# 1     B01         R2               0.00119                 0.039
# 2     C01         R1                     0               0.00253
# 3     D01         R2                     0               0.04064
# 4     E01         R1               0.00018                0.0538
#
#   Archaea|Thaumarchaeota Bacteria|Acidobacteria Bacteria|Actinobacteria  \
# 0                0.00016                0.39156                 7.16024
# 1                      0                0.25991                 5.16737
# 2                0.00042                0.31979                 8.27919
# 3                0.00617                0.31951                11.79747
# 4                0.02756                0.43642                 8.76166
#
#   Bacteria|Aquificae Bacteria|Armatimonadetes Bacteria|Bacteroidetes  \
# ...

# %%
df.to_csv('rarefaction_data_5488_phylum.csv')
