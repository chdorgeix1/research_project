# %%
from os import listdir
from os.path import isfile, join
import numpy as np
import re
import pandas as pd
import numpy as np
import dataProcessing as DP

# %%
my_path = '/Users/15404/Documents/GitHub/research_project/rarefaction_curve_data_202109/'
df = DP.data_processing(my_path, 'genus', False)
df.head()
# Out:
#   samples paired_end  \
# 0     A01         R1
# 1     A03         R2
# 2     A05         R1
# 3     A07         R2
# 4     A09         R1
#
#   Archaea|Crenarchaeota|Thermoprotei|Acidilobales|Acidilobaceae|Acidilobus  \
# 0                                                  0
# 1                                                  0
# 2                                            0.00031
# 3                                                  0
# 4                                                  0
#
#   Archaea|Crenarchaeota|Thermoprotei|Desulfurococcales|Desulfurococcaceae|Aeropyrum  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#   Archaea|Crenarchaeota|Thermoprotei|Desulfurococcales|Desulfurococcaceae|Desulfurococcus  \
# ...

# %%
df.to_csv('rarefaction_data_202109_genus.csv')
